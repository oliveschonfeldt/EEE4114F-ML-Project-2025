# %% [markdown]
# # EEE4114F ML Project Code
#
# The motionsense dataset is divided into three main folders:
#
# - **(A) DeviceMotion_data:** Contains a rich combination of accelerometer, gyroscope, and orientation-related features — 12 features in total.
#
# - **(B) Accelerometer_data:** Includes only the raw accelerometer readings (x, y, z) — 3 features.
#
# - **(C) Gyroscope_data:** Includes only the raw gyroscope readings (x, y, z) — 3 features.
#
#
# From these, **(A) DeviceMotion_data** provides the most comprehensive set of features, combining both linear and rotational data, as well as derived orientation estimates:
#
# - **Attitude (roll, pitch, yaw)** showing device orientation (e.g., facing up/down)
# - **Gravity (x, y, z)** showing static acceleration (orientation wrt gravity)
# - **Rotation Rate (x, y, z)** showing angular velocity from gyroscope
# - **User Acceleration (x, y, z)** showing motion (dynamic body acceleration)

# %% [markdown]
# ## Libraries to import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, TimeSeriesSplit, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %% [markdown]
# ## Loading the data
# Here are some useful functions from motionsense.ipyb we have copied. It helps to copy the data from (A) DeviceMotion_data as a labeled time series dataset.

# %%
def get_ds_infos():
    """
    Read the file includes data subject information.

    EEE4114: Technically we do not need these data, as we are not concerned about identifying the subjects. 
    
    Data Columns:
    0: code [1-24]
    1: weight [kg]
    2: height [cm]
    3: age [years]
    4: gender [0:Female, 1:Male]
    
    Returns:
        A pandas DataFrame that contains information about data subjects' attributes 
    """ 

    dss = pd.read_csv(f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/data_subjects_info.csv')
    print("[INFO] -- Data subjects' information is imported.")
    
    return dss

def set_data_types(data_types=["userAcceleration"]):
    """
    Select the sensors and the mode to shape the final dataset. 

    EEE4114F: Choose sensors that you think are useful or would like to include in training. 
    You can choose all of them, or you could opt to try a limited set of input features
    
    Args:
        data_types: A list of sensor data type from this list: [attitude, gravity, rotationRate, userAcceleration] 

    Returns:
        It returns a list of columns to use for creating time-series from files.
    """
    dt_list = []
    for t in data_types:
        if t != "attitude":
            dt_list.append([t+".x",t+".y",t+".z"])
        else:
            dt_list.append([t+".roll", t+".pitch", t+".yaw"])

    return dt_list


def create_time_series(dt_list, act_labels, trial_codes, mode="mag", labeled=True):
    """
    EEE4114F: This defines what data you would like to include for a given set.  

    Args:
        dt_list: A list of columns that shows the type of data we want.
        act_labels: list of activities.
        trial_codes: list of trial codes corresponding to each activity.
        mode: It can be "raw" (all dimensions of each data type) or "mag" (only magnitude per data type).
        labeled: True if labeled dataset (adds 'act', 'trial', 'sub_id'), False otherwise.

    Returns:
        pd.DataFrame: Time-series sensor data with optional labels.
    """
    num_data_cols = len(dt_list) if mode == "mag" else len(dt_list * 3)

    if labeled:
        # +3 for act, trial, sub_id labels
        dataset = np.zeros((0, num_data_cols + 3))
    else:
        dataset = np.zeros((0, num_data_cols))

    ds_list = get_ds_infos()  # Assume this returns dict with "code" key for subject IDs

    print("[INFO] -- Creating Time-Series")
    for sub_id in ds_list["code"]:
        for act_id, act in enumerate(act_labels):
            for trial in trial_codes[act_id]:
                fname = f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/A_DeviceMotion_data/{act}_{trial}/sub_{int(sub_id)}.csv'
                raw_data = pd.read_csv(fname)
                raw_data = raw_data.drop(['Unnamed: 0'], axis=1)
                vals = np.zeros((len(raw_data), num_data_cols))
                for x_id, axes in enumerate(dt_list):
                    if mode == "mag":
                        # Calculate magnitude of 3 axes per sensor type
                        vals[:, x_id] = (raw_data[axes] ** 2).sum(axis=1) ** 0.5        
                    else:
                        vals[:, x_id * 3:(x_id + 1) * 3] = raw_data[axes].values
                    vals = vals[:, :num_data_cols]
                if labeled:
                    # Add act, trial, sub_id as labels (same length as vals)
                    lbls = np.array([[act_id, trial, sub_id]] * len(raw_data))
                    vals = np.concatenate((vals, lbls), axis=1)
                dataset = np.append(dataset, vals, axis=0)

    cols = []
    for axes in dt_list:
        if mode == "raw":
            cols += axes
        else:
            cols += [str(axes[0][:-2])]  # Use first part of sensor name for magnitude

    if labeled:
        cols += ["act", "trial", "sub_id"]

    dataset = pd.DataFrame(data=dataset, columns=cols)
    return dataset

# %%
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}

## Here we set parameter to build labeled time-series from dataset of "(A)DeviceMotion_data"
## attitude(roll, pitch, yaw); gravity(x, y, z); rotationRate(x, y, z); userAcceleration(x,y,z)
sdt = ["attitude", "gravity"] #, "rotationRate", "userAcceleration"
print("[INFO] -- Selected sensor data types: "+str(sdt))    
act_labels = ACT_LABELS # choose all 6 classes
print("[INFO] -- Selected activites: "+str(act_labels))    
trial_codes = [TRIAL_CODES[act] for act in act_labels]
dt_list = set_data_types(sdt)
dataset = create_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
print("[INFO] -- Shape of time-Series dataset:"+str(dataset.shape))    
dataset.head()
# Out:
# [INFO] -- Selected sensor data types: ['attitude', 'gravity']
# [INFO] -- Selected activites: ['dws', 'ups', 'wlk', 'jog', 'std', 'sit']
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series
# [INFO] -- Shape of time-Series dataset:(1412865, 9)
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  act  trial  sub_id
# 0  -0.031672  0.0    1.0     1.0
# 1  -0.032255  0.0    1.0     1.0
# 2  -0.032707  0.0    1.0     1.0
# 3  -0.041140  0.0    1.0     1.0
# 4  -0.058530  0.0    1.0     1.0

# %% [markdown]
# ## Windowing and Splitting the Data
#
# Uses more useful definitions from motionsense.ipyb - the windows() function and MotionSense class.

# %%
def windows(dataset, window_size=400, stride=200):
    """
    Slice dataset into overlapping windows of fixed length.

    Args:
        dataset (pd.DataFrame): Time-series data with sensor features and 'act' label column.
        window_size (int): Number of samples per window.
        stride (int): Step size between windows.

    Returns:
        pd.DataFrame: A new DataFrame with flattened windows and corresponding labels.
    """

    # Separate the feature values and labels
    features = dataset.drop(columns=['act']).values  # Shape: [n_samples, n_features]
    labels = dataset['act'].values  # Shape: [n_samples]

    # Lists to collect the processed windows and labels
    windowed_data = []
    windowed_labels = []

    # Iterate over the dataset with a sliding window
    for start in range(0, len(dataset) - window_size + 1, stride):
        end = start + window_size

        # Extract a window of features and corresponding labels
        window = features[start:end]           # Shape: [window_size, n_features]
        label_window = labels[start:end]       # Shape: [window_size]

        # Flatten the feature window by transposing to [n_features, window_size], then flatten to 1D
        window_flat = window.T.flatten()       # Final shape: [n_features * window_size]

        # Assign the most frequent label in the window as the representative label
        label = np.bincount(label_window.astype(int)).argmax()

        # Append the flattened window and label to the lists
        windowed_data.append(window_flat)
        windowed_labels.append(label)

    # Convert the list of windows to a DataFrame (each row is one flattened window)
    X = pd.DataFrame(windowed_data)

    # Convert the list of labels to a Series
    Y = pd.Series(windowed_labels, name='act')

    return X, Y

# %%
class MotionSense(Dataset):
    def __init__(self, X, Y, transform=None):
        self.X = torch.tensor(X.values)
        self.Y = torch.tensor(Y.values)
        self.transform = transform

    def __getitem__(self, index):
        if torch.is_tensor(index):
            index = int(index.item())

        x = self.X[index]
        y = self.Y[index]

        return x, y

    def __len__(self):
        return len(self.X)

# %% [markdown]
# #### Chose to randomly split data 85% for training and 15% for testing, and to do it subject-wise to avoid data leakage across subjects.
#
# #### Knowing that the minimum recording length is 377, we chose a window size of 400.
#
# #### We chose a stride of 200, 50% of the window size.

# %%
# Split subjects for train/test
unique_sub_ids = dataset['sub_id'].unique()  # Get list of unique subject IDs
train_subs, test_subs = train_test_split(unique_sub_ids, test_size=0.15, random_state=1235498)  
# Randomly split subjects: 85% for training, 15% for testing (subject-wise split ensures no data leakage across subjects)

train_df = dataset[dataset['sub_id'].isin(train_subs)].reset_index(drop=True)  # Extract training data from selected subjects
test_df = dataset[dataset['sub_id'].isin(test_subs)].reset_index(drop=True)    # Extract test data from held-out subjects

# Select only sensor features (exclude meta-info like 'sub_id') and the activity label
feature_cols = [
    'attitude.roll', 'attitude.pitch', 'attitude.yaw',
    'gravity.x', 'gravity.y', 'gravity.z'
]# ,'rotationRate.x', 'rotationRate.y', 'rotationRate.z', userAcceleration.x', 'userAcceleration.y', 'userAcceleration.z'
filtered_train_df = train_df[feature_cols + ['act']]  # Retain only sensor features + label for training
filtered_test_df = test_df[feature_cols + ['act']]    # Same for test data

# Apply windowing to create overlapping segments of fixed length from continuous data
X_train, Y_train = windows(filtered_train_df, window_size=400, stride=200)
X_test, Y_test = windows(filtered_test_df, window_size=400, stride=200)
# Result: X_* are DataFrames of flattened windows, Y_* are Series of majority labels per window

# %% [markdown]
# ## K-Fold Cross-Validation
# K-Fold Cross-Validation is a technique to evaluate model performance by splitting the dataset into *k* equal parts (folds).
# - The dataset is split into **5 folds**.
# - For each of the 5 iterations:
#   - **4 folds are used for training**, and
#   - **1 fold is used for validation**.
# - Each fold serves as the validation set exactly once.
# - After all iterations, performance metrics are averaged to give a robust estimate of model generalization.
# This method ensures that every data point is used for both training and validation, helping to reduce overfitting and improve reliability.

# %%
k_folds = 5  # Define number of folds for cross-validation

# Initialize KFold cross-validator (shuffling ensures different class distributions across folds)
kf = KFold(n_splits=5, shuffle=True, random_state=147569)
all_splits = list(kf.split(X_train))  # Create list of (train_idx, val_idx) splits for each fold

# %% [markdown]
# ## Define Model Architecture - FCNet
#
# Due to the ease of implementation and interpretability (and since it was included in the motionsense.ipyb), we have decided to explore the FCNet architecture as the model architecture for classifying.
#
# The main parameters here is the input size (12 features * 400 time steps), the size of the hidden layer, and the total number of activity classes to clasify (which we all know is 6).
#
# The 4800 features became 50 then became 6 features, and to improve learning stability and generalisation, we also applied batch normalisation, ReLU activation and dropout (rate 0.5).

# %%
# Define the improved fully connected neural network for time-series classification
class FCNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FCNet, self).__init__()

        # First fully connected layer: input -> hidden_size
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)      # Batch normalization to stabilize learning
        self.dropout1 = nn.Dropout(0.5)             # Dropout to prevent overfitting

        # Second fully connected layer: hidden_size -> hidden_size // 2
        self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
        self.bn2 = nn.BatchNorm1d(hidden_size // 2) # Batch normalization
        self.dropout2 = nn.Dropout(0.5)             # Dropout again for regularization

        # Final layer: hidden_size // 2 -> number of classes
        self.fc3 = nn.Linear(hidden_size // 2, num_classes)

        self.relu = nn.ReLU()  # Activation function

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input from [batch, channels, time] to [batch, features]

        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.dropout2(x)

        x = self.fc3(x)  # Final output layer (no activation here; loss function will handle it)
        return x

# Parameters — adjusted according to our input window configuration
input_size = 6 * 400     # 12 sensor features per timestep × 400 time steps per window
hidden_size = 50          # Size of hidden layer (can be tuned)
num_classes = 6           # Total number of activity classes to classify

# %% [markdown]
# ## Model Training and Evaluation
#
# Here we train for 50 epochs. This was enough epochs for convergence whilst not under- or overfitting.
#
# We also use the Adam optimiser (better than standard gradient descent!) at a learning rate of 0.001.
#
# During the training, we track the training and validation losses and accuracies, as well as the best accuracy and the corresponding model for subsequent training.

# %%
num_epochs = 50  # Number of epochs to train per fold

# Track the best performing model across all folds
best_val_acc = 0
best_model_state = None

# Lists to store metrics for each fold
fold_train_losses = [[] for _ in range(k_folds)]
fold_val_losses = [[] for _ in range(k_folds)]
fold_train_accuracies = [[] for _ in range(k_folds)]
fold_val_accuracies = [[] for _ in range(k_folds)]

# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(all_splits):
    print(f"Fold {fold + 1}")

    # Prepare train and validation splits
    X_tr = X_train.iloc[train_idx].reset_index(drop=True)
    Y_tr = Y_train.iloc[train_idx].reset_index(drop=True)
    X_val = X_train.iloc[val_idx].reset_index(drop=True)
    Y_val = Y_train.iloc[val_idx].reset_index(drop=True)

    # Wrap data into custom dataset class
    train_ds = MotionSense(X_tr, Y_tr)
    val_ds = MotionSense(X_val, Y_val)

    # Create DataLoaders
    train_dl = DataLoader(train_ds, batch_size=32, shuffle=True, drop_last=True)
    val_dl = DataLoader(val_ds, batch_size=32, shuffle=False, drop_last=True)

    # Initialize model, loss function, and optimizer
    model = FCNet(input_size, hidden_size, num_classes)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

    # Train for the specified number of epochs
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        running_loss = 0
        correct = 0
        total = 0

        # Training loop
        for inputs, labels in train_dl:
            optimizer.zero_grad()                 # Clear previous gradients
            outputs = model(inputs.float())       # Forward pass
            loss = criterion(outputs, labels.long())  # Compute loss
            loss.backward()                       # Backward pass
            optimizer.step()                      # Update weights

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_dl)
        train_acc = 100 * correct / total

        # Store metrics for this epoch
        fold_train_losses[fold].append(train_loss)
        fold_train_accuracies[fold].append(train_acc)

        # Validation loop
        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels in val_dl:
                outputs = model(inputs.float())         # Forward pass
                loss = criterion(outputs, labels)       # Compute validation loss
                val_loss += loss.item() * inputs.size(0)  # Accumulate total loss

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        avg_val_loss = val_loss / val_total
        val_acc = 100 * val_correct / val_total

        # Log metrics
        print(f"Epoch {epoch+1}: Train Loss={train_loss:.4f}, Train Acc={train_acc:.2f}%, "
              f"Val Loss={avg_val_loss:.4f}, Val Acc={val_acc:.2f}%")

        fold_val_losses[fold].append(avg_val_loss)
        fold_val_accuracies[fold].append(val_acc)

    # Track the best-performing model based on final validation accuracy
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model_state = model.state_dict()  # Save best model parameters
# Out:
# Fold 1
# Epoch 1: Train Loss=1.4813, Train Acc=43.03%, Val Loss=1.3131, Val Acc=52.17%
# Epoch 2: Train Loss=1.3115, Train Acc=50.70%, Val Loss=1.2067, Val Acc=54.95%
# Epoch 3: Train Loss=1.2313, Train Acc=53.19%, Val Loss=1.1652, Val Acc=54.95%
# Epoch 4: Train Loss=1.1981, Train Acc=54.68%, Val Loss=1.1100, Val Acc=57.03%
# Epoch 5: Train Loss=1.1747, Train Acc=55.48%, Val Loss=1.0663, Val Acc=57.55%
# Epoch 6: Train Loss=1.1395, Train Acc=55.99%, Val Loss=1.0414, Val Acc=57.64%
# Epoch 7: Train Loss=1.1206, Train Acc=56.82%, Val Loss=1.0276, Val Acc=59.03%
# Epoch 8: Train Loss=1.0845, Train Acc=58.25%, Val Loss=0.9889, Val Acc=61.11%
# Epoch 9: Train Loss=1.0640, Train Acc=58.46%, Val Loss=0.9456, Val Acc=61.28%
# Epoch 10: Train Loss=1.0501, Train Acc=60.29%, Val Loss=0.8964, Val Acc=63.63%
# Epoch 11: Train Loss=1.0158, Train Acc=60.59%, Val Loss=0.8783, Val Acc=64.67%
# Epoch 12: Train Loss=0.9890, Train Acc=61.31%, Val Loss=0.8523, Val Acc=66.41%
# Epoch 13: Train Loss=0.9889, Train Acc=62.35%, Val Loss=0.8199, Val Acc=66.41%
# Epoch 14: Train Loss=0.9606, Train Acc=63.20%, Val Loss=0.8057, Val Acc=67.88%
# Epoch 15: Train Loss=0.9429, Train Acc=64.56%, Val Loss=0.7847, Val Acc=68.49%
# Epoch 16: Train Loss=0.9223, Train Acc=64.73%, Val Loss=0.7652, Val Acc=70.66%
# Epoch 17: Train Loss=0.9307, Train Acc=65.03%, Val Loss=0.7590, Val Acc=71.53%
# Epoch 18: Train Loss=0.9086, Train Acc=65.09%, Val Loss=0.7353, Val Acc=70.40%
# Epoch 19: Train Loss=0.9049, Train Acc=66.05%, Val Loss=0.7354, Val Acc=69.44%
# Epoch 20: Train Loss=0.8798, Train Acc=66.22%, Val Loss=0.7202, Val Acc=72.05%
# Epoch 21: Train Loss=0.8683, Train Acc=66.84%, Val Loss=0.7137, Val Acc=72.31%
# Epoch 22: Train Loss=0.8689, Train Acc=67.90%, Val Loss=0.7061, Val Acc=71.70%
# Epoch 23: Train Loss=0.8566, Train Acc=67.30%, Val Loss=0.6991, Val Acc=71.88%
# Epoch 24: Train Loss=0.8435, Train Acc=68.81%, Val Loss=0.6979, Val Acc=72.83%
# Epoch 25: Train Loss=0.8718, Train Acc=66.67%, Val Loss=0.6890, Val Acc=74.39%
# Epoch 26: Train Loss=0.8599, Train Acc=67.69%, Val Loss=0.7089, Val Acc=74.22%
# Epoch 27: Train Loss=0.8548, Train Acc=68.18%, Val Loss=0.6894, Val Acc=73.00%
# Epoch 28: Train Loss=0.8386, Train Acc=67.96%, Val Loss=0.6818, Val Acc=74.05%
# Epoch 29: Train Loss=0.8336, Train Acc=68.86%, Val Loss=0.6936, Val Acc=74.83%
# Epoch 30: Train Loss=0.8246, Train Acc=69.13%, Val Loss=0.6711, Val Acc=73.78%
# Epoch 31: Train Loss=0.8099, Train Acc=69.49%, Val Loss=0.6762, Val Acc=75.00%
# Epoch 32: Train Loss=0.8313, Train Acc=68.56%, Val Loss=0.6719, Val Acc=75.43%
# Epoch 33: Train Loss=0.8054, Train Acc=69.88%, Val Loss=0.6585, Val Acc=76.30%
# Epoch 34: Train Loss=0.8210, Train Acc=69.39%, Val Loss=0.6735, Val Acc=75.26%
# Epoch 35: Train Loss=0.8014, Train Acc=69.98%, Val Loss=0.6649, Val Acc=75.26%
# Epoch 36: Train Loss=0.7936, Train Acc=70.20%, Val Loss=0.6649, Val Acc=74.74%
# Epoch 37: Train Loss=0.7864, Train Acc=70.24%, Val Loss=0.6351, Val Acc=75.87%
# Epoch 38: Train Loss=0.7849, Train Acc=70.98%, Val Loss=0.6403, Val Acc=76.39%
# Epoch 39: Train Loss=0.7792, Train Acc=70.88%, Val Loss=0.6533, Val Acc=76.04%
# Epoch 40: Train Loss=0.7792, Train Acc=70.75%, Val Loss=0.6515, Val Acc=77.52%
# Epoch 41: Train Loss=0.8024, Train Acc=70.22%, Val Loss=0.6484, Val Acc=77.78%
# Epoch 42: Train Loss=0.7663, Train Acc=71.51%, Val Loss=0.6402, Val Acc=78.30%
# Epoch 43: Train Loss=0.7531, Train Acc=72.60%, Val Loss=0.6278, Val Acc=76.13%
# Epoch 44: Train Loss=0.7464, Train Acc=71.51%, Val Loss=0.6176, Val Acc=78.12%
# Epoch 45: Train Loss=0.7267, Train Acc=72.49%, Val Loss=0.6243, Val Acc=76.91%
# Epoch 46: Train Loss=0.7745, Train Acc=71.73%, Val Loss=0.6252, Val Acc=77.78%
# Epoch 47: Train Loss=0.7319, Train Acc=72.66%, Val Loss=0.5906, Val Acc=79.25%
# Epoch 48: Train Loss=0.7295, Train Acc=73.72%, Val Loss=0.5976, Val Acc=78.39%
# Epoch 49: Train Loss=0.7599, Train Acc=72.00%, Val Loss=0.6073, Val Acc=77.60%
# Epoch 50: Train Loss=0.7315, Train Acc=73.21%, Val Loss=0.6066, Val Acc=78.47%
# Fold 2
# Epoch 1: Train Loss=1.5255, Train Acc=37.80%, Val Loss=1.2853, Val Acc=50.35%
# Epoch 2: Train Loss=1.2865, Train Acc=50.83%, Val Loss=1.1664, Val Acc=55.12%
# Epoch 3: Train Loss=1.2253, Train Acc=53.68%, Val Loss=1.1085, Val Acc=57.38%
# Epoch 4: Train Loss=1.1728, Train Acc=54.51%, Val Loss=1.0685, Val Acc=58.59%
# Epoch 5: Train Loss=1.1591, Train Acc=54.68%, Val Loss=1.0253, Val Acc=58.68%
# Epoch 6: Train Loss=1.1250, Train Acc=55.59%, Val Loss=0.9843, Val Acc=60.24%
# Epoch 7: Train Loss=1.0800, Train Acc=58.38%, Val Loss=0.9480, Val Acc=62.67%
# Epoch 8: Train Loss=1.0583, Train Acc=59.52%, Val Loss=0.9148, Val Acc=63.28%
# Epoch 9: Train Loss=1.0225, Train Acc=60.23%, Val Loss=0.8690, Val Acc=66.49%
# Epoch 10: Train Loss=0.9996, Train Acc=61.12%, Val Loss=0.8491, Val Acc=66.84%
# Epoch 11: Train Loss=0.9921, Train Acc=60.69%, Val Loss=0.8079, Val Acc=68.84%
# Epoch 12: Train Loss=0.9758, Train Acc=61.88%, Val Loss=0.7932, Val Acc=69.01%
# Epoch 13: Train Loss=0.9507, Train Acc=63.71%, Val Loss=0.7920, Val Acc=69.01%
# Epoch 14: Train Loss=0.9348, Train Acc=63.24%, Val Loss=0.7887, Val Acc=70.40%
# Epoch 15: Train Loss=0.9575, Train Acc=63.10%, Val Loss=0.7460, Val Acc=71.01%
# Epoch 16: Train Loss=0.9259, Train Acc=64.26%, Val Loss=0.7504, Val Acc=70.31%
# Epoch 17: Train Loss=0.9383, Train Acc=64.05%, Val Loss=0.7609, Val Acc=71.70%
# Epoch 18: Train Loss=0.9078, Train Acc=65.45%, Val Loss=0.7224, Val Acc=73.18%
# Epoch 19: Train Loss=0.8948, Train Acc=65.84%, Val Loss=0.7333, Val Acc=72.40%
# Epoch 20: Train Loss=0.8915, Train Acc=66.07%, Val Loss=0.7091, Val Acc=72.66%
# Epoch 21: Train Loss=0.8710, Train Acc=66.09%, Val Loss=0.7087, Val Acc=72.66%
# Epoch 22: Train Loss=0.8609, Train Acc=67.33%, Val Loss=0.6935, Val Acc=72.74%
# Epoch 23: Train Loss=0.8653, Train Acc=67.73%, Val Loss=0.7097, Val Acc=73.44%
# Epoch 24: Train Loss=0.8628, Train Acc=67.22%, Val Loss=0.6800, Val Acc=75.43%
# Epoch 25: Train Loss=0.8730, Train Acc=67.22%, Val Loss=0.6905, Val Acc=73.70%
# Epoch 26: Train Loss=0.8396, Train Acc=68.94%, Val Loss=0.6796, Val Acc=74.22%
# Epoch 27: Train Loss=0.8384, Train Acc=68.05%, Val Loss=0.6714, Val Acc=73.70%
# Epoch 28: Train Loss=0.8438, Train Acc=67.18%, Val Loss=0.6702, Val Acc=75.61%
# Epoch 29: Train Loss=0.8455, Train Acc=67.94%, Val Loss=0.6560, Val Acc=74.74%
# Epoch 30: Train Loss=0.8180, Train Acc=68.45%, Val Loss=0.6479, Val Acc=76.91%
# Epoch 31: Train Loss=0.8111, Train Acc=69.32%, Val Loss=0.6519, Val Acc=74.48%
# Epoch 32: Train Loss=0.7995, Train Acc=69.90%, Val Loss=0.6393, Val Acc=76.74%
# Epoch 33: Train Loss=0.7973, Train Acc=70.22%, Val Loss=0.6409, Val Acc=77.43%
# Epoch 34: Train Loss=0.8110, Train Acc=69.69%, Val Loss=0.6547, Val Acc=74.57%
# Epoch 35: Train Loss=0.8128, Train Acc=69.13%, Val Loss=0.6370, Val Acc=77.34%
# Epoch 36: Train Loss=0.7909, Train Acc=70.51%, Val Loss=0.6151, Val Acc=77.95%
# Epoch 37: Train Loss=0.7818, Train Acc=70.51%, Val Loss=0.6299, Val Acc=78.73%
# Epoch 38: Train Loss=0.7812, Train Acc=70.20%, Val Loss=0.6095, Val Acc=76.65%
# Epoch 39: Train Loss=0.7639, Train Acc=70.39%, Val Loss=0.6130, Val Acc=78.39%
# Epoch 40: Train Loss=0.7758, Train Acc=70.62%, Val Loss=0.6250, Val Acc=76.82%
# Epoch 41: Train Loss=0.7420, Train Acc=71.90%, Val Loss=0.5988, Val Acc=78.30%
# Epoch 42: Train Loss=0.7563, Train Acc=71.92%, Val Loss=0.6020, Val Acc=78.91%
# Epoch 43: Train Loss=0.7413, Train Acc=72.41%, Val Loss=0.5842, Val Acc=79.69%
# Epoch 44: Train Loss=0.7454, Train Acc=72.07%, Val Loss=0.5883, Val Acc=79.25%
# Epoch 45: Train Loss=0.7246, Train Acc=73.19%, Val Loss=0.5869, Val Acc=79.95%
# Epoch 46: Train Loss=0.7270, Train Acc=73.02%, Val Loss=0.5851, Val Acc=78.12%
# Epoch 47: Train Loss=0.7462, Train Acc=71.28%, Val Loss=0.5924, Val Acc=78.39%
# Epoch 48: Train Loss=0.7400, Train Acc=72.53%, Val Loss=0.5843, Val Acc=79.08%
# Epoch 49: Train Loss=0.7120, Train Acc=73.32%, Val Loss=0.5752, Val Acc=79.95%
# Epoch 50: Train Loss=0.7369, Train Acc=72.41%, Val Loss=0.5827, Val Acc=78.73%
# Fold 3
# Epoch 1: Train Loss=1.4777, Train Acc=43.35%, Val Loss=1.2061, Val Acc=54.51%
# Epoch 2: Train Loss=1.3004, Train Acc=50.83%, Val Loss=1.0912, Val Acc=57.90%
# Epoch 3: Train Loss=1.2348, Train Acc=52.55%, Val Loss=1.0610, Val Acc=60.07%
# Epoch 4: Train Loss=1.2019, Train Acc=53.95%, Val Loss=1.0220, Val Acc=58.59%
# Epoch 5: Train Loss=1.1657, Train Acc=55.08%, Val Loss=0.9739, Val Acc=60.16%
# Epoch 6: Train Loss=1.1336, Train Acc=55.08%, Val Loss=0.9543, Val Acc=61.37%
# Epoch 7: Train Loss=1.1153, Train Acc=56.02%, Val Loss=0.9252, Val Acc=62.15%
# Epoch 8: Train Loss=1.0999, Train Acc=57.70%, Val Loss=0.9012, Val Acc=63.80%
# Epoch 9: Train Loss=1.0735, Train Acc=57.82%, Val Loss=0.8560, Val Acc=65.97%
# Epoch 10: Train Loss=1.0461, Train Acc=58.91%, Val Loss=0.8301, Val Acc=65.28%
# Epoch 11: Train Loss=1.0497, Train Acc=58.76%, Val Loss=0.8290, Val Acc=65.97%
# Epoch 12: Train Loss=1.0087, Train Acc=60.99%, Val Loss=0.7964, Val Acc=68.66%
# Epoch 13: Train Loss=0.9858, Train Acc=61.39%, Val Loss=0.7899, Val Acc=69.70%
# Epoch 14: Train Loss=0.9790, Train Acc=62.12%, Val Loss=0.7572, Val Acc=68.49%
# Epoch 15: Train Loss=0.9609, Train Acc=62.52%, Val Loss=0.7445, Val Acc=69.97%
# Epoch 16: Train Loss=0.9523, Train Acc=63.31%, Val Loss=0.7318, Val Acc=69.27%
# Epoch 17: Train Loss=0.9414, Train Acc=63.69%, Val Loss=0.7131, Val Acc=71.79%
# Epoch 18: Train Loss=0.9229, Train Acc=64.39%, Val Loss=0.7085, Val Acc=72.22%
# Epoch 19: Train Loss=0.9306, Train Acc=64.22%, Val Loss=0.6943, Val Acc=71.53%
# Epoch 20: Train Loss=0.9000, Train Acc=64.82%, Val Loss=0.6962, Val Acc=72.14%
# Epoch 21: Train Loss=0.8923, Train Acc=64.86%, Val Loss=0.6787, Val Acc=73.87%
# Epoch 22: Train Loss=0.8957, Train Acc=65.39%, Val Loss=0.6839, Val Acc=73.61%
# Epoch 23: Train Loss=0.8813, Train Acc=66.52%, Val Loss=0.6722, Val Acc=73.70%
# Epoch 24: Train Loss=0.8855, Train Acc=65.86%, Val Loss=0.6645, Val Acc=75.09%
# Epoch 25: Train Loss=0.8612, Train Acc=67.26%, Val Loss=0.6473, Val Acc=74.65%
# Epoch 26: Train Loss=0.8612, Train Acc=67.28%, Val Loss=0.6443, Val Acc=76.04%
# Epoch 27: Train Loss=0.8546, Train Acc=68.26%, Val Loss=0.6402, Val Acc=75.26%
# Epoch 28: Train Loss=0.8491, Train Acc=68.43%, Val Loss=0.6465, Val Acc=73.44%
# Epoch 29: Train Loss=0.8229, Train Acc=68.73%, Val Loss=0.6251, Val Acc=76.30%
# Epoch 30: Train Loss=0.8336, Train Acc=69.03%, Val Loss=0.6103, Val Acc=77.60%
# Epoch 31: Train Loss=0.7948, Train Acc=70.09%, Val Loss=0.6218, Val Acc=75.61%
# Epoch 32: Train Loss=0.8271, Train Acc=68.37%, Val Loss=0.6213, Val Acc=78.82%
# Epoch 33: Train Loss=0.8038, Train Acc=70.62%, Val Loss=0.5965, Val Acc=79.08%
# Epoch 34: Train Loss=0.7930, Train Acc=70.94%, Val Loss=0.5946, Val Acc=78.99%
# Epoch 35: Train Loss=0.8003, Train Acc=70.79%, Val Loss=0.5993, Val Acc=79.77%
# Epoch 36: Train Loss=0.8017, Train Acc=70.24%, Val Loss=0.6025, Val Acc=80.47%
# Epoch 37: Train Loss=0.7740, Train Acc=72.34%, Val Loss=0.5986, Val Acc=80.90%
# Epoch 38: Train Loss=0.7612, Train Acc=72.39%, Val Loss=0.5723, Val Acc=79.95%
# Epoch 39: Train Loss=0.7754, Train Acc=70.88%, Val Loss=0.5766, Val Acc=79.43%
# Epoch 40: Train Loss=0.7689, Train Acc=71.30%, Val Loss=0.5604, Val Acc=80.64%
# Epoch 41: Train Loss=0.7849, Train Acc=71.70%, Val Loss=0.5721, Val Acc=79.51%
# Epoch 42: Train Loss=0.7525, Train Acc=72.19%, Val Loss=0.5439, Val Acc=81.60%
# Epoch 43: Train Loss=0.7673, Train Acc=71.45%, Val Loss=0.5580, Val Acc=80.99%
# Epoch 44: Train Loss=0.7305, Train Acc=73.87%, Val Loss=0.5592, Val Acc=82.29%
# Epoch 45: Train Loss=0.7525, Train Acc=73.30%, Val Loss=0.5527, Val Acc=81.34%
# Epoch 46: Train Loss=0.7379, Train Acc=72.56%, Val Loss=0.5542, Val Acc=79.08%
# Epoch 47: Train Loss=0.7239, Train Acc=73.26%, Val Loss=0.5497, Val Acc=81.42%
# Epoch 48: Train Loss=0.7345, Train Acc=72.60%, Val Loss=0.5387, Val Acc=80.99%
# Epoch 49: Train Loss=0.7259, Train Acc=73.13%, Val Loss=0.5428, Val Acc=81.08%
# Epoch 50: Train Loss=0.7456, Train Acc=72.87%, Val Loss=0.5368, Val Acc=82.20%
# Fold 4
# Epoch 1: Train Loss=1.5180, Train Acc=39.60%, Val Loss=1.2715, Val Acc=55.82%
# Epoch 2: Train Loss=1.3224, Train Acc=50.02%, Val Loss=1.1730, Val Acc=57.03%
# Epoch 3: Train Loss=1.2411, Train Acc=52.70%, Val Loss=1.1152, Val Acc=59.03%
# Epoch 4: Train Loss=1.2091, Train Acc=53.27%, Val Loss=1.0776, Val Acc=59.64%
# Epoch 5: Train Loss=1.1685, Train Acc=55.10%, Val Loss=1.0431, Val Acc=60.24%
# Epoch 6: Train Loss=1.1314, Train Acc=55.95%, Val Loss=1.0106, Val Acc=61.63%
# Epoch 7: Train Loss=1.1237, Train Acc=56.08%, Val Loss=0.9810, Val Acc=63.80%
# Epoch 8: Train Loss=1.0931, Train Acc=58.14%, Val Loss=0.9557, Val Acc=65.02%
# Epoch 9: Train Loss=1.0669, Train Acc=59.52%, Val Loss=0.9422, Val Acc=65.71%
# Epoch 10: Train Loss=1.0689, Train Acc=58.38%, Val Loss=0.9272, Val Acc=65.28%
# Epoch 11: Train Loss=1.0396, Train Acc=59.63%, Val Loss=0.8942, Val Acc=66.49%
# Epoch 12: Train Loss=1.0253, Train Acc=60.50%, Val Loss=0.8807, Val Acc=66.32%
# Epoch 13: Train Loss=1.0229, Train Acc=59.97%, Val Loss=0.8641, Val Acc=66.67%
# Epoch 14: Train Loss=0.9774, Train Acc=62.84%, Val Loss=0.8298, Val Acc=68.06%
# Epoch 15: Train Loss=0.9796, Train Acc=61.95%, Val Loss=0.8283, Val Acc=67.27%
# Epoch 16: Train Loss=0.9757, Train Acc=62.10%, Val Loss=0.8278, Val Acc=68.92%
# Epoch 17: Train Loss=0.9668, Train Acc=63.20%, Val Loss=0.7963, Val Acc=69.53%
# Epoch 18: Train Loss=0.9625, Train Acc=62.69%, Val Loss=0.7907, Val Acc=69.18%
# Epoch 19: Train Loss=0.9607, Train Acc=63.80%, Val Loss=0.8079, Val Acc=68.40%
# Epoch 20: Train Loss=0.9449, Train Acc=64.54%, Val Loss=0.7664, Val Acc=70.40%
# Epoch 21: Train Loss=0.9222, Train Acc=65.07%, Val Loss=0.7834, Val Acc=69.88%
# Epoch 22: Train Loss=0.9004, Train Acc=65.88%, Val Loss=0.7509, Val Acc=71.27%
# Epoch 23: Train Loss=0.8876, Train Acc=66.14%, Val Loss=0.7609, Val Acc=72.66%
# Epoch 24: Train Loss=0.8896, Train Acc=66.77%, Val Loss=0.7428, Val Acc=72.83%
# Epoch 25: Train Loss=0.8855, Train Acc=66.18%, Val Loss=0.7296, Val Acc=73.26%
# Epoch 26: Train Loss=0.8750, Train Acc=67.35%, Val Loss=0.7224, Val Acc=72.14%
# Epoch 27: Train Loss=0.8741, Train Acc=67.64%, Val Loss=0.7142, Val Acc=72.74%
# Epoch 28: Train Loss=0.8625, Train Acc=67.03%, Val Loss=0.7111, Val Acc=73.35%
# Epoch 29: Train Loss=0.8575, Train Acc=67.71%, Val Loss=0.6984, Val Acc=73.18%
# Epoch 30: Train Loss=0.8453, Train Acc=68.60%, Val Loss=0.6958, Val Acc=75.00%
# Epoch 31: Train Loss=0.8667, Train Acc=67.52%, Val Loss=0.6984, Val Acc=76.30%
# Epoch 32: Train Loss=0.8380, Train Acc=68.77%, Val Loss=0.6661, Val Acc=74.48%
# Epoch 33: Train Loss=0.8147, Train Acc=69.60%, Val Loss=0.6582, Val Acc=74.74%
# Epoch 34: Train Loss=0.8358, Train Acc=68.45%, Val Loss=0.6656, Val Acc=75.00%
# Epoch 35: Train Loss=0.8121, Train Acc=69.94%, Val Loss=0.6612, Val Acc=77.95%
# Epoch 36: Train Loss=0.8115, Train Acc=69.79%, Val Loss=0.6712, Val Acc=77.52%
# Epoch 37: Train Loss=0.7789, Train Acc=71.07%, Val Loss=0.6410, Val Acc=76.91%
# Epoch 38: Train Loss=0.7993, Train Acc=70.03%, Val Loss=0.6436, Val Acc=76.91%
# Epoch 39: Train Loss=0.7957, Train Acc=70.73%, Val Loss=0.6507, Val Acc=77.17%
# Epoch 40: Train Loss=0.7989, Train Acc=69.98%, Val Loss=0.6424, Val Acc=75.87%
# Epoch 41: Train Loss=0.7696, Train Acc=70.77%, Val Loss=0.6222, Val Acc=76.91%
# Epoch 42: Train Loss=0.7877, Train Acc=70.62%, Val Loss=0.6409, Val Acc=76.91%
# Epoch 43: Train Loss=0.7854, Train Acc=71.75%, Val Loss=0.6209, Val Acc=77.34%
# Epoch 44: Train Loss=0.7582, Train Acc=72.34%, Val Loss=0.6116, Val Acc=77.52%
# Epoch 45: Train Loss=0.7711, Train Acc=71.68%, Val Loss=0.6227, Val Acc=77.52%
# Epoch 46: Train Loss=0.7386, Train Acc=71.81%, Val Loss=0.6085, Val Acc=78.04%
# Epoch 47: Train Loss=0.7532, Train Acc=71.32%, Val Loss=0.6124, Val Acc=78.12%
# Epoch 48: Train Loss=0.7782, Train Acc=72.41%, Val Loss=0.6275, Val Acc=76.56%
# Epoch 49: Train Loss=0.7402, Train Acc=73.43%, Val Loss=0.6101, Val Acc=78.39%
# Epoch 50: Train Loss=0.7590, Train Acc=72.68%, Val Loss=0.5977, Val Acc=77.95%
# Fold 5
# Epoch 1: Train Loss=1.4583, Train Acc=45.37%, Val Loss=1.2450, Val Acc=54.77%
# Epoch 2: Train Loss=1.2902, Train Acc=51.64%, Val Loss=1.1558, Val Acc=56.60%
# Epoch 3: Train Loss=1.2215, Train Acc=53.87%, Val Loss=1.0995, Val Acc=57.99%
# Epoch 4: Train Loss=1.1715, Train Acc=54.89%, Val Loss=1.0672, Val Acc=59.72%
# Epoch 5: Train Loss=1.1514, Train Acc=55.53%, Val Loss=1.0403, Val Acc=60.59%
# Epoch 6: Train Loss=1.1326, Train Acc=55.38%, Val Loss=1.0008, Val Acc=60.76%
# Epoch 7: Train Loss=1.1176, Train Acc=56.76%, Val Loss=0.9796, Val Acc=61.11%
# Epoch 8: Train Loss=1.0960, Train Acc=57.23%, Val Loss=0.9522, Val Acc=61.46%
# Epoch 9: Train Loss=1.0570, Train Acc=57.84%, Val Loss=0.9374, Val Acc=61.63%
# Epoch 10: Train Loss=1.0542, Train Acc=58.12%, Val Loss=0.8979, Val Acc=62.15%
# Epoch 11: Train Loss=1.0191, Train Acc=59.72%, Val Loss=0.8712, Val Acc=63.28%
# Epoch 12: Train Loss=1.0115, Train Acc=60.67%, Val Loss=0.8741, Val Acc=63.37%
# Epoch 13: Train Loss=0.9902, Train Acc=60.67%, Val Loss=0.8447, Val Acc=66.49%
# Epoch 14: Train Loss=0.9943, Train Acc=60.29%, Val Loss=0.8183, Val Acc=66.49%
# Epoch 15: Train Loss=0.9630, Train Acc=61.95%, Val Loss=0.8164, Val Acc=68.14%
# Epoch 16: Train Loss=0.9345, Train Acc=62.48%, Val Loss=0.7704, Val Acc=67.27%
# Epoch 17: Train Loss=0.9456, Train Acc=63.22%, Val Loss=0.7827, Val Acc=69.79%
# Epoch 18: Train Loss=0.9084, Train Acc=64.41%, Val Loss=0.7541, Val Acc=69.62%
# Epoch 19: Train Loss=0.9080, Train Acc=64.37%, Val Loss=0.7510, Val Acc=69.97%
# Epoch 20: Train Loss=0.8915, Train Acc=65.77%, Val Loss=0.7332, Val Acc=70.23%
# Epoch 21: Train Loss=0.9040, Train Acc=66.09%, Val Loss=0.7220, Val Acc=72.22%
# Epoch 22: Train Loss=0.8683, Train Acc=66.26%, Val Loss=0.7295, Val Acc=72.57%
# Epoch 23: Train Loss=0.8814, Train Acc=66.48%, Val Loss=0.6989, Val Acc=72.40%
# Epoch 24: Train Loss=0.8591, Train Acc=67.92%, Val Loss=0.7063, Val Acc=71.35%
# Epoch 25: Train Loss=0.8757, Train Acc=66.65%, Val Loss=0.6833, Val Acc=73.18%
# Epoch 26: Train Loss=0.8510, Train Acc=68.05%, Val Loss=0.6723, Val Acc=73.61%
# Epoch 27: Train Loss=0.8238, Train Acc=69.07%, Val Loss=0.6573, Val Acc=74.39%
# Epoch 28: Train Loss=0.8367, Train Acc=69.01%, Val Loss=0.6554, Val Acc=74.65%
# Epoch 29: Train Loss=0.8194, Train Acc=68.92%, Val Loss=0.6530, Val Acc=76.91%
# Epoch 30: Train Loss=0.8262, Train Acc=69.64%, Val Loss=0.6364, Val Acc=75.09%
# Epoch 31: Train Loss=0.8153, Train Acc=69.92%, Val Loss=0.6288, Val Acc=77.95%
# Epoch 32: Train Loss=0.8304, Train Acc=69.15%, Val Loss=0.6325, Val Acc=76.65%
# Epoch 33: Train Loss=0.7983, Train Acc=70.45%, Val Loss=0.6225, Val Acc=76.30%
# Epoch 34: Train Loss=0.8002, Train Acc=70.34%, Val Loss=0.6233, Val Acc=77.78%
# Epoch 35: Train Loss=0.7867, Train Acc=71.11%, Val Loss=0.6076, Val Acc=77.43%
# Epoch 36: Train Loss=0.7879, Train Acc=70.41%, Val Loss=0.5999, Val Acc=77.26%
# Epoch 37: Train Loss=0.7634, Train Acc=70.98%, Val Loss=0.6066, Val Acc=78.39%
# Epoch 38: Train Loss=0.7800, Train Acc=70.56%, Val Loss=0.6046, Val Acc=76.04%
# Epoch 39: Train Loss=0.7819, Train Acc=70.66%, Val Loss=0.5970, Val Acc=79.95%
# Epoch 40: Train Loss=0.7550, Train Acc=71.51%, Val Loss=0.5895, Val Acc=78.21%
# Epoch 41: Train Loss=0.7721, Train Acc=71.26%, Val Loss=0.6101, Val Acc=78.99%
# Epoch 42: Train Loss=0.7508, Train Acc=72.64%, Val Loss=0.5995, Val Acc=77.43%
# Epoch 43: Train Loss=0.7439, Train Acc=72.19%, Val Loss=0.5810, Val Acc=77.86%
# Epoch 44: Train Loss=0.7593, Train Acc=72.13%, Val Loss=0.5913, Val Acc=77.52%
# Epoch 45: Train Loss=0.7467, Train Acc=71.94%, Val Loss=0.5895, Val Acc=77.95%
# Epoch 46: Train Loss=0.7385, Train Acc=72.60%, Val Loss=0.5744, Val Acc=79.08%
# Epoch 47: Train Loss=0.7663, Train Acc=72.56%, Val Loss=0.5791, Val Acc=79.08%
# Epoch 48: Train Loss=0.7308, Train Acc=73.85%, Val Loss=0.5634, Val Acc=80.21%
# Epoch 49: Train Loss=0.7383, Train Acc=72.56%, Val Loss=0.5641, Val Acc=79.43%
# Epoch 50: Train Loss=0.7374, Train Acc=73.45%, Val Loss=0.5690, Val Acc=80.56%

# %%
# Plot Training and Validation Accuracy
plt.figure(figsize=(10, 4))  # Set figure size

# Plot accuracy curves for each fold
for i in range(k_folds):
    plt.plot(fold_train_accuracies[i], label=f'Train Fold {i+1}', linestyle='-')  # Solid line for training accuracy
    plt.plot(fold_val_accuracies[i], label=f'Val Fold {i+1}', linestyle='--')     # Dashed line for validation accuracy

# Configure plot appearance
plt.title('Training/Validation Accuracy per Fold')
plt.xlabel('Epoch')             # X-axis: epoch number
plt.ylabel('Accuracy')          # Y-axis: accuracy percentage
plt.legend()                    # Show legend to distinguish folds
plt.grid(True)                  # Add grid for readability
plt.tight_layout()              # Adjust layout to prevent clipping
plt.show()                      # Display the plot

# Plot Training and Validation Loss
plt.figure(figsize=(10, 4))  # Set figure size

# Plot loss curves for each fold
for i in range(k_folds):
    plt.plot(fold_train_losses[i], label=f'Train Fold {i+1}', linestyle='-')  # Solid line for training loss
    plt.plot(fold_val_losses[i], label=f'Val Fold {i+1}', linestyle='--')     # Dashed line for validation loss

# Configure plot appearance
plt.title('Training/Validation Loss per Fold')
plt.xlabel('Epoch')          # X-axis: epoch number
plt.ylabel('Loss')           # Y-axis: loss value
plt.legend()                 # Show legend to distinguish folds
plt.grid(True)               # Add grid for readability
plt.tight_layout()           # Adjust layout
plt.show()                   # Display the plot

# Calculate and print average validation accuracy across all folds
avg_val_acc = np.mean([accs[-1] for accs in fold_val_accuracies])
print(f"Average validation accuracy across folds: {avg_val_acc:.2f}%")
# Out:
# Average validation accuracy across folds: 79.58%

# %% [markdown]
# ## Retraining on Full Training Data
#
# Using the best performing fold, we are now training on the full data set. We're using the same parameters as before (50 epochs, Adam optimiser at learning rate 0.001 and weight decay 1e-4, batch size 32).

# %%
# Prepare full training dataset and dataloader
full_train_ds = MotionSense(X_train, Y_train)                      # Use entire training set
full_train_dl = DataLoader(full_train_ds, batch_size=32, shuffle=True)  # DataLoader for batching and shuffling

# Initialize the model
model = FCNet(input_size, hidden_size, num_classes)

# Load weights from the best-performing fold 
model.load_state_dict(best_model_state)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

# Retrain for a fixed number of epochs using the full dataset
for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0
    correct = 0
    total = 0

    # Iterate over batches
    for inputs, labels in full_train_dl:
        optimizer.zero_grad()                    # Reset gradients
        outputs = model(inputs.float())          # Forward pass
        loss = criterion(outputs, labels.long()) # Compute loss
        loss.backward()                          # Backpropagation
        optimizer.step()                         # Update model weights

        # Accumulate loss and accuracy
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Compute epoch-level loss and accuracy
    epoch_loss = running_loss / len(full_train_dl)
    epoch_acc = 100 * correct / total

    # Print training progress
    print(f"Retrain Epoch {epoch+1}: Loss = {epoch_loss:.4f}, Accuracy = {epoch_acc:.2f}%")
# Out:
# Retrain Epoch 1: Loss = 0.7334, Accuracy = 73.07%
# Retrain Epoch 2: Loss = 0.7546, Accuracy = 71.76%
# Retrain Epoch 3: Loss = 0.7702, Accuracy = 71.81%
# Retrain Epoch 4: Loss = 0.7319, Accuracy = 73.47%
# Retrain Epoch 5: Loss = 0.7118, Accuracy = 73.95%
# Retrain Epoch 6: Loss = 0.7173, Accuracy = 73.86%
# Retrain Epoch 7: Loss = 0.7227, Accuracy = 74.22%
# Retrain Epoch 8: Loss = 0.7208, Accuracy = 73.52%
# Retrain Epoch 9: Loss = 0.6960, Accuracy = 74.47%
# Retrain Epoch 10: Loss = 0.7290, Accuracy = 73.66%
# Retrain Epoch 11: Loss = 0.6987, Accuracy = 74.47%
# Retrain Epoch 12: Loss = 0.6896, Accuracy = 74.92%
# Retrain Epoch 13: Loss = 0.7251, Accuracy = 73.90%
# Retrain Epoch 14: Loss = 0.6940, Accuracy = 74.93%
# Retrain Epoch 15: Loss = 0.7011, Accuracy = 74.69%
# Retrain Epoch 16: Loss = 0.6872, Accuracy = 75.29%
# Retrain Epoch 17: Loss = 0.6996, Accuracy = 74.05%
# Retrain Epoch 18: Loss = 0.6996, Accuracy = 74.81%
# Retrain Epoch 19: Loss = 0.6873, Accuracy = 75.59%
# Retrain Epoch 20: Loss = 0.6814, Accuracy = 75.37%
# Retrain Epoch 21: Loss = 0.6788, Accuracy = 74.90%
# Retrain Epoch 22: Loss = 0.6643, Accuracy = 75.86%
# Retrain Epoch 23: Loss = 0.6750, Accuracy = 74.75%
# Retrain Epoch 24: Loss = 0.6652, Accuracy = 76.37%
# Retrain Epoch 25: Loss = 0.6694, Accuracy = 76.59%
# Retrain Epoch 26: Loss = 0.6647, Accuracy = 76.51%
# Retrain Epoch 27: Loss = 0.6643, Accuracy = 75.76%
# Retrain Epoch 28: Loss = 0.6644, Accuracy = 76.49%
# Retrain Epoch 29: Loss = 0.6741, Accuracy = 76.14%
# Retrain Epoch 30: Loss = 0.6753, Accuracy = 75.20%
# Retrain Epoch 31: Loss = 0.6631, Accuracy = 76.24%
# Retrain Epoch 32: Loss = 0.6748, Accuracy = 75.73%
# Retrain Epoch 33: Loss = 0.6628, Accuracy = 75.42%
# Retrain Epoch 34: Loss = 0.6559, Accuracy = 75.63%
# Retrain Epoch 35: Loss = 0.6654, Accuracy = 76.00%
# Retrain Epoch 36: Loss = 0.6574, Accuracy = 76.29%
# Retrain Epoch 37: Loss = 0.6655, Accuracy = 76.32%
# Retrain Epoch 38: Loss = 0.6611, Accuracy = 76.83%
# Retrain Epoch 39: Loss = 0.6592, Accuracy = 77.05%
# Retrain Epoch 40: Loss = 0.6758, Accuracy = 75.95%
# Retrain Epoch 41: Loss = 0.6553, Accuracy = 76.73%
# Retrain Epoch 42: Loss = 0.6475, Accuracy = 76.83%
# Retrain Epoch 43: Loss = 0.6630, Accuracy = 76.37%
# Retrain Epoch 44: Loss = 0.6376, Accuracy = 76.92%
# Retrain Epoch 45: Loss = 0.6315, Accuracy = 77.75%
# Retrain Epoch 46: Loss = 0.6399, Accuracy = 77.71%
# Retrain Epoch 47: Loss = 0.6404, Accuracy = 76.51%
# Retrain Epoch 48: Loss = 0.6576, Accuracy = 76.44%
# Retrain Epoch 49: Loss = 0.6630, Accuracy = 76.37%
# Retrain Epoch 50: Loss = 0.6614, Accuracy = 76.36%

# %% [markdown]
# ## Testing Time

# %%
# Prepare test dataset and DataLoader
test_ds = MotionSense(X_test, Y_test)                  # Create dataset from test features and labels
test_dl = DataLoader(test_ds, batch_size=32, shuffle=False)  # DataLoader without shuffling for evaluation

model.eval()   # Set model to evaluation mode (disables dropout, batchnorm updates)
all_preds = [] # To store predicted labels for all test samples
all_labels = [] # To store true labels for all test samples

# Disable gradient computation for faster inference and lower memory usage
with torch.no_grad():
    for inputs, labels in test_dl:
        outputs = model(inputs.float())               # Forward pass to get outputs/logits
        _, predicted = torch.max(outputs.data, 1)    # Get class with highest score as prediction
        all_preds.extend(predicted.cpu().numpy())    # Collect predictions on CPU as numpy array
        all_labels.extend(labels.cpu().numpy())      # Collect true labels

# Convert collected lists to numpy arrays for metric calculations
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Calculate overall test accuracy
test_acc = 100 * (all_preds == all_labels).sum() / len(all_labels)
print(f"Test Accuracy: {test_acc:.2f}%")

# Calculate additional performance metrics with weighted averaging for imbalanced classes
precision = precision_score(all_labels, all_preds, average='weighted')  # Precision metric
recall = recall_score(all_labels, all_preds, average='weighted')        # Recall metric
f1 = f1_score(all_labels, all_preds, average='weighted')                # F1 score metric
conf_matrix = confusion_matrix(all_labels, all_preds)                   # Confusion matrix

# Print the computed metrics
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)

# Print detailed classification report with per-class metrics
print("\nClassification Report:")
print(classification_report(all_labels, all_preds))
# Out:
# Test Accuracy: 83.88%
# Precision: 0.8544
# Recall: 0.8388
# F1 Score: 0.8391
# Confusion Matrix:
# [[ 89  13   1   2   3   0]
#  [ 45  70  10   5   1   0]
#  [  8  18 191  14  26   7]
#  [ 12   1   0  97   0   6]
#  [ 11   1   0   2 243   0]
#  [  2   0   0   0   0 288]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.82      0.65       108
#            1       0.68      0.53      0.60       131
#            2       0.95      0.72      0.82       264
#            3       0.81      0.84      0.82       116
#            4       0.89      0.95      0.92       257
#            5       0.96      0.99      0.97       290
#
#     accuracy                           0.84      1166
#    macro avg       0.80      0.81      0.80      1166
# weighted avg       0.85      0.84      0.84      1166

# %%
import seaborn as sns

# Set up the plot with a specific size for better readability
plt.figure(figsize=(8,6))

# Create a heatmap visualization of the confusion matrix using Seaborn
sns.heatmap(
    conf_matrix,            # Confusion matrix data to visualize
    annot=True,             # Annotate cells with numeric values
    fmt='d',                # Format annotations as integers
    cmap='Blues',           # Use a blue color palette for the heatmap
    xticklabels=['dws', 'ups', 'wlk', 'jog', 'std', 'sit'],  # Class labels for predicted axis
    yticklabels=['dws', 'ups', 'wlk', 'jog', 'std', 'sit']   # Class labels for true axis
)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
