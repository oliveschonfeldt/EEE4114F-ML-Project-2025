# %% [markdown]
# # EEE4114F ML Project Code
#
# The motionsense dataset is divided into three main folders:
#
# - **(A) DeviceMotion_data:** Contains a rich combination of accelerometer, gyroscope, and orientation-related features — 12 features in total.
#
# - **(B) Accelerometer_data:** Includes only the raw accelerometer readings (x, y, z) — 3 features.
#
# - **(C) Gyroscope_data:** Includes only the raw gyroscope readings (x, y, z) — 3 features.
#
#
# From these, **(A) DeviceMotion_data** provides the most comprehensive set of features, combining both linear and rotational data, as well as derived orientation estimates:
#
# - **Attitude (roll, pitch, yaw)** showing device orientation (e.g., facing up/down)
# - **Gravity (x, y, z)** showing static acceleration (orientation wrt gravity)
# - **Rotation Rate (x, y, z)** showing angular velocity from gyroscope
# - **User Acceleration (x, y, z)** showing motion (dynamic body acceleration)

# %% [markdown]
# ## Libraries to import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, TimeSeriesSplit, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %% [markdown]
# ## Loading the data
# Here are some useful functions from motionsense.ipyb we have copied. It helps to copy the data from (A) DeviceMotion_data as a labeled time series dataset.

# %%
def get_ds_infos():
    """
    Read the file includes data subject information.

    EEE4114: Technically we do not need these data, as we are not concerned about identifying the subjects. 
    
    Data Columns:
    0: code [1-24]
    1: weight [kg]
    2: height [cm]
    3: age [years]
    4: gender [0:Female, 1:Male]
    
    Returns:
        A pandas DataFrame that contains information about data subjects' attributes 
    """ 

    dss = pd.read_csv(f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/data_subjects_info.csv')
    print("[INFO] -- Data subjects' information is imported.")
    
    return dss

def set_data_types(data_types=["userAcceleration"]):
    """
    Select the sensors and the mode to shape the final dataset. 

    EEE4114F: Choose sensors that you think are useful or would like to include in training. 
    You can choose all of them, or you could opt to try a limited set of input features
    
    Args:
        data_types: A list of sensor data type from this list: [attitude, gravity, rotationRate, userAcceleration] 

    Returns:
        It returns a list of columns to use for creating time-series from files.
    """
    dt_list = []
    for t in data_types:
        if t != "attitude":
            dt_list.append([t+".x",t+".y",t+".z"])
        else:
            dt_list.append([t+".roll", t+".pitch", t+".yaw"])

    return dt_list


def create_time_series(dt_list, act_labels, trial_codes, mode="mag", labeled=True):
    """
    EEE4114F: This defines what data you would like to include for a given set.  

    Args:
        dt_list: A list of columns that shows the type of data we want.
        act_labels: list of activities.
        trial_codes: list of trial codes corresponding to each activity.
        mode: It can be "raw" (all dimensions of each data type) or "mag" (only magnitude per data type).
        labeled: True if labeled dataset (adds 'act', 'trial', 'sub_id'), False otherwise.

    Returns:
        pd.DataFrame: Time-series sensor data with optional labels.
    """
    num_data_cols = len(dt_list) if mode == "mag" else len(dt_list * 3)

    if labeled:
        # +3 for act, trial, sub_id labels
        dataset = np.zeros((0, num_data_cols + 3))
    else:
        dataset = np.zeros((0, num_data_cols))

    ds_list = get_ds_infos()  # Assume this returns dict with "code" key for subject IDs

    print("[INFO] -- Creating Time-Series")
    for sub_id in ds_list["code"]:
        for act_id, act in enumerate(act_labels):
            for trial in trial_codes[act_id]:
                fname = f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/A_DeviceMotion_data/{act}_{trial}/sub_{int(sub_id)}.csv'
                raw_data = pd.read_csv(fname)
                raw_data = raw_data.drop(['Unnamed: 0'], axis=1)
                vals = np.zeros((len(raw_data), num_data_cols))
                for x_id, axes in enumerate(dt_list):
                    if mode == "mag":
                        # Calculate magnitude of 3 axes per sensor type
                        vals[:, x_id] = (raw_data[axes] ** 2).sum(axis=1) ** 0.5        
                    else:
                        vals[:, x_id * 3:(x_id + 1) * 3] = raw_data[axes].values
                    vals = vals[:, :num_data_cols]
                if labeled:
                    # Add act, trial, sub_id as labels (same length as vals)
                    lbls = np.array([[act_id, trial, sub_id]] * len(raw_data))
                    vals = np.concatenate((vals, lbls), axis=1)
                dataset = np.append(dataset, vals, axis=0)

    cols = []
    for axes in dt_list:
        if mode == "raw":
            cols += axes
        else:
            cols += [str(axes[0][:-2])]  # Use first part of sensor name for magnitude

    if labeled:
        cols += ["act", "trial", "sub_id"]

    dataset = pd.DataFrame(data=dataset, columns=cols)
    return dataset

# %%
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}

## Here we set parameter to build labeled time-series from dataset of "(A)DeviceMotion_data"
## attitude(roll, pitch, yaw); gravity(x, y, z); rotationRate(x, y, z); userAcceleration(x,y,z)
sdt = ["attitude", "gravity", "rotationRate", "userAcceleration"]
print("[INFO] -- Selected sensor data types: "+str(sdt))    
act_labels = ACT_LABELS # choose all 6 classes
print("[INFO] -- Selected activites: "+str(act_labels))    
trial_codes = [TRIAL_CODES[act] for act in act_labels]
dt_list = set_data_types(sdt)
dataset = create_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
print("[INFO] -- Shape of time-Series dataset:"+str(dataset.shape))    
dataset.head()
# Out:
# [INFO] -- Selected sensor data types: ['attitude', 'gravity', 'rotationRate', 'userAcceleration']
# [INFO] -- Selected activites: ['dws', 'ups', 'wlk', 'jog', 'std', 'sit']
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series
# [INFO] -- Shape of time-Series dataset:(1412865, 15)
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z  act  trial  \
# 0            0.294894           -0.184493            0.377542  0.0    1.0
# 1            0.219405            0.035846            0.114866  0.0    1.0
# 2            0.010714            0.134701           -0.167808  0.0    1.0
# 3           -0.008389            0.136788            0.094958  0.0    1.0
# 4            0.199441            0.353996           -0.044299  0.0    1.0
#
#    sub_id
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %% [markdown]
# ## Windowing and Splitting the Data
#
# Uses more useful definitions from motionsense.ipyb - the windows() function and MotionSense class.

# %%
def windows(dataset, window_size=400, stride=200):
    """
    Slice dataset into overlapping windows of fixed length.

    Args:
        dataset (pd.DataFrame): Time-series data with sensor features and 'act' label column.
        window_size (int): Number of samples per window.
        stride (int): Step size between windows.

    Returns:
        pd.DataFrame: A new DataFrame with flattened windows and corresponding labels.
    """

    # Separate the feature values and labels
    features = dataset.drop(columns=['act']).values  # Shape: [n_samples, n_features]
    labels = dataset['act'].values  # Shape: [n_samples]

    # Lists to collect the processed windows and labels
    windowed_data = []
    windowed_labels = []

    # Iterate over the dataset with a sliding window
    for start in range(0, len(dataset) - window_size + 1, stride):
        end = start + window_size

        # Extract a window of features and corresponding labels
        window = features[start:end]           # Shape: [window_size, n_features]
        label_window = labels[start:end]       # Shape: [window_size]

        # Flatten the feature window by transposing to [n_features, window_size], then flatten to 1D
        window_flat = window.T.flatten()       # Final shape: [n_features * window_size]

        # Assign the most frequent label in the window as the representative label
        label = np.bincount(label_window.astype(int)).argmax()

        # Append the flattened window and label to the lists
        windowed_data.append(window_flat)
        windowed_labels.append(label)

    # Convert the list of windows to a DataFrame (each row is one flattened window)
    X = pd.DataFrame(windowed_data)

    # Convert the list of labels to a Series
    Y = pd.Series(windowed_labels, name='act')

    return X, Y

# %%
class MotionSense(Dataset):
    def __init__(self, X, Y, transform=None):
        self.X = torch.tensor(X.values)
        self.Y = torch.tensor(Y.values)
        self.transform = transform

    def __getitem__(self, index):
        if torch.is_tensor(index):
            index = int(index.item())

        x = self.X[index]
        y = self.Y[index]

        return x, y

    def __len__(self):
        return len(self.X)

# %% [markdown]
# #### Chose to randomly split data 85% for training and 15% for testing, and to do it subject-wise to avoid data leakage across subjects.
#
# #### Knowing that the minimum recording length is 377, we chose a window size of 400.
#
# #### We chose a stride of 200, 50% of the window size.

# %%
# Split subjects for train/test
unique_sub_ids = dataset['sub_id'].unique()  # Get list of unique subject IDs
train_subs, test_subs = train_test_split(unique_sub_ids, test_size=0.15, random_state=852963)  
# Randomly split subjects: 85% for training, 15% for testing (subject-wise split ensures no data leakage across subjects)

train_df = dataset[dataset['sub_id'].isin(train_subs)].reset_index(drop=True)  # Extract training data from selected subjects
test_df = dataset[dataset['sub_id'].isin(test_subs)].reset_index(drop=True)    # Extract test data from held-out subjects

# Select only sensor features (exclude meta-info like 'sub_id') and the activity label
feature_cols = [
    'attitude.roll', 'attitude.pitch', 'attitude.yaw',
    'gravity.x', 'gravity.y', 'gravity.z','rotationRate.x', 
    'rotationRate.y', 'rotationRate.z', 'userAcceleration.x', 
    'userAcceleration.y', 'userAcceleration.z'
]# 
filtered_train_df = train_df[feature_cols + ['act']]  # Retain only sensor features + label for training
filtered_test_df = test_df[feature_cols + ['act']]    # Same for test data

# Apply windowing to create overlapping segments of fixed length from continuous data
X_train, Y_train = windows(filtered_train_df, window_size=400, stride=200)
X_test, Y_test = windows(filtered_test_df, window_size=400, stride=200)
# Result: X_* are DataFrames of flattened windows, Y_* are Series of majority labels per window

# %% [markdown]
# ## K-Fold Cross-Validation
# K-Fold Cross-Validation is a technique to evaluate model performance by splitting the dataset into *k* equal parts (folds).
# - The dataset is split into **5 folds**.
# - For each of the 5 iterations:
#   - **4 folds are used for training**, and
#   - **1 fold is used for validation**.
# - Each fold serves as the validation set exactly once.
# - After all iterations, performance metrics are averaged to give a robust estimate of model generalization.
# This method ensures that every data point is used for both training and validation, helping to reduce overfitting and improve reliability.

# %%
k_folds = 5  # Define number of folds for cross-validation

# Initialize KFold cross-validator (shuffling ensures different class distributions across folds)
kf = KFold(n_splits=5, shuffle=True, random_state=7419954)
all_splits = list(kf.split(X_train))  # Create list of (train_idx, val_idx) splits for each fold

# %% [markdown]
# ## Define Model Architecture - FCNet
#
# Due to the ease of implementation and interpretability (and since it was included in the motionsense.ipyb), we have decided to explore the FCNet architecture as the model architecture for classifying.
#
# The main parameters here is the input size (12 features * 400 time steps), the size of the hidden layer, and the total number of activity classes to clasify (which we all know is 6).
#
# The 4800 features became 50 then became 6 features, and to improve learning stability and generalisation, we also applied batch normalisation, ReLU activation and dropout (rate 0.5).

# %%
# Define the improved fully connected neural network for time-series classification
class FCNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FCNet, self).__init__()

        # First fully connected layer: input -> hidden_size
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)      # Batch normalization to stabilize learning
        self.dropout1 = nn.Dropout(0.5)             # Dropout to prevent overfitting

        # Second fully connected layer: hidden_size -> hidden_size // 2
        self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
        self.bn2 = nn.BatchNorm1d(hidden_size // 2) # Batch normalization
        self.dropout2 = nn.Dropout(0.5)             # Dropout again for regularization

        # Final layer: hidden_size // 2 -> number of classes
        self.fc3 = nn.Linear(hidden_size // 2, num_classes)

        self.relu = nn.ReLU()  # Activation function

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input from [batch, channels, time] to [batch, features]

        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.dropout2(x)

        x = self.fc3(x)  # Final output layer (no activation here; loss function will handle it)
        return x

# Parameters — adjusted according to our input window configuration
input_size = 12 * 400     # 12 sensor features per timestep × 400 time steps per window
hidden_size = 100          # Size of hidden layer (can be tuned)
num_classes = 6           # Total number of activity classes to classify

# %% [markdown]
# ## Model Training and Evaluation
#
# Here we train for 50 epochs. This was enough epochs for convergence whilst not under- or overfitting.
#
# We also use the Adam optimiser (better than standard gradient descent!) at a learning rate of 0.001.
#
# During the training, we track the training and validation losses and accuracies, as well as the best accuracy and the corresponding model for subsequent training.

# %%
num_epochs = 50  # Number of epochs to train per fold

# Track the best performing model across all folds
best_val_acc = 0
best_model_state = None

# Lists to store metrics for each fold
fold_train_losses = [[] for _ in range(k_folds)]
fold_val_losses = [[] for _ in range(k_folds)]
fold_train_accuracies = [[] for _ in range(k_folds)]
fold_val_accuracies = [[] for _ in range(k_folds)]

# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(all_splits):
    print(f"Fold {fold + 1}")

    # Prepare train and validation splits
    X_tr = X_train.iloc[train_idx].reset_index(drop=True)
    Y_tr = Y_train.iloc[train_idx].reset_index(drop=True)
    X_val = X_train.iloc[val_idx].reset_index(drop=True)
    Y_val = Y_train.iloc[val_idx].reset_index(drop=True)

    # Wrap data into custom dataset class
    train_ds = MotionSense(X_tr, Y_tr)
    val_ds = MotionSense(X_val, Y_val)

    # Create DataLoaders
    train_dl = DataLoader(train_ds, batch_size=32, shuffle=True, drop_last=True)
    val_dl = DataLoader(val_ds, batch_size=32, shuffle=False, drop_last=True)

    # Initialize model, loss function, and optimizer
    model = FCNet(input_size, hidden_size, num_classes)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

    # Train for the specified number of epochs
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        running_loss = 0
        correct = 0
        total = 0

        # Training loop
        for inputs, labels in train_dl:
            optimizer.zero_grad()                 # Clear previous gradients
            outputs = model(inputs.float())       # Forward pass
            loss = criterion(outputs, labels.long())  # Compute loss
            loss.backward()                       # Backward pass
            optimizer.step()                      # Update weights

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_dl)
        train_acc = 100 * correct / total

        # Store metrics for this epoch
        fold_train_losses[fold].append(train_loss)
        fold_train_accuracies[fold].append(train_acc)

        # Validation loop
        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels in val_dl:
                outputs = model(inputs.float())         # Forward pass
                loss = criterion(outputs, labels)       # Compute validation loss
                val_loss += loss.item() * inputs.size(0)  # Accumulate total loss

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        avg_val_loss = val_loss / val_total
        val_acc = 100 * val_correct / val_total

        # Log metrics
        print(f"Epoch {epoch+1}: Train Loss={train_loss:.4f}, Train Acc={train_acc:.2f}%, "
              f"Val Loss={avg_val_loss:.4f}, Val Acc={val_acc:.2f}%")

        fold_val_losses[fold].append(avg_val_loss)
        fold_val_accuracies[fold].append(val_acc)

    # Track the best-performing model based on final validation accuracy
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model_state = model.state_dict()  # Save best model parameters
# Out:
# Fold 1
# Epoch 1: Train Loss=1.3113, Train Acc=53.23%, Val Loss=0.9380, Val Acc=71.88%
# Epoch 2: Train Loss=0.8788, Train Acc=71.79%, Val Loss=0.5671, Val Acc=86.89%
# Epoch 3: Train Loss=0.6571, Train Acc=80.48%, Val Loss=0.3955, Val Acc=90.28%
# Epoch 4: Train Loss=0.5346, Train Acc=84.42%, Val Loss=0.3375, Val Acc=91.75%
# Epoch 5: Train Loss=0.4528, Train Acc=87.01%, Val Loss=0.3481, Val Acc=90.80%
# Epoch 6: Train Loss=0.4031, Train Acc=88.27%, Val Loss=0.2930, Val Acc=91.67%
# Epoch 7: Train Loss=0.3549, Train Acc=89.92%, Val Loss=0.2464, Val Acc=93.14%
# Epoch 8: Train Loss=0.3444, Train Acc=90.05%, Val Loss=0.2558, Val Acc=92.62%
# Epoch 9: Train Loss=0.3193, Train Acc=90.99%, Val Loss=0.2568, Val Acc=92.53%
# Epoch 10: Train Loss=0.3065, Train Acc=91.12%, Val Loss=0.2407, Val Acc=93.14%
# Epoch 11: Train Loss=0.2759, Train Acc=91.95%, Val Loss=0.2393, Val Acc=92.97%
# Epoch 12: Train Loss=0.2630, Train Acc=92.44%, Val Loss=0.2320, Val Acc=93.23%
# Epoch 13: Train Loss=0.2548, Train Acc=92.83%, Val Loss=0.2477, Val Acc=92.97%
# Epoch 14: Train Loss=0.2388, Train Acc=92.77%, Val Loss=0.2286, Val Acc=92.88%
# Epoch 15: Train Loss=0.2308, Train Acc=93.15%, Val Loss=0.2174, Val Acc=94.18%
# Epoch 16: Train Loss=0.2277, Train Acc=93.30%, Val Loss=0.2113, Val Acc=93.66%
# Epoch 17: Train Loss=0.2054, Train Acc=93.77%, Val Loss=0.2428, Val Acc=93.49%
# Epoch 18: Train Loss=0.2070, Train Acc=93.58%, Val Loss=0.2424, Val Acc=93.06%
# Epoch 19: Train Loss=0.2009, Train Acc=93.77%, Val Loss=0.2198, Val Acc=94.10%
# Epoch 20: Train Loss=0.1955, Train Acc=94.37%, Val Loss=0.2218, Val Acc=93.84%
# Epoch 21: Train Loss=0.2074, Train Acc=93.77%, Val Loss=0.2285, Val Acc=93.66%
# Epoch 22: Train Loss=0.2019, Train Acc=93.99%, Val Loss=0.2274, Val Acc=93.40%
# Epoch 23: Train Loss=0.1854, Train Acc=94.52%, Val Loss=0.2409, Val Acc=93.49%
# Epoch 24: Train Loss=0.1855, Train Acc=94.35%, Val Loss=0.2254, Val Acc=94.18%
# Epoch 25: Train Loss=0.1813, Train Acc=94.50%, Val Loss=0.2187, Val Acc=93.84%
# Epoch 26: Train Loss=0.1843, Train Acc=94.76%, Val Loss=0.2221, Val Acc=93.84%
# Epoch 27: Train Loss=0.1749, Train Acc=95.08%, Val Loss=0.2321, Val Acc=93.58%
# Epoch 28: Train Loss=0.1669, Train Acc=95.06%, Val Loss=0.2339, Val Acc=93.75%
# Epoch 29: Train Loss=0.1617, Train Acc=95.14%, Val Loss=0.2200, Val Acc=94.36%
# Epoch 30: Train Loss=0.1499, Train Acc=95.55%, Val Loss=0.2236, Val Acc=94.27%
# Epoch 31: Train Loss=0.1408, Train Acc=95.85%, Val Loss=0.2254, Val Acc=93.66%
# Epoch 32: Train Loss=0.1422, Train Acc=95.70%, Val Loss=0.2075, Val Acc=94.44%
# Epoch 33: Train Loss=0.1465, Train Acc=95.63%, Val Loss=0.2110, Val Acc=94.27%
# Epoch 34: Train Loss=0.1469, Train Acc=95.74%, Val Loss=0.2163, Val Acc=94.27%
# Epoch 35: Train Loss=0.1489, Train Acc=95.78%, Val Loss=0.2180, Val Acc=94.27%
# Epoch 36: Train Loss=0.1539, Train Acc=95.59%, Val Loss=0.2201, Val Acc=94.53%
# Epoch 37: Train Loss=0.1603, Train Acc=95.18%, Val Loss=0.2329, Val Acc=93.75%
# Epoch 38: Train Loss=0.1320, Train Acc=95.95%, Val Loss=0.2130, Val Acc=94.18%
# Epoch 39: Train Loss=0.1311, Train Acc=96.23%, Val Loss=0.2080, Val Acc=94.53%
# Epoch 40: Train Loss=0.1323, Train Acc=95.91%, Val Loss=0.2148, Val Acc=94.44%
# Epoch 41: Train Loss=0.1254, Train Acc=96.00%, Val Loss=0.2167, Val Acc=94.44%
# Epoch 42: Train Loss=0.1536, Train Acc=95.38%, Val Loss=0.2199, Val Acc=94.62%
# Epoch 43: Train Loss=0.1303, Train Acc=95.91%, Val Loss=0.2481, Val Acc=93.75%
# Epoch 44: Train Loss=0.1230, Train Acc=96.28%, Val Loss=0.2170, Val Acc=94.62%
# Epoch 45: Train Loss=0.1256, Train Acc=96.13%, Val Loss=0.2119, Val Acc=94.97%
# Epoch 46: Train Loss=0.1271, Train Acc=95.98%, Val Loss=0.2236, Val Acc=94.79%
# Epoch 47: Train Loss=0.1121, Train Acc=96.64%, Val Loss=0.2373, Val Acc=94.01%
# Epoch 48: Train Loss=0.1184, Train Acc=96.38%, Val Loss=0.2231, Val Acc=94.62%
# Epoch 49: Train Loss=0.1212, Train Acc=96.08%, Val Loss=0.2442, Val Acc=94.01%
# Epoch 50: Train Loss=0.1193, Train Acc=96.49%, Val Loss=0.2345, Val Acc=94.36%
# Fold 2
# Epoch 1: Train Loss=1.3202, Train Acc=50.88%, Val Loss=0.9501, Val Acc=70.75%
# Epoch 2: Train Loss=0.9303, Train Acc=68.99%, Val Loss=0.5826, Val Acc=88.37%
# Epoch 3: Train Loss=0.6801, Train Acc=79.26%, Val Loss=0.4132, Val Acc=89.93%
# Epoch 4: Train Loss=0.5436, Train Acc=84.25%, Val Loss=0.3387, Val Acc=91.75%
# Epoch 5: Train Loss=0.4739, Train Acc=85.87%, Val Loss=0.2940, Val Acc=92.36%
# Epoch 6: Train Loss=0.4327, Train Acc=86.92%, Val Loss=0.2800, Val Acc=92.71%
# Epoch 7: Train Loss=0.3693, Train Acc=89.30%, Val Loss=0.2629, Val Acc=93.23%
# Epoch 8: Train Loss=0.3584, Train Acc=89.49%, Val Loss=0.2408, Val Acc=93.40%
# Epoch 9: Train Loss=0.3134, Train Acc=90.56%, Val Loss=0.2442, Val Acc=93.32%
# Epoch 10: Train Loss=0.3204, Train Acc=90.67%, Val Loss=0.2586, Val Acc=92.97%
# Epoch 11: Train Loss=0.2871, Train Acc=91.22%, Val Loss=0.2556, Val Acc=92.80%
# Epoch 12: Train Loss=0.2542, Train Acc=92.74%, Val Loss=0.2382, Val Acc=93.49%
# Epoch 13: Train Loss=0.2549, Train Acc=92.10%, Val Loss=0.2249, Val Acc=94.36%
# Epoch 14: Train Loss=0.2495, Train Acc=92.94%, Val Loss=0.2093, Val Acc=95.14%
# Epoch 15: Train Loss=0.2417, Train Acc=92.94%, Val Loss=0.2380, Val Acc=94.18%
# Epoch 16: Train Loss=0.2192, Train Acc=93.24%, Val Loss=0.2233, Val Acc=94.36%
# Epoch 17: Train Loss=0.2099, Train Acc=93.54%, Val Loss=0.3882, Val Acc=90.45%
# Epoch 18: Train Loss=0.2141, Train Acc=93.75%, Val Loss=0.2456, Val Acc=94.10%
# Epoch 19: Train Loss=0.1984, Train Acc=94.07%, Val Loss=0.2224, Val Acc=95.23%
# Epoch 20: Train Loss=0.1883, Train Acc=94.35%, Val Loss=0.2172, Val Acc=94.79%
# Epoch 21: Train Loss=0.1811, Train Acc=94.88%, Val Loss=0.2205, Val Acc=94.36%
# Epoch 22: Train Loss=0.1942, Train Acc=93.99%, Val Loss=0.2230, Val Acc=94.53%
# Epoch 23: Train Loss=0.1779, Train Acc=94.37%, Val Loss=0.2223, Val Acc=94.97%
# Epoch 24: Train Loss=0.1744, Train Acc=94.67%, Val Loss=0.2257, Val Acc=94.97%
# Epoch 25: Train Loss=0.1769, Train Acc=94.93%, Val Loss=0.2343, Val Acc=94.62%
# Epoch 26: Train Loss=0.1780, Train Acc=94.67%, Val Loss=0.2138, Val Acc=95.05%
# Epoch 27: Train Loss=0.1728, Train Acc=94.95%, Val Loss=0.2400, Val Acc=94.53%
# Epoch 28: Train Loss=0.1822, Train Acc=94.52%, Val Loss=0.2196, Val Acc=95.23%
# Epoch 29: Train Loss=0.1638, Train Acc=95.16%, Val Loss=0.2267, Val Acc=95.14%
# Epoch 30: Train Loss=0.1527, Train Acc=95.53%, Val Loss=0.2274, Val Acc=95.31%
# Epoch 31: Train Loss=0.1721, Train Acc=94.67%, Val Loss=0.2234, Val Acc=95.49%
# Epoch 32: Train Loss=0.1510, Train Acc=95.48%, Val Loss=0.2214, Val Acc=95.14%
# Epoch 33: Train Loss=0.1538, Train Acc=95.48%, Val Loss=0.2391, Val Acc=95.05%
# Epoch 34: Train Loss=0.1543, Train Acc=95.23%, Val Loss=0.2388, Val Acc=94.97%
# Epoch 35: Train Loss=0.1344, Train Acc=96.32%, Val Loss=0.2433, Val Acc=94.97%
# Epoch 36: Train Loss=0.1651, Train Acc=94.67%, Val Loss=0.2326, Val Acc=95.40%
# Epoch 37: Train Loss=0.1284, Train Acc=96.19%, Val Loss=0.2185, Val Acc=95.66%
# Epoch 38: Train Loss=0.1351, Train Acc=95.78%, Val Loss=0.2316, Val Acc=95.40%
# Epoch 39: Train Loss=0.1384, Train Acc=95.89%, Val Loss=0.2397, Val Acc=95.23%
# Epoch 40: Train Loss=0.1454, Train Acc=95.48%, Val Loss=0.2527, Val Acc=95.23%
# Epoch 41: Train Loss=0.1354, Train Acc=95.89%, Val Loss=0.2535, Val Acc=94.88%
# Epoch 42: Train Loss=0.1291, Train Acc=95.95%, Val Loss=0.2402, Val Acc=95.40%
# Epoch 43: Train Loss=0.1377, Train Acc=95.76%, Val Loss=0.2375, Val Acc=95.31%
# Epoch 44: Train Loss=0.1528, Train Acc=94.95%, Val Loss=0.2581, Val Acc=95.31%
# Epoch 45: Train Loss=0.1356, Train Acc=96.10%, Val Loss=0.2533, Val Acc=95.49%
# Epoch 46: Train Loss=0.1365, Train Acc=96.19%, Val Loss=0.2349, Val Acc=95.49%
# Epoch 47: Train Loss=0.1254, Train Acc=96.19%, Val Loss=0.2420, Val Acc=95.23%
# Epoch 48: Train Loss=0.1203, Train Acc=96.30%, Val Loss=0.2516, Val Acc=95.23%
# Epoch 49: Train Loss=0.1314, Train Acc=95.98%, Val Loss=0.2497, Val Acc=95.57%
# Epoch 50: Train Loss=0.1186, Train Acc=96.36%, Val Loss=0.2589, Val Acc=95.14%
# Fold 3
# Epoch 1: Train Loss=1.3206, Train Acc=50.88%, Val Loss=1.0142, Val Acc=68.58%
# Epoch 2: Train Loss=0.8962, Train Acc=70.80%, Val Loss=0.6534, Val Acc=85.50%
# Epoch 3: Train Loss=0.6473, Train Acc=80.84%, Val Loss=0.4972, Val Acc=87.24%
# Epoch 4: Train Loss=0.5412, Train Acc=84.50%, Val Loss=0.4258, Val Acc=88.98%
# Epoch 5: Train Loss=0.4466, Train Acc=86.71%, Val Loss=0.3563, Val Acc=90.19%
# Epoch 6: Train Loss=0.4070, Train Acc=88.16%, Val Loss=0.3449, Val Acc=90.45%
# Epoch 7: Train Loss=0.3607, Train Acc=89.88%, Val Loss=0.3071, Val Acc=92.36%
# Epoch 8: Train Loss=0.3232, Train Acc=90.45%, Val Loss=0.3230, Val Acc=91.15%
# Epoch 9: Train Loss=0.2961, Train Acc=91.31%, Val Loss=0.2807, Val Acc=93.66%
# Epoch 10: Train Loss=0.2899, Train Acc=91.70%, Val Loss=0.2966, Val Acc=92.71%
# Epoch 11: Train Loss=0.2832, Train Acc=91.61%, Val Loss=0.2944, Val Acc=92.53%
# Epoch 12: Train Loss=0.2368, Train Acc=93.28%, Val Loss=0.2824, Val Acc=93.06%
# Epoch 13: Train Loss=0.2693, Train Acc=91.46%, Val Loss=0.2816, Val Acc=93.32%
# Epoch 14: Train Loss=0.2266, Train Acc=93.45%, Val Loss=0.2702, Val Acc=93.75%
# Epoch 15: Train Loss=0.2258, Train Acc=93.43%, Val Loss=0.2541, Val Acc=94.27%
# Epoch 16: Train Loss=0.2252, Train Acc=93.21%, Val Loss=0.2597, Val Acc=93.75%
# Epoch 17: Train Loss=0.1990, Train Acc=94.20%, Val Loss=0.2705, Val Acc=93.32%
# Epoch 18: Train Loss=0.1883, Train Acc=94.22%, Val Loss=0.2569, Val Acc=93.84%
# Epoch 19: Train Loss=0.2148, Train Acc=93.64%, Val Loss=0.2792, Val Acc=93.40%
# Epoch 20: Train Loss=0.1972, Train Acc=93.96%, Val Loss=0.2701, Val Acc=93.75%
# Epoch 21: Train Loss=0.1818, Train Acc=94.61%, Val Loss=0.2706, Val Acc=93.75%
# Epoch 22: Train Loss=0.1788, Train Acc=94.82%, Val Loss=0.2797, Val Acc=93.49%
# Epoch 23: Train Loss=0.1889, Train Acc=94.39%, Val Loss=0.2665, Val Acc=93.92%
# Epoch 24: Train Loss=0.1671, Train Acc=95.23%, Val Loss=0.2619, Val Acc=93.92%
# Epoch 25: Train Loss=0.1699, Train Acc=94.93%, Val Loss=0.2544, Val Acc=94.44%
# Epoch 26: Train Loss=0.1583, Train Acc=95.33%, Val Loss=0.2670, Val Acc=94.18%
# Epoch 27: Train Loss=0.1476, Train Acc=95.48%, Val Loss=0.2582, Val Acc=94.18%
# Epoch 28: Train Loss=0.1493, Train Acc=95.53%, Val Loss=0.2771, Val Acc=94.18%
# Epoch 29: Train Loss=0.1582, Train Acc=95.03%, Val Loss=0.2629, Val Acc=94.27%
# Epoch 30: Train Loss=0.1686, Train Acc=94.84%, Val Loss=0.2640, Val Acc=93.49%
# Epoch 31: Train Loss=0.1472, Train Acc=95.53%, Val Loss=0.2712, Val Acc=93.49%
# Epoch 32: Train Loss=0.1486, Train Acc=95.27%, Val Loss=0.2728, Val Acc=93.32%
# Epoch 33: Train Loss=0.1311, Train Acc=96.02%, Val Loss=0.2654, Val Acc=94.18%
# Epoch 34: Train Loss=0.1523, Train Acc=95.42%, Val Loss=0.2833, Val Acc=93.49%
# Epoch 35: Train Loss=0.1479, Train Acc=95.72%, Val Loss=0.2807, Val Acc=94.10%
# Epoch 36: Train Loss=0.1476, Train Acc=95.48%, Val Loss=0.2882, Val Acc=93.23%
# Epoch 37: Train Loss=0.1362, Train Acc=95.91%, Val Loss=0.2667, Val Acc=94.44%
# Epoch 38: Train Loss=0.1250, Train Acc=96.08%, Val Loss=0.2898, Val Acc=93.40%
# Epoch 39: Train Loss=0.1256, Train Acc=95.93%, Val Loss=0.2964, Val Acc=93.75%
# Epoch 40: Train Loss=0.1206, Train Acc=96.32%, Val Loss=0.2819, Val Acc=94.01%
# Epoch 41: Train Loss=0.1322, Train Acc=95.89%, Val Loss=0.3006, Val Acc=93.14%
# Epoch 42: Train Loss=0.1204, Train Acc=95.95%, Val Loss=0.2854, Val Acc=94.18%
# Epoch 43: Train Loss=0.1374, Train Acc=96.00%, Val Loss=0.2824, Val Acc=93.58%
# Epoch 44: Train Loss=0.1302, Train Acc=96.08%, Val Loss=0.2761, Val Acc=94.10%
# Epoch 45: Train Loss=0.1197, Train Acc=96.36%, Val Loss=0.2779, Val Acc=94.01%
# Epoch 46: Train Loss=0.1330, Train Acc=95.74%, Val Loss=0.2997, Val Acc=93.40%
# Epoch 47: Train Loss=0.1172, Train Acc=96.51%, Val Loss=0.2864, Val Acc=93.75%
# Epoch 48: Train Loss=0.1198, Train Acc=96.34%, Val Loss=0.2666, Val Acc=94.97%
# Epoch 49: Train Loss=0.1328, Train Acc=95.93%, Val Loss=0.2871, Val Acc=94.10%
# Epoch 50: Train Loss=0.1226, Train Acc=96.55%, Val Loss=0.2788, Val Acc=94.10%
# Fold 4
# Epoch 1: Train Loss=1.3367, Train Acc=50.47%, Val Loss=0.9960, Val Acc=65.71%
# Epoch 2: Train Loss=0.9195, Train Acc=69.73%, Val Loss=0.6418, Val Acc=82.20%
# Epoch 3: Train Loss=0.6400, Train Acc=80.69%, Val Loss=0.4483, Val Acc=88.02%
# Epoch 4: Train Loss=0.5157, Train Acc=84.91%, Val Loss=0.3632, Val Acc=89.84%
# Epoch 5: Train Loss=0.4516, Train Acc=86.99%, Val Loss=0.3617, Val Acc=90.89%
# Epoch 6: Train Loss=0.4019, Train Acc=88.81%, Val Loss=0.2896, Val Acc=91.84%
# Epoch 7: Train Loss=0.3554, Train Acc=89.23%, Val Loss=0.2894, Val Acc=92.19%
# Epoch 8: Train Loss=0.3228, Train Acc=91.16%, Val Loss=0.2688, Val Acc=92.19%
# Epoch 9: Train Loss=0.3119, Train Acc=91.37%, Val Loss=0.2745, Val Acc=91.32%
# Epoch 10: Train Loss=0.3126, Train Acc=90.69%, Val Loss=0.2646, Val Acc=93.40%
# Epoch 11: Train Loss=0.2725, Train Acc=91.95%, Val Loss=0.2440, Val Acc=93.49%
# Epoch 12: Train Loss=0.2522, Train Acc=92.70%, Val Loss=0.2547, Val Acc=93.14%
# Epoch 13: Train Loss=0.2341, Train Acc=93.02%, Val Loss=0.2429, Val Acc=93.49%
# Epoch 14: Train Loss=0.2244, Train Acc=93.58%, Val Loss=0.2714, Val Acc=92.36%
# Epoch 15: Train Loss=0.2177, Train Acc=93.64%, Val Loss=0.2335, Val Acc=93.84%
# Epoch 16: Train Loss=0.2275, Train Acc=93.24%, Val Loss=0.2593, Val Acc=93.06%
# Epoch 17: Train Loss=0.2062, Train Acc=94.14%, Val Loss=0.2451, Val Acc=93.32%
# Epoch 18: Train Loss=0.1960, Train Acc=93.77%, Val Loss=0.2469, Val Acc=93.84%
# Epoch 19: Train Loss=0.1773, Train Acc=94.91%, Val Loss=0.2430, Val Acc=94.27%
# Epoch 20: Train Loss=0.1799, Train Acc=94.86%, Val Loss=0.2556, Val Acc=93.75%
# Epoch 21: Train Loss=0.1857, Train Acc=94.43%, Val Loss=0.2546, Val Acc=93.23%
# Epoch 22: Train Loss=0.1845, Train Acc=94.31%, Val Loss=0.2351, Val Acc=94.53%
# Epoch 23: Train Loss=0.1761, Train Acc=94.54%, Val Loss=0.2435, Val Acc=93.92%
# Epoch 24: Train Loss=0.1552, Train Acc=95.25%, Val Loss=0.2315, Val Acc=94.62%
# Epoch 25: Train Loss=0.1898, Train Acc=94.37%, Val Loss=0.2140, Val Acc=95.31%
# Epoch 26: Train Loss=0.1672, Train Acc=94.67%, Val Loss=0.2382, Val Acc=93.32%
# Epoch 27: Train Loss=0.1542, Train Acc=95.44%, Val Loss=0.2344, Val Acc=94.70%
# Epoch 28: Train Loss=0.1608, Train Acc=95.03%, Val Loss=0.2277, Val Acc=94.79%
# Epoch 29: Train Loss=0.1500, Train Acc=95.76%, Val Loss=0.2324, Val Acc=94.70%
# Epoch 30: Train Loss=0.1636, Train Acc=95.33%, Val Loss=0.2357, Val Acc=95.14%
# Epoch 31: Train Loss=0.1510, Train Acc=95.42%, Val Loss=0.2340, Val Acc=94.62%
# Epoch 32: Train Loss=0.1469, Train Acc=95.59%, Val Loss=0.2562, Val Acc=94.36%
# Epoch 33: Train Loss=0.1393, Train Acc=95.42%, Val Loss=0.2387, Val Acc=94.36%
# Epoch 34: Train Loss=0.1436, Train Acc=95.93%, Val Loss=0.2495, Val Acc=94.79%
# Epoch 35: Train Loss=0.1461, Train Acc=95.40%, Val Loss=0.2538, Val Acc=94.44%
# Epoch 36: Train Loss=0.1529, Train Acc=95.27%, Val Loss=0.2569, Val Acc=94.62%
# Epoch 37: Train Loss=0.1409, Train Acc=95.68%, Val Loss=0.2514, Val Acc=94.70%
# Epoch 38: Train Loss=0.1484, Train Acc=95.23%, Val Loss=0.2735, Val Acc=94.01%
# Epoch 39: Train Loss=0.1305, Train Acc=96.15%, Val Loss=0.2503, Val Acc=94.18%
# Epoch 40: Train Loss=0.1586, Train Acc=95.55%, Val Loss=0.2509, Val Acc=94.44%
# Epoch 41: Train Loss=0.1323, Train Acc=95.70%, Val Loss=0.2393, Val Acc=95.05%
# Epoch 42: Train Loss=0.1199, Train Acc=96.17%, Val Loss=0.2481, Val Acc=93.84%
# Epoch 43: Train Loss=0.1159, Train Acc=96.58%, Val Loss=0.2369, Val Acc=94.79%
# Epoch 44: Train Loss=0.1241, Train Acc=96.15%, Val Loss=0.2809, Val Acc=94.18%
# Epoch 45: Train Loss=0.1232, Train Acc=96.21%, Val Loss=0.2565, Val Acc=94.36%
# Epoch 46: Train Loss=0.1202, Train Acc=96.58%, Val Loss=0.2554, Val Acc=94.62%
# Epoch 47: Train Loss=0.1258, Train Acc=96.32%, Val Loss=0.2370, Val Acc=94.70%
# Epoch 48: Train Loss=0.1242, Train Acc=96.32%, Val Loss=0.2541, Val Acc=94.18%
# Epoch 49: Train Loss=0.1265, Train Acc=96.47%, Val Loss=0.2430, Val Acc=94.88%
# Epoch 50: Train Loss=0.1066, Train Acc=96.64%, Val Loss=0.2350, Val Acc=94.62%
# Fold 5
# Epoch 1: Train Loss=1.3449, Train Acc=50.54%, Val Loss=0.9696, Val Acc=65.97%
# Epoch 2: Train Loss=0.9653, Train Acc=66.42%, Val Loss=0.6655, Val Acc=83.42%
# Epoch 3: Train Loss=0.7257, Train Acc=77.63%, Val Loss=0.4597, Val Acc=87.76%
# Epoch 4: Train Loss=0.5550, Train Acc=83.71%, Val Loss=0.3479, Val Acc=90.45%
# Epoch 5: Train Loss=0.4621, Train Acc=86.90%, Val Loss=0.2934, Val Acc=91.67%
# Epoch 6: Train Loss=0.4304, Train Acc=87.50%, Val Loss=0.2919, Val Acc=91.41%
# Epoch 7: Train Loss=0.3837, Train Acc=88.81%, Val Loss=0.2606, Val Acc=92.97%
# Epoch 8: Train Loss=0.3331, Train Acc=90.58%, Val Loss=0.2441, Val Acc=93.14%
# Epoch 9: Train Loss=0.3267, Train Acc=90.33%, Val Loss=0.2321, Val Acc=92.80%
# Epoch 10: Train Loss=0.2892, Train Acc=92.08%, Val Loss=0.2214, Val Acc=93.84%
# Epoch 11: Train Loss=0.2902, Train Acc=91.46%, Val Loss=0.2491, Val Acc=92.10%
# Epoch 12: Train Loss=0.2652, Train Acc=91.85%, Val Loss=0.2154, Val Acc=93.23%
# Epoch 13: Train Loss=0.2510, Train Acc=92.77%, Val Loss=0.2158, Val Acc=94.10%
# Epoch 14: Train Loss=0.2319, Train Acc=93.00%, Val Loss=0.1979, Val Acc=94.27%
# Epoch 15: Train Loss=0.2235, Train Acc=93.36%, Val Loss=0.2176, Val Acc=93.49%
# Epoch 16: Train Loss=0.2270, Train Acc=93.17%, Val Loss=0.2160, Val Acc=93.75%
# Epoch 17: Train Loss=0.2216, Train Acc=93.56%, Val Loss=0.1942, Val Acc=94.53%
# Epoch 18: Train Loss=0.2052, Train Acc=93.90%, Val Loss=0.2001, Val Acc=94.36%
# Epoch 19: Train Loss=0.2047, Train Acc=93.66%, Val Loss=0.2069, Val Acc=94.36%
# Epoch 20: Train Loss=0.2007, Train Acc=93.96%, Val Loss=0.1909, Val Acc=95.05%
# Epoch 21: Train Loss=0.1938, Train Acc=94.50%, Val Loss=0.1867, Val Acc=94.79%
# Epoch 22: Train Loss=0.1871, Train Acc=94.58%, Val Loss=0.1854, Val Acc=95.23%
# Epoch 23: Train Loss=0.1845, Train Acc=94.61%, Val Loss=0.2004, Val Acc=94.70%
# Epoch 24: Train Loss=0.1934, Train Acc=94.39%, Val Loss=0.2106, Val Acc=94.44%
# Epoch 25: Train Loss=0.1654, Train Acc=95.16%, Val Loss=0.2014, Val Acc=94.27%
# Epoch 26: Train Loss=0.1762, Train Acc=94.78%, Val Loss=0.2078, Val Acc=95.14%
# Epoch 27: Train Loss=0.1818, Train Acc=94.82%, Val Loss=0.1891, Val Acc=94.44%
# Epoch 28: Train Loss=0.1737, Train Acc=94.91%, Val Loss=0.2040, Val Acc=94.79%
# Epoch 29: Train Loss=0.1563, Train Acc=95.48%, Val Loss=0.1877, Val Acc=95.49%
# Epoch 30: Train Loss=0.1585, Train Acc=95.44%, Val Loss=0.2018, Val Acc=94.97%
# Epoch 31: Train Loss=0.1423, Train Acc=95.98%, Val Loss=0.2075, Val Acc=94.88%
# Epoch 32: Train Loss=0.1328, Train Acc=96.15%, Val Loss=0.1919, Val Acc=95.05%
# Epoch 33: Train Loss=0.1433, Train Acc=95.80%, Val Loss=0.1952, Val Acc=94.70%
# Epoch 34: Train Loss=0.1359, Train Acc=95.91%, Val Loss=0.1969, Val Acc=94.88%
# Epoch 35: Train Loss=0.1681, Train Acc=95.03%, Val Loss=0.2090, Val Acc=94.62%
# Epoch 36: Train Loss=0.1393, Train Acc=95.83%, Val Loss=0.2164, Val Acc=94.70%
# Epoch 37: Train Loss=0.1419, Train Acc=95.74%, Val Loss=0.2106, Val Acc=94.70%
# Epoch 38: Train Loss=0.1283, Train Acc=96.17%, Val Loss=0.1804, Val Acc=95.40%
# Epoch 39: Train Loss=0.1401, Train Acc=95.72%, Val Loss=0.2282, Val Acc=94.36%
# Epoch 40: Train Loss=0.1307, Train Acc=96.00%, Val Loss=0.1964, Val Acc=94.79%
# Epoch 41: Train Loss=0.1512, Train Acc=95.55%, Val Loss=0.1966, Val Acc=95.05%
# Epoch 42: Train Loss=0.1585, Train Acc=95.38%, Val Loss=0.1994, Val Acc=94.44%
# Epoch 43: Train Loss=0.1404, Train Acc=95.89%, Val Loss=0.1986, Val Acc=95.14%
# Epoch 44: Train Loss=0.1169, Train Acc=96.30%, Val Loss=0.2050, Val Acc=94.88%
# Epoch 45: Train Loss=0.1345, Train Acc=95.91%, Val Loss=0.1838, Val Acc=95.49%
# Epoch 46: Train Loss=0.1402, Train Acc=95.55%, Val Loss=0.2257, Val Acc=94.18%
# Epoch 47: Train Loss=0.1443, Train Acc=95.70%, Val Loss=0.2133, Val Acc=94.70%
# Epoch 48: Train Loss=0.1245, Train Acc=96.36%, Val Loss=0.2068, Val Acc=94.88%
# Epoch 49: Train Loss=0.1185, Train Acc=96.25%, Val Loss=0.2164, Val Acc=95.05%
# Epoch 50: Train Loss=0.1105, Train Acc=96.68%, Val Loss=0.2051, Val Acc=95.05%

# %%
# Plot Training and Validation Accuracy
plt.figure(figsize=(10, 4))  # Set figure size

# Plot accuracy curves for each fold
for i in range(k_folds):
    plt.plot(fold_train_accuracies[i], label=f'Train Fold {i+1}', linestyle='-')  # Solid line for training accuracy
    plt.plot(fold_val_accuracies[i], label=f'Val Fold {i+1}', linestyle='--')     # Dashed line for validation accuracy

# Configure plot appearance
plt.title('Training/Validation Accuracy per Fold')
plt.xlabel('Epoch')             # X-axis: epoch number
plt.ylabel('Accuracy')          # Y-axis: accuracy percentage
plt.legend()                    # Show legend to distinguish folds
plt.grid(True)                  # Add grid for readability
plt.tight_layout()              # Adjust layout to prevent clipping
plt.show()                      # Display the plot

# Plot Training and Validation Loss
plt.figure(figsize=(10, 4))  # Set figure size

# Plot loss curves for each fold
for i in range(k_folds):
    plt.plot(fold_train_losses[i], label=f'Train Fold {i+1}', linestyle='-')  # Solid line for training loss
    plt.plot(fold_val_losses[i], label=f'Val Fold {i+1}', linestyle='--')     # Dashed line for validation loss

# Configure plot appearance
plt.title('Training/Validation Loss per Fold')
plt.xlabel('Epoch')          # X-axis: epoch number
plt.ylabel('Loss')           # Y-axis: loss value
plt.legend()                 # Show legend to distinguish folds
plt.grid(True)               # Add grid for readability
plt.tight_layout()           # Adjust layout
plt.show()                   # Display the plot

# Calculate and print average validation accuracy across all folds
avg_val_acc = np.mean([accs[-1] for accs in fold_val_accuracies])
print(f"Average validation accuracy across folds: {avg_val_acc:.2f}%")
# Out:
# Average validation accuracy across folds: 94.65%

# %% [markdown]
# ## Retraining on Full Training Data
#
# Using the best performing fold, we are now training on the full data set. We're using the same parameters as before (50 epochs, Adam optimiser at learning rate 0.001 and weight decay 1e-4, batch size 32).

# %%
# Prepare full training dataset and dataloader
full_train_ds = MotionSense(X_train, Y_train)                      # Use entire training set
full_train_dl = DataLoader(full_train_ds, batch_size=32, shuffle=True)  # DataLoader for batching and shuffling

# Initialize the model
model = FCNet(input_size, hidden_size, num_classes)

# Load weights from the best-performing fold 
model.load_state_dict(best_model_state)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

# Retrain for a fixed number of epochs using the full dataset
for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0
    correct = 0
    total = 0

    # Iterate over batches
    for inputs, labels in full_train_dl:
        optimizer.zero_grad()                    # Reset gradients
        outputs = model(inputs.float())          # Forward pass
        loss = criterion(outputs, labels.long()) # Compute loss
        loss.backward()                          # Backpropagation
        optimizer.step()                         # Update model weights

        # Accumulate loss and accuracy
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Compute epoch-level loss and accuracy
    epoch_loss = running_loss / len(full_train_dl)
    epoch_acc = 100 * correct / total

    # Print training progress
    print(f"Retrain Epoch {epoch+1}: Loss = {epoch_loss:.4f}, Accuracy = {epoch_acc:.2f}%")
# Out:
# Retrain Epoch 1: Loss = 0.1750, Accuracy = 95.55%
# Retrain Epoch 2: Loss = 0.1750, Accuracy = 95.26%
# Retrain Epoch 3: Loss = 0.1731, Accuracy = 94.99%
# Retrain Epoch 4: Loss = 0.1594, Accuracy = 95.41%
# Retrain Epoch 5: Loss = 0.1431, Accuracy = 95.89%
# Retrain Epoch 6: Loss = 0.1433, Accuracy = 95.98%
# Retrain Epoch 7: Loss = 0.1437, Accuracy = 95.88%
# Retrain Epoch 8: Loss = 0.1287, Accuracy = 96.27%
# Retrain Epoch 9: Loss = 0.1421, Accuracy = 96.05%
# Retrain Epoch 10: Loss = 0.1275, Accuracy = 96.27%
# Retrain Epoch 11: Loss = 0.1302, Accuracy = 96.29%
# Retrain Epoch 12: Loss = 0.1365, Accuracy = 95.77%
# Retrain Epoch 13: Loss = 0.1210, Accuracy = 96.18%
# Retrain Epoch 14: Loss = 0.1378, Accuracy = 95.76%
# Retrain Epoch 15: Loss = 0.1296, Accuracy = 96.08%
# Retrain Epoch 16: Loss = 0.1343, Accuracy = 96.05%
# Retrain Epoch 17: Loss = 0.1176, Accuracy = 96.63%
# Retrain Epoch 18: Loss = 0.1363, Accuracy = 96.10%
# Retrain Epoch 19: Loss = 0.1176, Accuracy = 96.53%
# Retrain Epoch 20: Loss = 0.1274, Accuracy = 95.84%
# Retrain Epoch 21: Loss = 0.1226, Accuracy = 96.20%
# Retrain Epoch 22: Loss = 0.1270, Accuracy = 96.17%
# Retrain Epoch 23: Loss = 0.1335, Accuracy = 96.07%
# Retrain Epoch 24: Loss = 0.1251, Accuracy = 96.36%
# Retrain Epoch 25: Loss = 0.1280, Accuracy = 96.17%
# Retrain Epoch 26: Loss = 0.1121, Accuracy = 96.68%
# Retrain Epoch 27: Loss = 0.1192, Accuracy = 96.46%
# Retrain Epoch 28: Loss = 0.0995, Accuracy = 97.07%
# Retrain Epoch 29: Loss = 0.1088, Accuracy = 96.95%
# Retrain Epoch 30: Loss = 0.1171, Accuracy = 96.22%
# Retrain Epoch 31: Loss = 0.1094, Accuracy = 96.70%
# Retrain Epoch 32: Loss = 0.1228, Accuracy = 96.17%
# Retrain Epoch 33: Loss = 0.1143, Accuracy = 96.48%
# Retrain Epoch 34: Loss = 0.1172, Accuracy = 96.37%
# Retrain Epoch 35: Loss = 0.1121, Accuracy = 96.72%
# Retrain Epoch 36: Loss = 0.1191, Accuracy = 96.60%
# Retrain Epoch 37: Loss = 0.1060, Accuracy = 96.75%
# Retrain Epoch 38: Loss = 0.1333, Accuracy = 96.12%
# Retrain Epoch 39: Loss = 0.1049, Accuracy = 96.66%
# Retrain Epoch 40: Loss = 0.1158, Accuracy = 96.54%
# Retrain Epoch 41: Loss = 0.1073, Accuracy = 96.82%
# Retrain Epoch 42: Loss = 0.0966, Accuracy = 97.06%
# Retrain Epoch 43: Loss = 0.1277, Accuracy = 96.20%
# Retrain Epoch 44: Loss = 0.1012, Accuracy = 97.02%
# Retrain Epoch 45: Loss = 0.1090, Accuracy = 96.70%
# Retrain Epoch 46: Loss = 0.1011, Accuracy = 97.16%
# Retrain Epoch 47: Loss = 0.1269, Accuracy = 96.22%
# Retrain Epoch 48: Loss = 0.1152, Accuracy = 96.27%
# Retrain Epoch 49: Loss = 0.1134, Accuracy = 96.65%
# Retrain Epoch 50: Loss = 0.0980, Accuracy = 97.18%

# %% [markdown]
# ## Testing Time

# %%
# Prepare test dataset and DataLoader
test_ds = MotionSense(X_test, Y_test)                  # Create dataset from test features and labels
test_dl = DataLoader(test_ds, batch_size=32, shuffle=False)  # DataLoader without shuffling for evaluation

model.eval()   # Set model to evaluation mode (disables dropout, batchnorm updates)
all_preds = [] # To store predicted labels for all test samples
all_labels = [] # To store true labels for all test samples

# Disable gradient computation for faster inference and lower memory usage
with torch.no_grad():
    for inputs, labels in test_dl:
        outputs = model(inputs.float())               # Forward pass to get outputs/logits
        _, predicted = torch.max(outputs.data, 1)    # Get class with highest score as prediction
        all_preds.extend(predicted.cpu().numpy())    # Collect predictions on CPU as numpy array
        all_labels.extend(labels.cpu().numpy())      # Collect true labels

# Convert collected lists to numpy arrays for metric calculations
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Calculate overall test accuracy
test_acc = 100 * (all_preds == all_labels).sum() / len(all_labels)
print(f"Test Accuracy: {test_acc:.2f}%")

# Calculate additional performance metrics with weighted averaging for imbalanced classes
precision = precision_score(all_labels, all_preds, average='weighted')  # Precision metric
recall = recall_score(all_labels, all_preds, average='weighted')        # Recall metric
f1 = f1_score(all_labels, all_preds, average='weighted')                # F1 score metric
conf_matrix = confusion_matrix(all_labels, all_preds)                   # Confusion matrix

# Print the computed metrics
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)

# Print detailed classification report with per-class metrics
print("\nClassification Report:")
print(classification_report(all_labels, all_preds))
# Out:
# Test Accuracy: 91.69%
# Precision: 0.9193
# Recall: 0.9169
# F1 Score: 0.9172
# Confusion Matrix:
# [[ 90   0  12   1   2   1]
#  [  2 114  13   0   1   0]
#  [ 13  12 238   0   6   1]
#  [  3   4   1 107   0   0]
#  [  0   1   0   1 266   2]
#  [  0   0   0   0  25 300]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       106
#            1       0.87      0.88      0.87       130
#            2       0.90      0.88      0.89       270
#            3       0.98      0.93      0.96       115
#            4       0.89      0.99      0.93       270
#            5       0.99      0.92      0.95       325
#
#     accuracy                           0.92      1216
#    macro avg       0.91      0.91      0.91      1216
# weighted avg       0.92      0.92      0.92      1216

# %%
import seaborn as sns

# Set up the plot with a specific size for better readability
plt.figure(figsize=(8,6))

# Create a heatmap visualization of the confusion matrix using Seaborn
sns.heatmap(
    conf_matrix,            # Confusion matrix data to visualize
    annot=True,             # Annotate cells with numeric values
    fmt='d',                # Format annotations as integers
    cmap='Blues',           # Use a blue color palette for the heatmap
    xticklabels=['dws', 'ups', 'wlk', 'jog', 'std', 'sit'],  # Class labels for predicted axis
    yticklabels=['dws', 'ups', 'wlk', 'jog', 'std', 'sit']   # Class labels for true axis
)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
