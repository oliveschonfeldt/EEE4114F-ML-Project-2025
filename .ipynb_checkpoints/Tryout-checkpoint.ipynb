# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, TimeSeriesSplit, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
def get_ds_infos():
    """
    Read the file includes data subject information.

    EEE4114: Technically we do not need these data, as we are not concerned about identifying the subjects. 
    
    Data Columns:
    0: code [1-24]
    1: weight [kg]
    2: height [cm]
    3: age [years]
    4: gender [0:Female, 1:Male]
    
    Returns:
        A pandas DataFrame that contains information about data subjects' attributes 
    """ 

    dss = pd.read_csv(f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/data_subjects_info.csv')
    print("[INFO] -- Data subjects' information is imported.")
    
    return dss

def set_data_types(data_types=["userAcceleration"]):
    """
    Select the sensors and the mode to shape the final dataset. 

    EEE4114F: Choose sensors that you think are useful or would like to include in training. 
    You can choose all of them, or you could opt to try a limited set of input features
    
    Args:
        data_types: A list of sensor data type from this list: [attitude, gravity, rotationRate, userAcceleration] 

    Returns:
        It returns a list of columns to use for creating time-series from files.
    """
    dt_list = []
    for t in data_types:
        if t != "attitude":
            dt_list.append([t+".x",t+".y",t+".z"])
        else:
            dt_list.append([t+".roll", t+".pitch", t+".yaw"])

    return dt_list


def create_time_series(dt_list, act_labels, trial_codes, mode="mag", labeled=True):
    """
    EEE4114F: This defines what data you would like to include for a given set.  

    Args:
        dt_list: A list of columns that shows the type of data we want.
        act_labels: list of activities.
        trial_codes: list of trial codes corresponding to each activity.
        mode: It can be "raw" (all dimensions of each data type) or "mag" (only magnitude per data type).
        labeled: True if labeled dataset (adds 'act', 'trial', 'sub_id'), False otherwise.

    Returns:
        pd.DataFrame: Time-series sensor data with optional labels.
    """
    num_data_cols = len(dt_list) if mode == "mag" else len(dt_list * 3)

    if labeled:
        # +3 for act, trial, sub_id labels
        dataset = np.zeros((0, num_data_cols + 3))
    else:
        dataset = np.zeros((0, num_data_cols))

    ds_list = get_ds_infos()  # Assume this returns dict with "code" key for subject IDs

    print("[INFO] -- Creating Time-Series")
    for sub_id in ds_list["code"]:
        for act_id, act in enumerate(act_labels):
            for trial in trial_codes[act_id]:
                fname = f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/A_DeviceMotion_data/{act}_{trial}/sub_{int(sub_id)}.csv'
                raw_data = pd.read_csv(fname)
                raw_data = raw_data.drop(['Unnamed: 0'], axis=1)
                vals = np.zeros((len(raw_data), num_data_cols))
                for x_id, axes in enumerate(dt_list):
                    if mode == "mag":
                        # Calculate magnitude of 3 axes per sensor type
                        vals[:, x_id] = (raw_data[axes] ** 2).sum(axis=1) ** 0.5        
                    else:
                        vals[:, x_id * 3:(x_id + 1) * 3] = raw_data[axes].values
                    vals = vals[:, :num_data_cols]
                if labeled:
                    # Add act, trial, sub_id as labels (same length as vals)
                    lbls = np.array([[act_id, trial, sub_id]] * len(raw_data))
                    vals = np.concatenate((vals, lbls), axis=1)
                dataset = np.append(dataset, vals, axis=0)

    cols = []
    for axes in dt_list:
        if mode == "raw":
            cols += axes
        else:
            cols += [str(axes[0][:-2])]  # Use first part of sensor name for magnitude

    if labeled:
        cols += ["act", "trial", "sub_id"]

    dataset = pd.DataFrame(data=dataset, columns=cols)
    return dataset

# %%
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}

## Here we set parameter to build labeled time-series from dataset of "(A)DeviceMotion_data"
## attitude(roll, pitch, yaw); gravity(x, y, z); rotationRate(x, y, z); userAcceleration(x,y,z)
sdt = ["attitude", "gravity", "rotationRate", "userAcceleration"]
print("[INFO] -- Selected sensor data types: "+str(sdt))    
act_labels = ACT_LABELS # choose all 6 classes
print("[INFO] -- Selected activites: "+str(act_labels))    
trial_codes = [TRIAL_CODES[act] for act in act_labels]
dt_list = set_data_types(sdt)
dataset = create_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
print("[INFO] -- Shape of time-Series dataset:"+str(dataset.shape))    
dataset.head()
# Out:
# [INFO] -- Selected sensor data types: ['attitude', 'gravity', 'rotationRate', 'userAcceleration']
# [INFO] -- Selected activites: ['dws', 'ups', 'wlk', 'jog', 'std', 'sit']
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series
# [INFO] -- Shape of time-Series dataset:(1412865, 15)
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z  act  trial  \
# 0            0.294894           -0.184493            0.377542  0.0    1.0
# 1            0.219405            0.035846            0.114866  0.0    1.0
# 2            0.010714            0.134701           -0.167808  0.0    1.0
# 3           -0.008389            0.136788            0.094958  0.0    1.0
# 4            0.199441            0.353996           -0.044299  0.0    1.0
#
#    sub_id
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
def windows(dataset, window_size=400, stride=200):
    """
    Slice dataset into overlapping windows of fixed length.

    Args:
        dataset (pd.DataFrame): Time-series data with sensor features and 'act' label column.
        window_size (int): Number of samples per window.
        stride (int): Step size between windows.

    Returns:
        pd.DataFrame: A new DataFrame with flattened windows and corresponding labels.
    """

    # Separate the feature values and labels
    features = dataset.drop(columns=['act']).values  # Shape: [n_samples, n_features]
    labels = dataset['act'].values  # Shape: [n_samples]

    # Lists to collect the processed windows and labels
    windowed_data = []
    windowed_labels = []

    # Iterate over the dataset with a sliding window
    for start in range(0, len(dataset) - window_size + 1, stride):
        end = start + window_size

        # Extract a window of features and corresponding labels
        window = features[start:end]           # Shape: [window_size, n_features]
        label_window = labels[start:end]       # Shape: [window_size]

        # Flatten the feature window by transposing to [n_features, window_size], then flatten to 1D
        window_flat = window.T.flatten()       # Final shape: [n_features * window_size]

        # Assign the most frequent label in the window as the representative label
        label = np.bincount(label_window.astype(int)).argmax()

        # Append the flattened window and label to the lists
        windowed_data.append(window_flat)
        windowed_labels.append(label)

    # Convert the list of windows to a DataFrame (each row is one flattened window)
    X = pd.DataFrame(windowed_data)

    # Convert the list of labels to a Series
    Y = pd.Series(windowed_labels, name='act')

    return X, Y

# %%
class MotionSense(Dataset):
    def __init__(self, X, Y, transform=None):
        self.X = torch.tensor(X.values)
        self.Y = torch.tensor(Y.values)
        self.transform = transform

    def __getitem__(self, index):
        if torch.is_tensor(index):
            index = int(index.item())

        x = self.X[index]
        y = self.Y[index]

        return x, y

    def __len__(self):
        return len(self.X)

# %%
# Split subjects for train/test
unique_sub_ids = dataset['sub_id'].unique()  # Get list of unique subject IDs
train_subs, test_subs = train_test_split(unique_sub_ids, test_size=0.15, random_state=13739)  
# Randomly split subjects: 85% for training, 15% for testing (subject-wise split ensures no data leakage across subjects)

train_df = dataset[dataset['sub_id'].isin(train_subs)].reset_index(drop=True)  # Extract training data from selected subjects
test_df = dataset[dataset['sub_id'].isin(test_subs)].reset_index(drop=True)    # Extract test data from held-out subjects

# Select only sensor features (exclude meta-info like 'sub_id') and the activity label
feature_cols = [
    'attitude.roll', 'attitude.pitch', 'attitude.yaw',
    'gravity.x', 'gravity.y', 'gravity.z',
    'rotationRate.x', 'rotationRate.y', 'rotationRate.z',
    'userAcceleration.x', 'userAcceleration.y', 'userAcceleration.z'
]
filtered_train_df = train_df[feature_cols + ['act']]  # Retain only sensor features + label for training
filtered_test_df = test_df[feature_cols + ['act']]    # Same for test data

# Apply windowing to create overlapping segments of fixed length from continuous data
X_train, Y_train = windows(filtered_train_df, window_size=400, stride=200)
X_test, Y_test = windows(filtered_test_df, window_size=400, stride=200)
# Result: X_* are DataFrames of flattened windows, Y_* are Series of majority labels per window

k_folds = 5  # Define number of folds for cross-validation

# Initialize KFold cross-validator (shuffling ensures different class distributions across folds)
kf = KFold(n_splits=5, shuffle=True, random_state=42)
all_splits = list(kf.split(X_train))  # Create list of (train_idx, val_idx) splits for each fold

# %%
# Define the improved fully connected neural network for time-series classification
class FCNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FCNet, self).__init__()

        # First fully connected layer: input -> hidden_size
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)      # Batch normalization to stabilize learning
        self.dropout1 = nn.Dropout(0.5)             # Dropout to prevent overfitting

        # Second fully connected layer: hidden_size -> hidden_size // 2
        self.fc2 = nn.Linear(hidden_size, hidden_size // 2)
        self.bn2 = nn.BatchNorm1d(hidden_size // 2) # Batch normalization
        self.dropout2 = nn.Dropout(0.5)             # Dropout again for regularization

        # Final layer: hidden_size // 2 -> number of classes
        self.fc3 = nn.Linear(hidden_size // 2, num_classes)

        self.relu = nn.ReLU()  # Activation function

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input from [batch, channels, time] to [batch, features]

        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.dropout2(x)

        x = self.fc3(x)  # Final output layer (no activation here; loss function will handle it)
        return x

# Parameters — adjust according to your input window configuration
input_size = 12 * 400     # 12 sensor features per timestep × 400 time steps per window
hidden_size = 50          # Size of hidden layer (can be tuned)
num_classes = 6           # Total number of activity classes to classify

# %%
num_epochs = 50  # Number of epochs to train per fold

# Track the best performing model across all folds
best_val_acc = 0
best_model_state = None

# Lists to store metrics for each fold
fold_train_losses = [[] for _ in range(k_folds)]
fold_val_losses = [[] for _ in range(k_folds)]
fold_train_accuracies = [[] for _ in range(k_folds)]
fold_val_accuracies = [[] for _ in range(k_folds)]

# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(all_splits):
    print(f"Fold {fold + 1}")

    # Prepare train and validation splits
    X_tr = X_train.iloc[train_idx].reset_index(drop=True)
    Y_tr = Y_train.iloc[train_idx].reset_index(drop=True)
    X_val = X_train.iloc[val_idx].reset_index(drop=True)
    Y_val = Y_train.iloc[val_idx].reset_index(drop=True)

    # Wrap data into custom dataset class
    train_ds = MotionSense(X_tr, Y_tr)
    val_ds = MotionSense(X_val, Y_val)

    # Create DataLoaders
    train_dl = DataLoader(train_ds, batch_size=32, shuffle=True, drop_last=True)
    val_dl = DataLoader(val_ds, batch_size=32, shuffle=False, drop_last=True)

    # Initialize model, loss function, and optimizer
    model = FCNet(input_size, hidden_size, num_classes)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

    # Train for the specified number of epochs
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        running_loss = 0
        correct = 0
        total = 0

        # Training loop
        for inputs, labels in train_dl:
            optimizer.zero_grad()                 # Clear previous gradients
            outputs = model(inputs.float())       # Forward pass
            loss = criterion(outputs, labels.long())  # Compute loss
            loss.backward()                       # Backward pass
            optimizer.step()                      # Update weights

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_dl)
        train_acc = 100 * correct / total

        # Store metrics for this epoch
        fold_train_losses[fold].append(train_loss)
        fold_train_accuracies[fold].append(train_acc)

        # Validation loop
        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels in val_dl:
                outputs = model(inputs.float())         # Forward pass
                loss = criterion(outputs, labels)       # Compute validation loss
                val_loss += loss.item() * inputs.size(0)  # Accumulate total loss

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        avg_val_loss = val_loss / val_total
        val_acc = 100 * val_correct / val_total

        # Log metrics
        print(f"Epoch {epoch+1}: Train Loss={train_loss:.4f}, Train Acc={train_acc:.2f}%, "
              f"Val Loss={avg_val_loss:.4f}, Val Acc={val_acc:.2f}%")

        fold_val_losses[fold].append(avg_val_loss)
        fold_val_accuracies[fold].append(val_acc)

    # Track the best-performing model based on final validation accuracy
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model_state = model.state_dict()  # Save best model parameters
# Out:
# Fold 1
# Epoch 1: Train Loss=1.4208, Train Acc=47.57%, Val Loss=1.0928, Val Acc=66.98%
# Epoch 2: Train Loss=1.0994, Train Acc=62.31%, Val Loss=0.8365, Val Acc=78.04%
# Epoch 3: Train Loss=0.9202, Train Acc=69.93%, Val Loss=0.6516, Val Acc=81.93%
# Epoch 4: Train Loss=0.7987, Train Acc=74.05%, Val Loss=0.5618, Val Acc=86.15%
# Epoch 5: Train Loss=0.7218, Train Acc=77.17%, Val Loss=0.4699, Val Acc=88.68%
# Epoch 6: Train Loss=0.6673, Train Acc=79.43%, Val Loss=0.4205, Val Acc=89.86%
# Epoch 7: Train Loss=0.6201, Train Acc=80.76%, Val Loss=0.3884, Val Acc=90.96%
# Epoch 8: Train Loss=0.5753, Train Acc=82.45%, Val Loss=0.3722, Val Acc=90.12%
# Epoch 9: Train Loss=0.5381, Train Acc=83.68%, Val Loss=0.3478, Val Acc=90.96%
# Epoch 10: Train Loss=0.5079, Train Acc=84.92%, Val Loss=0.3295, Val Acc=92.06%
# Epoch 11: Train Loss=0.4801, Train Acc=85.52%, Val Loss=0.3422, Val Acc=90.88%
# Epoch 12: Train Loss=0.4741, Train Acc=85.71%, Val Loss=0.3498, Val Acc=91.13%
# Epoch 13: Train Loss=0.4488, Train Acc=86.13%, Val Loss=0.3253, Val Acc=92.23%
# Epoch 14: Train Loss=0.4470, Train Acc=85.68%, Val Loss=0.3289, Val Acc=91.30%
# Epoch 15: Train Loss=0.4228, Train Acc=86.99%, Val Loss=0.3087, Val Acc=92.48%
# Epoch 16: Train Loss=0.4265, Train Acc=86.74%, Val Loss=0.2998, Val Acc=93.33%
# Epoch 17: Train Loss=0.4058, Train Acc=87.01%, Val Loss=0.3166, Val Acc=92.23%
# Epoch 18: Train Loss=0.3728, Train Acc=88.66%, Val Loss=0.3034, Val Acc=92.31%
# Epoch 19: Train Loss=0.3801, Train Acc=88.68%, Val Loss=0.3221, Val Acc=91.81%
# Epoch 20: Train Loss=0.3833, Train Acc=88.72%, Val Loss=0.3005, Val Acc=92.48%
# Epoch 21: Train Loss=0.3649, Train Acc=89.32%, Val Loss=0.3327, Val Acc=91.81%
# Epoch 22: Train Loss=0.3650, Train Acc=89.04%, Val Loss=0.3274, Val Acc=92.15%
# Epoch 23: Train Loss=0.3587, Train Acc=88.98%, Val Loss=0.3126, Val Acc=92.99%
# Epoch 24: Train Loss=0.3688, Train Acc=88.56%, Val Loss=0.3213, Val Acc=91.98%
# Epoch 25: Train Loss=0.3311, Train Acc=89.84%, Val Loss=0.3371, Val Acc=92.82%
# Epoch 26: Train Loss=0.3460, Train Acc=89.32%, Val Loss=0.3359, Val Acc=91.98%
# Epoch 27: Train Loss=0.3281, Train Acc=90.01%, Val Loss=0.3158, Val Acc=91.72%
# Epoch 28: Train Loss=0.3307, Train Acc=89.72%, Val Loss=0.3379, Val Acc=92.48%
# Epoch 29: Train Loss=0.3187, Train Acc=90.01%, Val Loss=0.3277, Val Acc=92.91%
# Epoch 30: Train Loss=0.3245, Train Acc=90.14%, Val Loss=0.3439, Val Acc=92.23%
# Epoch 31: Train Loss=0.2902, Train Acc=90.98%, Val Loss=0.3532, Val Acc=92.23%
# Epoch 32: Train Loss=0.3248, Train Acc=90.35%, Val Loss=0.3407, Val Acc=91.98%
# Epoch 33: Train Loss=0.2998, Train Acc=90.96%, Val Loss=0.3203, Val Acc=92.91%
# Epoch 34: Train Loss=0.3080, Train Acc=89.91%, Val Loss=0.3312, Val Acc=92.74%
# Epoch 35: Train Loss=0.3109, Train Acc=90.18%, Val Loss=0.3306, Val Acc=92.31%
# Epoch 36: Train Loss=0.2947, Train Acc=91.30%, Val Loss=0.3331, Val Acc=92.57%
# Epoch 37: Train Loss=0.3001, Train Acc=90.20%, Val Loss=0.3357, Val Acc=92.82%
# Epoch 38: Train Loss=0.2919, Train Acc=91.43%, Val Loss=0.3541, Val Acc=92.06%
# Epoch 39: Train Loss=0.2956, Train Acc=91.13%, Val Loss=0.3472, Val Acc=92.23%
# Epoch 40: Train Loss=0.3044, Train Acc=90.79%, Val Loss=0.3525, Val Acc=92.15%
# Epoch 41: Train Loss=0.2966, Train Acc=91.26%, Val Loss=0.3343, Val Acc=92.91%
# Epoch 42: Train Loss=0.2759, Train Acc=91.66%, Val Loss=0.3424, Val Acc=92.74%
# Epoch 43: Train Loss=0.2729, Train Acc=91.39%, Val Loss=0.3357, Val Acc=92.74%
# Epoch 44: Train Loss=0.2852, Train Acc=91.32%, Val Loss=0.3662, Val Acc=92.40%
# Epoch 45: Train Loss=0.2925, Train Acc=90.86%, Val Loss=0.3649, Val Acc=92.06%
# Epoch 46: Train Loss=0.2734, Train Acc=91.43%, Val Loss=0.3719, Val Acc=92.06%
# Epoch 47: Train Loss=0.2784, Train Acc=91.01%, Val Loss=0.3692, Val Acc=92.40%
# Epoch 48: Train Loss=0.2687, Train Acc=91.64%, Val Loss=0.3685, Val Acc=92.48%
# Epoch 49: Train Loss=0.2676, Train Acc=91.70%, Val Loss=0.3312, Val Acc=92.40%
# Epoch 50: Train Loss=0.2618, Train Acc=91.70%, Val Loss=0.3553, Val Acc=92.40%
# Fold 2
# Epoch 1: Train Loss=1.4618, Train Acc=44.09%, Val Loss=1.1140, Val Acc=65.37%
# Epoch 2: Train Loss=1.1312, Train Acc=60.09%, Val Loss=0.8865, Val Acc=71.96%
# Epoch 3: Train Loss=0.9521, Train Acc=68.48%, Val Loss=0.6822, Val Acc=81.17%
# Epoch 4: Train Loss=0.8171, Train Acc=73.48%, Val Loss=0.5550, Val Acc=86.57%
# Epoch 5: Train Loss=0.7263, Train Acc=76.52%, Val Loss=0.4782, Val Acc=89.02%
# Epoch 6: Train Loss=0.6486, Train Acc=80.34%, Val Loss=0.4158, Val Acc=89.95%
# Epoch 7: Train Loss=0.6019, Train Acc=81.31%, Val Loss=0.4071, Val Acc=88.34%
# Epoch 8: Train Loss=0.5716, Train Acc=82.20%, Val Loss=0.3796, Val Acc=90.37%
# Epoch 9: Train Loss=0.5282, Train Acc=83.70%, Val Loss=0.3583, Val Acc=90.46%
# Epoch 10: Train Loss=0.5031, Train Acc=84.71%, Val Loss=0.3205, Val Acc=90.79%
# Epoch 11: Train Loss=0.4897, Train Acc=85.28%, Val Loss=0.3379, Val Acc=91.39%
# Epoch 12: Train Loss=0.4840, Train Acc=85.20%, Val Loss=0.3024, Val Acc=91.47%
# Epoch 13: Train Loss=0.4436, Train Acc=86.57%, Val Loss=0.2935, Val Acc=91.81%
# Epoch 14: Train Loss=0.4543, Train Acc=86.21%, Val Loss=0.3012, Val Acc=91.55%
# Epoch 15: Train Loss=0.4198, Train Acc=87.58%, Val Loss=0.2844, Val Acc=91.89%
# Epoch 16: Train Loss=0.4252, Train Acc=87.29%, Val Loss=0.2841, Val Acc=91.81%
# Epoch 17: Train Loss=0.3900, Train Acc=88.43%, Val Loss=0.2704, Val Acc=93.07%
# Epoch 18: Train Loss=0.4012, Train Acc=87.48%, Val Loss=0.2729, Val Acc=92.06%
# Epoch 19: Train Loss=0.3945, Train Acc=88.01%, Val Loss=0.2885, Val Acc=92.40%
# Epoch 20: Train Loss=0.3617, Train Acc=89.23%, Val Loss=0.2792, Val Acc=92.40%
# Epoch 21: Train Loss=0.3572, Train Acc=88.83%, Val Loss=0.2802, Val Acc=92.40%
# Epoch 22: Train Loss=0.3746, Train Acc=88.70%, Val Loss=0.2912, Val Acc=92.06%
# Epoch 23: Train Loss=0.3396, Train Acc=89.57%, Val Loss=0.2827, Val Acc=92.57%
# Epoch 24: Train Loss=0.3510, Train Acc=89.63%, Val Loss=0.2850, Val Acc=92.06%
# Epoch 25: Train Loss=0.3577, Train Acc=89.74%, Val Loss=0.2765, Val Acc=92.74%
# Epoch 26: Train Loss=0.3261, Train Acc=90.10%, Val Loss=0.2556, Val Acc=93.07%
# Epoch 27: Train Loss=0.3409, Train Acc=89.61%, Val Loss=0.2696, Val Acc=92.48%
# Epoch 28: Train Loss=0.3169, Train Acc=90.27%, Val Loss=0.2535, Val Acc=93.07%
# Epoch 29: Train Loss=0.3269, Train Acc=90.20%, Val Loss=0.2645, Val Acc=92.74%
# Epoch 30: Train Loss=0.3180, Train Acc=90.43%, Val Loss=0.2598, Val Acc=92.48%
# Epoch 31: Train Loss=0.3156, Train Acc=90.82%, Val Loss=0.2784, Val Acc=92.40%
# Epoch 32: Train Loss=0.3380, Train Acc=90.16%, Val Loss=0.2708, Val Acc=92.31%
# Epoch 33: Train Loss=0.3074, Train Acc=90.58%, Val Loss=0.2773, Val Acc=92.74%
# Epoch 34: Train Loss=0.3100, Train Acc=90.86%, Val Loss=0.2907, Val Acc=92.23%
# Epoch 35: Train Loss=0.3118, Train Acc=90.56%, Val Loss=0.2859, Val Acc=92.40%
# Epoch 36: Train Loss=0.3066, Train Acc=90.92%, Val Loss=0.2917, Val Acc=92.65%
# Epoch 37: Train Loss=0.3041, Train Acc=91.09%, Val Loss=0.2653, Val Acc=92.65%
# Epoch 38: Train Loss=0.3014, Train Acc=91.15%, Val Loss=0.2597, Val Acc=92.57%
# Epoch 39: Train Loss=0.3001, Train Acc=90.84%, Val Loss=0.2723, Val Acc=93.16%
# Epoch 40: Train Loss=0.2794, Train Acc=91.74%, Val Loss=0.2676, Val Acc=92.82%
# Epoch 41: Train Loss=0.2719, Train Acc=91.68%, Val Loss=0.2921, Val Acc=92.91%
# Epoch 42: Train Loss=0.2909, Train Acc=91.05%, Val Loss=0.2958, Val Acc=92.31%
# Epoch 43: Train Loss=0.2775, Train Acc=91.83%, Val Loss=0.2743, Val Acc=92.65%
# Epoch 44: Train Loss=0.2887, Train Acc=91.15%, Val Loss=0.2571, Val Acc=92.74%
# Epoch 45: Train Loss=0.2905, Train Acc=91.51%, Val Loss=0.2982, Val Acc=92.74%
# Epoch 46: Train Loss=0.3029, Train Acc=91.11%, Val Loss=0.2897, Val Acc=92.65%
# Epoch 47: Train Loss=0.2788, Train Acc=91.43%, Val Loss=0.2620, Val Acc=92.23%
# Epoch 48: Train Loss=0.2725, Train Acc=91.45%, Val Loss=0.2949, Val Acc=92.74%
# Epoch 49: Train Loss=0.2621, Train Acc=92.61%, Val Loss=0.2765, Val Acc=92.91%
# Epoch 50: Train Loss=0.2834, Train Acc=91.68%, Val Loss=0.2753, Val Acc=92.23%
# Fold 3
# Epoch 1: Train Loss=1.4699, Train Acc=44.62%, Val Loss=1.1558, Val Acc=63.09%
# Epoch 2: Train Loss=1.1662, Train Acc=58.74%, Val Loss=0.9508, Val Acc=68.24%
# Epoch 3: Train Loss=0.9945, Train Acc=65.41%, Val Loss=0.7571, Val Acc=81.08%
# Epoch 4: Train Loss=0.8470, Train Acc=72.80%, Val Loss=0.5838, Val Acc=86.99%
# Epoch 5: Train Loss=0.7477, Train Acc=75.74%, Val Loss=0.4717, Val Acc=90.62%
# Epoch 6: Train Loss=0.7194, Train Acc=77.22%, Val Loss=0.4469, Val Acc=89.10%
# Epoch 7: Train Loss=0.6306, Train Acc=80.19%, Val Loss=0.3651, Val Acc=90.96%
# Epoch 8: Train Loss=0.5985, Train Acc=80.55%, Val Loss=0.3419, Val Acc=92.23%
# Epoch 9: Train Loss=0.5658, Train Acc=82.64%, Val Loss=0.3531, Val Acc=91.81%
# Epoch 10: Train Loss=0.5270, Train Acc=82.96%, Val Loss=0.2859, Val Acc=92.40%
# Epoch 11: Train Loss=0.4874, Train Acc=84.86%, Val Loss=0.2808, Val Acc=92.48%
# Epoch 12: Train Loss=0.4840, Train Acc=84.40%, Val Loss=0.2897, Val Acc=92.74%
# Epoch 13: Train Loss=0.4661, Train Acc=85.05%, Val Loss=0.2681, Val Acc=92.82%
# Epoch 14: Train Loss=0.4432, Train Acc=86.91%, Val Loss=0.2687, Val Acc=93.07%
# Epoch 15: Train Loss=0.4489, Train Acc=85.39%, Val Loss=0.2600, Val Acc=93.16%
# Epoch 16: Train Loss=0.4257, Train Acc=87.14%, Val Loss=0.2424, Val Acc=93.67%
# Epoch 17: Train Loss=0.4218, Train Acc=87.52%, Val Loss=0.2591, Val Acc=93.24%
# Epoch 18: Train Loss=0.3902, Train Acc=87.63%, Val Loss=0.2409, Val Acc=94.09%
# Epoch 19: Train Loss=0.3906, Train Acc=87.58%, Val Loss=0.2379, Val Acc=93.50%
# Epoch 20: Train Loss=0.3771, Train Acc=88.07%, Val Loss=0.2516, Val Acc=93.67%
# Epoch 21: Train Loss=0.4022, Train Acc=87.69%, Val Loss=0.2227, Val Acc=93.92%
# Epoch 22: Train Loss=0.3667, Train Acc=88.49%, Val Loss=0.2248, Val Acc=93.92%
# Epoch 23: Train Loss=0.3681, Train Acc=88.41%, Val Loss=0.2219, Val Acc=94.34%
# Epoch 24: Train Loss=0.3467, Train Acc=88.56%, Val Loss=0.2384, Val Acc=93.83%
# Epoch 25: Train Loss=0.3544, Train Acc=89.02%, Val Loss=0.2252, Val Acc=94.09%
# Epoch 26: Train Loss=0.3431, Train Acc=89.23%, Val Loss=0.2349, Val Acc=93.58%
# Epoch 27: Train Loss=0.3559, Train Acc=89.27%, Val Loss=0.2145, Val Acc=94.43%
# Epoch 28: Train Loss=0.3291, Train Acc=89.76%, Val Loss=0.2284, Val Acc=93.67%
# Epoch 29: Train Loss=0.3430, Train Acc=89.84%, Val Loss=0.2129, Val Acc=94.26%
# Epoch 30: Train Loss=0.3201, Train Acc=89.38%, Val Loss=0.2405, Val Acc=93.50%
# Epoch 31: Train Loss=0.3231, Train Acc=89.76%, Val Loss=0.2061, Val Acc=94.68%
# Epoch 32: Train Loss=0.3072, Train Acc=90.24%, Val Loss=0.2317, Val Acc=93.83%
# Epoch 33: Train Loss=0.3493, Train Acc=89.46%, Val Loss=0.2191, Val Acc=93.92%
# Epoch 34: Train Loss=0.3301, Train Acc=90.50%, Val Loss=0.2199, Val Acc=94.43%
# Epoch 35: Train Loss=0.3136, Train Acc=89.93%, Val Loss=0.2369, Val Acc=94.26%
# Epoch 36: Train Loss=0.3169, Train Acc=90.24%, Val Loss=0.2341, Val Acc=93.75%
# Epoch 37: Train Loss=0.2949, Train Acc=91.01%, Val Loss=0.2268, Val Acc=93.92%
# Epoch 38: Train Loss=0.2880, Train Acc=90.90%, Val Loss=0.2223, Val Acc=94.51%
# Epoch 39: Train Loss=0.3028, Train Acc=90.37%, Val Loss=0.2281, Val Acc=94.26%
# Epoch 40: Train Loss=0.2933, Train Acc=91.05%, Val Loss=0.2252, Val Acc=93.83%
# Epoch 41: Train Loss=0.3087, Train Acc=90.58%, Val Loss=0.2353, Val Acc=93.83%
# Epoch 42: Train Loss=0.2869, Train Acc=90.98%, Val Loss=0.2290, Val Acc=94.00%
# Epoch 43: Train Loss=0.2988, Train Acc=90.90%, Val Loss=0.2167, Val Acc=94.17%
# Epoch 44: Train Loss=0.2982, Train Acc=90.65%, Val Loss=0.2124, Val Acc=94.85%
# Epoch 45: Train Loss=0.3062, Train Acc=90.20%, Val Loss=0.2211, Val Acc=93.83%
# Epoch 46: Train Loss=0.3152, Train Acc=90.18%, Val Loss=0.2129, Val Acc=94.93%
# Epoch 47: Train Loss=0.3006, Train Acc=90.56%, Val Loss=0.2264, Val Acc=94.51%
# Epoch 48: Train Loss=0.2814, Train Acc=90.96%, Val Loss=0.2320, Val Acc=93.83%
# Epoch 49: Train Loss=0.2744, Train Acc=91.55%, Val Loss=0.2198, Val Acc=93.92%
# Epoch 50: Train Loss=0.2819, Train Acc=90.77%, Val Loss=0.2464, Val Acc=94.34%
# Fold 4
# Epoch 1: Train Loss=1.3790, Train Acc=48.78%, Val Loss=1.0366, Val Acc=62.58%
# Epoch 2: Train Loss=1.0962, Train Acc=60.77%, Val Loss=0.7997, Val Acc=78.97%
# Epoch 3: Train Loss=0.9442, Train Acc=67.57%, Val Loss=0.6119, Val Acc=87.08%
# Epoch 4: Train Loss=0.7973, Train Acc=73.59%, Val Loss=0.5284, Val Acc=87.33%
# Epoch 5: Train Loss=0.7155, Train Acc=76.54%, Val Loss=0.4442, Val Acc=90.20%
# Epoch 6: Train Loss=0.6593, Train Acc=79.86%, Val Loss=0.3878, Val Acc=90.37%
# Epoch 7: Train Loss=0.5888, Train Acc=81.84%, Val Loss=0.3574, Val Acc=91.22%
# Epoch 8: Train Loss=0.5683, Train Acc=82.39%, Val Loss=0.3516, Val Acc=90.37%
# Epoch 9: Train Loss=0.5387, Train Acc=83.53%, Val Loss=0.3255, Val Acc=91.39%
# Epoch 10: Train Loss=0.5149, Train Acc=84.04%, Val Loss=0.3125, Val Acc=91.98%
# Epoch 11: Train Loss=0.5002, Train Acc=85.14%, Val Loss=0.2837, Val Acc=92.31%
# Epoch 12: Train Loss=0.4644, Train Acc=85.94%, Val Loss=0.3043, Val Acc=91.47%
# Epoch 13: Train Loss=0.4486, Train Acc=86.15%, Val Loss=0.3024, Val Acc=91.72%
# Epoch 14: Train Loss=0.4242, Train Acc=86.59%, Val Loss=0.2838, Val Acc=92.57%
# Epoch 15: Train Loss=0.4385, Train Acc=86.95%, Val Loss=0.2923, Val Acc=92.99%
# Epoch 16: Train Loss=0.4341, Train Acc=86.82%, Val Loss=0.3016, Val Acc=91.98%
# Epoch 17: Train Loss=0.3938, Train Acc=88.28%, Val Loss=0.2862, Val Acc=92.65%
# Epoch 18: Train Loss=0.3846, Train Acc=88.20%, Val Loss=0.2925, Val Acc=92.31%
# Epoch 19: Train Loss=0.3917, Train Acc=88.24%, Val Loss=0.2817, Val Acc=92.40%
# Epoch 20: Train Loss=0.3965, Train Acc=88.15%, Val Loss=0.2940, Val Acc=92.06%
# Epoch 21: Train Loss=0.3657, Train Acc=89.06%, Val Loss=0.2728, Val Acc=92.74%
# Epoch 22: Train Loss=0.3591, Train Acc=89.46%, Val Loss=0.2886, Val Acc=92.57%
# Epoch 23: Train Loss=0.3608, Train Acc=89.70%, Val Loss=0.2821, Val Acc=92.65%
# Epoch 24: Train Loss=0.3788, Train Acc=88.34%, Val Loss=0.2861, Val Acc=92.40%
# Epoch 25: Train Loss=0.3370, Train Acc=89.46%, Val Loss=0.2843, Val Acc=91.81%
# Epoch 26: Train Loss=0.3629, Train Acc=89.27%, Val Loss=0.2928, Val Acc=92.23%
# Epoch 27: Train Loss=0.3189, Train Acc=90.14%, Val Loss=0.2817, Val Acc=92.82%
# Epoch 28: Train Loss=0.3327, Train Acc=89.36%, Val Loss=0.2992, Val Acc=92.65%
# Epoch 29: Train Loss=0.3074, Train Acc=90.54%, Val Loss=0.2854, Val Acc=93.67%
# Epoch 30: Train Loss=0.3399, Train Acc=89.44%, Val Loss=0.2825, Val Acc=93.33%
# Epoch 31: Train Loss=0.3180, Train Acc=90.60%, Val Loss=0.2952, Val Acc=92.57%
# Epoch 32: Train Loss=0.3177, Train Acc=89.80%, Val Loss=0.2861, Val Acc=92.65%
# Epoch 33: Train Loss=0.3251, Train Acc=90.69%, Val Loss=0.2737, Val Acc=93.24%
# Epoch 34: Train Loss=0.3043, Train Acc=90.48%, Val Loss=0.3071, Val Acc=92.23%
# Epoch 35: Train Loss=0.3134, Train Acc=90.41%, Val Loss=0.3062, Val Acc=92.15%
# Epoch 36: Train Loss=0.3137, Train Acc=90.46%, Val Loss=0.2860, Val Acc=93.50%
# Epoch 37: Train Loss=0.3054, Train Acc=90.46%, Val Loss=0.2838, Val Acc=93.16%
# Epoch 38: Train Loss=0.2875, Train Acc=91.32%, Val Loss=0.2755, Val Acc=92.82%
# Epoch 39: Train Loss=0.3042, Train Acc=90.43%, Val Loss=0.3041, Val Acc=92.57%
# Epoch 40: Train Loss=0.2868, Train Acc=91.32%, Val Loss=0.3122, Val Acc=92.31%
# Epoch 41: Train Loss=0.2977, Train Acc=90.90%, Val Loss=0.2966, Val Acc=92.91%
# Epoch 42: Train Loss=0.2847, Train Acc=91.17%, Val Loss=0.2839, Val Acc=93.33%
# Epoch 43: Train Loss=0.3026, Train Acc=90.67%, Val Loss=0.3110, Val Acc=92.74%
# Epoch 44: Train Loss=0.2705, Train Acc=91.64%, Val Loss=0.2961, Val Acc=92.99%
# Epoch 45: Train Loss=0.2885, Train Acc=91.11%, Val Loss=0.3122, Val Acc=92.82%
# Epoch 46: Train Loss=0.2882, Train Acc=91.32%, Val Loss=0.3379, Val Acc=92.06%
# Epoch 47: Train Loss=0.2950, Train Acc=91.05%, Val Loss=0.3044, Val Acc=93.33%
# Epoch 48: Train Loss=0.2481, Train Acc=92.31%, Val Loss=0.2996, Val Acc=93.50%
# Epoch 49: Train Loss=0.2819, Train Acc=91.91%, Val Loss=0.3045, Val Acc=93.41%
# Epoch 50: Train Loss=0.3166, Train Acc=90.69%, Val Loss=0.3077, Val Acc=92.91%
# Fold 5
# Epoch 1: Train Loss=1.4780, Train Acc=42.46%, Val Loss=1.1702, Val Acc=63.18%
# Epoch 2: Train Loss=1.1968, Train Acc=57.66%, Val Loss=0.9526, Val Acc=65.88%
# Epoch 3: Train Loss=1.0388, Train Acc=63.79%, Val Loss=0.7915, Val Acc=79.22%
# Epoch 4: Train Loss=0.8870, Train Acc=70.33%, Val Loss=0.5980, Val Acc=87.42%
# Epoch 5: Train Loss=0.7776, Train Acc=73.78%, Val Loss=0.4516, Val Acc=91.05%
# Epoch 6: Train Loss=0.6982, Train Acc=76.79%, Val Loss=0.4089, Val Acc=91.39%
# Epoch 7: Train Loss=0.6567, Train Acc=78.25%, Val Loss=0.3643, Val Acc=91.30%
# Epoch 8: Train Loss=0.6002, Train Acc=80.28%, Val Loss=0.3410, Val Acc=91.64%
# Epoch 9: Train Loss=0.5500, Train Acc=83.15%, Val Loss=0.3061, Val Acc=92.40%
# Epoch 10: Train Loss=0.5414, Train Acc=83.21%, Val Loss=0.2987, Val Acc=92.74%
# Epoch 11: Train Loss=0.5141, Train Acc=84.06%, Val Loss=0.2942, Val Acc=92.57%
# Epoch 12: Train Loss=0.4860, Train Acc=84.57%, Val Loss=0.2841, Val Acc=93.07%
# Epoch 13: Train Loss=0.4688, Train Acc=85.54%, Val Loss=0.3031, Val Acc=91.47%
# Epoch 14: Train Loss=0.4818, Train Acc=84.78%, Val Loss=0.2852, Val Acc=92.74%
# Epoch 15: Train Loss=0.4446, Train Acc=85.90%, Val Loss=0.2904, Val Acc=91.72%
# Epoch 16: Train Loss=0.4258, Train Acc=87.06%, Val Loss=0.2727, Val Acc=93.07%
# Epoch 17: Train Loss=0.4182, Train Acc=87.01%, Val Loss=0.2824, Val Acc=91.98%
# Epoch 18: Train Loss=0.4211, Train Acc=86.93%, Val Loss=0.2690, Val Acc=93.07%
# Epoch 19: Train Loss=0.4086, Train Acc=87.10%, Val Loss=0.2723, Val Acc=93.16%
# Epoch 20: Train Loss=0.3685, Train Acc=89.32%, Val Loss=0.2682, Val Acc=92.91%
# Epoch 21: Train Loss=0.3941, Train Acc=87.73%, Val Loss=0.2689, Val Acc=93.07%
# Epoch 22: Train Loss=0.3703, Train Acc=88.05%, Val Loss=0.2756, Val Acc=92.99%
# Epoch 23: Train Loss=0.3910, Train Acc=88.05%, Val Loss=0.2763, Val Acc=92.91%
# Epoch 24: Train Loss=0.3668, Train Acc=89.06%, Val Loss=0.2572, Val Acc=93.33%
# Epoch 25: Train Loss=0.3362, Train Acc=89.23%, Val Loss=0.2583, Val Acc=93.33%
# Epoch 26: Train Loss=0.3732, Train Acc=88.20%, Val Loss=0.2627, Val Acc=94.00%
# Epoch 27: Train Loss=0.3423, Train Acc=89.57%, Val Loss=0.2638, Val Acc=93.67%
# Epoch 28: Train Loss=0.3366, Train Acc=89.67%, Val Loss=0.2763, Val Acc=93.67%
# Epoch 29: Train Loss=0.3432, Train Acc=89.42%, Val Loss=0.2866, Val Acc=93.33%
# Epoch 30: Train Loss=0.3261, Train Acc=89.86%, Val Loss=0.2798, Val Acc=93.67%
# Epoch 31: Train Loss=0.3340, Train Acc=89.27%, Val Loss=0.3006, Val Acc=92.57%
# Epoch 32: Train Loss=0.3196, Train Acc=90.03%, Val Loss=0.2778, Val Acc=93.16%
# Epoch 33: Train Loss=0.3038, Train Acc=90.60%, Val Loss=0.2925, Val Acc=93.58%
# Epoch 34: Train Loss=0.3284, Train Acc=89.91%, Val Loss=0.2914, Val Acc=93.58%
# Epoch 35: Train Loss=0.3060, Train Acc=90.12%, Val Loss=0.2760, Val Acc=93.75%
# Epoch 36: Train Loss=0.2950, Train Acc=90.92%, Val Loss=0.2751, Val Acc=94.26%
# Epoch 37: Train Loss=0.3138, Train Acc=90.46%, Val Loss=0.2960, Val Acc=93.41%
# Epoch 38: Train Loss=0.3010, Train Acc=91.11%, Val Loss=0.3026, Val Acc=94.17%
# Epoch 39: Train Loss=0.2863, Train Acc=91.49%, Val Loss=0.3167, Val Acc=93.24%
# Epoch 40: Train Loss=0.3021, Train Acc=90.96%, Val Loss=0.3096, Val Acc=94.26%
# Epoch 41: Train Loss=0.2819, Train Acc=90.90%, Val Loss=0.2877, Val Acc=94.09%
# Epoch 42: Train Loss=0.2884, Train Acc=90.62%, Val Loss=0.3107, Val Acc=94.59%
# Epoch 43: Train Loss=0.2890, Train Acc=90.92%, Val Loss=0.3155, Val Acc=93.24%
# Epoch 44: Train Loss=0.2966, Train Acc=90.35%, Val Loss=0.3014, Val Acc=94.34%
# Epoch 45: Train Loss=0.3016, Train Acc=90.84%, Val Loss=0.3058, Val Acc=94.34%
# Epoch 46: Train Loss=0.2753, Train Acc=91.22%, Val Loss=0.2912, Val Acc=94.26%
# Epoch 47: Train Loss=0.2918, Train Acc=90.65%, Val Loss=0.3240, Val Acc=93.24%
# Epoch 48: Train Loss=0.2894, Train Acc=91.03%, Val Loss=0.3108, Val Acc=93.92%
# Epoch 49: Train Loss=0.2763, Train Acc=90.88%, Val Loss=0.3041, Val Acc=93.58%
# Epoch 50: Train Loss=0.2730, Train Acc=91.22%, Val Loss=0.3147, Val Acc=94.34%

# %%
# Plot Training and Validation Accuracy
plt.figure(figsize=(10, 4))  # Set figure size

# Plot accuracy curves for each fold
for i in range(k_folds):
    plt.plot(fold_train_accuracies[i], label=f'Train Fold {i+1}', linestyle='-')  # Solid line for training accuracy
    plt.plot(fold_val_accuracies[i], label=f'Val Fold {i+1}', linestyle='--')     # Dashed line for validation accuracy

# Configure plot appearance
plt.title('Training/Validation Accuracy per Fold')
plt.xlabel('Epoch')             # X-axis: epoch number
plt.ylabel('Accuracy')          # Y-axis: accuracy percentage
plt.legend()                    # Show legend to distinguish folds
plt.grid(True)                  # Add grid for readability
plt.tight_layout()              # Adjust layout to prevent clipping
plt.show()                      # Display the plot

# Plot Training and Validation Loss
plt.figure(figsize=(10, 4))  # Set figure size

# Plot loss curves for each fold
for i in range(k_folds):
    plt.plot(fold_train_losses[i], label=f'Train Fold {i+1}', linestyle='-')  # Solid line for training loss
    plt.plot(fold_val_losses[i], label=f'Val Fold {i+1}', linestyle='--')     # Dashed line for validation loss

# Configure plot appearance
plt.title('Training/Validation Loss per Fold')
plt.xlabel('Epoch')          # X-axis: epoch number
plt.ylabel('Loss')           # Y-axis: loss value
plt.legend()                 # Show legend to distinguish folds
plt.grid(True)               # Add grid for readability
plt.tight_layout()           # Adjust layout
plt.show()                   # Display the plot

# %%
# Print best cross-validation accuracy obtained during K-Fold training
print(f"Best validation accuracy from CV: {best_val_acc:.2f}%")
print("Retraining on full training data...")

# Prepare full training dataset and dataloader
full_train_ds = MotionSense(X_train, Y_train)                      # Use entire training set
full_train_dl = DataLoader(full_train_ds, batch_size=32, shuffle=True)  # DataLoader for batching and shuffling

# Initialize the model
model = FCNet(input_size, hidden_size, num_classes)

# Load weights from the best-performing fold (optional but helpful)
model.load_state_dict(best_model_state)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

# Retrain for a fixed number of epochs using the full dataset
for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0
    correct = 0
    total = 0

    # Iterate over batches
    for inputs, labels in full_train_dl:
        optimizer.zero_grad()                    # Reset gradients
        outputs = model(inputs.float())          # Forward pass
        loss = criterion(outputs, labels.long()) # Compute loss
        loss.backward()                          # Backpropagation
        optimizer.step()                         # Update model weights

        # Accumulate loss and accuracy
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Compute epoch-level loss and accuracy
    epoch_loss = running_loss / len(full_train_dl)
    epoch_acc = 100 * correct / total

    # Print training progress
    print(f"Retrain Epoch {epoch+1}: Loss = {epoch_loss:.4f}, Accuracy = {epoch_acc:.2f}%")
# Out:
# Best validation accuracy from CV: 94.34%
# Retraining on full training data...
# Retrain Epoch 1: Loss = 0.3418, Accuracy = 90.17%
# Retrain Epoch 2: Loss = 0.3269, Accuracy = 90.41%
# Retrain Epoch 3: Loss = 0.3198, Accuracy = 89.84%
# Retrain Epoch 4: Loss = 0.3392, Accuracy = 89.77%
# Retrain Epoch 5: Loss = 0.3044, Accuracy = 90.41%
# Retrain Epoch 6: Loss = 0.3103, Accuracy = 90.38%
# Retrain Epoch 7: Loss = 0.2945, Accuracy = 90.98%
# Retrain Epoch 8: Loss = 0.3055, Accuracy = 90.31%
# Retrain Epoch 9: Loss = 0.3068, Accuracy = 90.59%
# Retrain Epoch 10: Loss = 0.3133, Accuracy = 90.44%
# Retrain Epoch 11: Loss = 0.2875, Accuracy = 91.20%
# Retrain Epoch 12: Loss = 0.2995, Accuracy = 91.35%
# Retrain Epoch 13: Loss = 0.2887, Accuracy = 90.86%
# Retrain Epoch 14: Loss = 0.2946, Accuracy = 90.73%
# Retrain Epoch 15: Loss = 0.2724, Accuracy = 91.89%
# Retrain Epoch 16: Loss = 0.3052, Accuracy = 90.97%
# Retrain Epoch 17: Loss = 0.2727, Accuracy = 91.84%
# Retrain Epoch 18: Loss = 0.2969, Accuracy = 90.56%
# Retrain Epoch 19: Loss = 0.2938, Accuracy = 91.05%
# Retrain Epoch 20: Loss = 0.2794, Accuracy = 91.07%
# Retrain Epoch 21: Loss = 0.2661, Accuracy = 91.72%
# Retrain Epoch 22: Loss = 0.2689, Accuracy = 91.66%
# Retrain Epoch 23: Loss = 0.2730, Accuracy = 91.89%
# Retrain Epoch 24: Loss = 0.2637, Accuracy = 92.26%
# Retrain Epoch 25: Loss = 0.2687, Accuracy = 91.74%
# Retrain Epoch 26: Loss = 0.2996, Accuracy = 91.07%
# Retrain Epoch 27: Loss = 0.2736, Accuracy = 91.29%
# Retrain Epoch 28: Loss = 0.2547, Accuracy = 91.94%
# Retrain Epoch 29: Loss = 0.2742, Accuracy = 91.54%
# Retrain Epoch 30: Loss = 0.2711, Accuracy = 91.42%
# Retrain Epoch 31: Loss = 0.2420, Accuracy = 92.42%
# Retrain Epoch 32: Loss = 0.2596, Accuracy = 91.72%
# Retrain Epoch 33: Loss = 0.2595, Accuracy = 92.21%
# Retrain Epoch 34: Loss = 0.2727, Accuracy = 91.71%
# Retrain Epoch 35: Loss = 0.2553, Accuracy = 92.21%
# Retrain Epoch 36: Loss = 0.2589, Accuracy = 92.35%
# Retrain Epoch 37: Loss = 0.2531, Accuracy = 91.71%
# Retrain Epoch 38: Loss = 0.2454, Accuracy = 92.26%
# Retrain Epoch 39: Loss = 0.2732, Accuracy = 91.51%
# Retrain Epoch 40: Loss = 0.2592, Accuracy = 92.11%
# Retrain Epoch 41: Loss = 0.2491, Accuracy = 92.42%
# Retrain Epoch 42: Loss = 0.2479, Accuracy = 91.99%
# Retrain Epoch 43: Loss = 0.2651, Accuracy = 92.31%
# Retrain Epoch 44: Loss = 0.2665, Accuracy = 91.72%
# Retrain Epoch 45: Loss = 0.2692, Accuracy = 91.74%
# Retrain Epoch 46: Loss = 0.2481, Accuracy = 92.06%
# Retrain Epoch 47: Loss = 0.2470, Accuracy = 92.45%
# Retrain Epoch 48: Loss = 0.2600, Accuracy = 91.88%
# Retrain Epoch 49: Loss = 0.2593, Accuracy = 92.26%
# Retrain Epoch 50: Loss = 0.2697, Accuracy = 91.93%

# %%
# Prepare test dataset and DataLoader
test_ds = MotionSense(X_test, Y_test)                  # Create dataset from test features and labels
test_dl = DataLoader(test_ds, batch_size=32, shuffle=False)  # DataLoader without shuffling for evaluation

model.eval()   # Set model to evaluation mode (disables dropout, batchnorm updates)
all_preds = [] # To store predicted labels for all test samples
all_labels = [] # To store true labels for all test samples

# Disable gradient computation for faster inference and lower memory usage
with torch.no_grad():
    for inputs, labels in test_dl:
        outputs = model(inputs.float())               # Forward pass to get outputs/logits
        _, predicted = torch.max(outputs.data, 1)    # Get class with highest score as prediction
        all_preds.extend(predicted.cpu().numpy())    # Collect predictions on CPU as numpy array
        all_labels.extend(labels.cpu().numpy())      # Collect true labels

# Convert collected lists to numpy arrays for metric calculations
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Calculate overall test accuracy
test_acc = 100 * (all_preds == all_labels).sum() / len(all_labels)
print(f"Test Accuracy: {test_acc:.2f}%")

# Calculate additional performance metrics with weighted averaging for imbalanced classes
precision = precision_score(all_labels, all_preds, average='weighted')  # Precision metric
recall = recall_score(all_labels, all_preds, average='weighted')        # Recall metric
f1 = f1_score(all_labels, all_preds, average='weighted')                # F1 score metric
conf_matrix = confusion_matrix(all_labels, all_preds)                   # Confusion matrix

# Print the computed metrics
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)

# Optional: Print detailed classification report with per-class metrics
print("\nClassification Report:")
print(classification_report(all_labels, all_preds))
# Out:
# Test Accuracy: 93.44%
# Precision: 0.9357
# Recall: 0.9344
# F1 Score: 0.9334
# Confusion Matrix:
# [[ 86   0   5   1   5   0]
#  [ 10  89   8   0   1   2]
#  [  0   8 255   1   8   0]
#  [ 11   6   5  75   2   0]
#  [  0   1   0   0 266   0]
#  [  0   0   0   0   0 283]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84        97
#            1       0.86      0.81      0.83       110
#            2       0.93      0.94      0.94       272
#            3       0.97      0.76      0.85        99
#            4       0.94      1.00      0.97       267
#            5       0.99      1.00      1.00       283
#
#     accuracy                           0.93      1128
#    macro avg       0.92      0.90      0.90      1128
# weighted avg       0.94      0.93      0.93      1128

# %%
import seaborn as sns

# Set up the plot with a specific size for better readability
plt.figure(figsize=(8,6))

# Create a heatmap visualization of the confusion matrix using Seaborn
sns.heatmap(
    conf_matrix,            # Confusion matrix data to visualize
    annot=True,             # Annotate cells with numeric values
    fmt='d',                # Format annotations as integers
    cmap='Blues',           # Use a blue color palette for the heatmap
    xticklabels=['dws', 'ups', 'wlk', 'jog', 'std', 'sit'],  # Class labels for predicted axis
    yticklabels=['dws', 'ups', 'wlk', 'jog', 'std', 'sit']   # Class labels for true axis
)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
