# %% [markdown]
# # Human Activity Recognition
# This notebook provides some guidelines for building a classifier for the MotionSense dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# # Generate time-series data
# The original MotionSense dataset comes in a slightly cumbersome format, but the authors do provide a few functions to produce Pandas DataFrames with control over what is produced. For our purposes we are not concerned with all of the target data, as we only need to know the activity that was being recorded.

# %%
def get_ds_infos():
    """
    Read the file includes data subject information.

    EEE4114: Technically we do not need these data, as we are not concerned about identifying the subjects. 
    
    Data Columns:
    0: code [1-24]
    1: weight [kg]
    2: height [cm]
    3: age [years]
    4: gender [0:Female, 1:Male]
    
    Returns:
        A pandas DataFrame that contains information about data subjects' attributes 
    """ 

    dss = pd.read_csv(f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/data_subjects_info.csv')
    print("[INFO] -- Data subjects' information is imported.")
    
    return dss

def set_data_types(data_types=["userAcceleration"]):
    """
    Select the sensors and the mode to shape the final dataset. 

    EEE4114F: Choose sensors that you think are useful or would like to include in training. 
    You can choose all of them, or you could opt to try a limited set of input features
    
    Args:
        data_types: A list of sensor data type from this list: [attitude, gravity, rotationRate, userAcceleration] 

    Returns:
        It returns a list of columns to use for creating time-series from files.
    """
    dt_list = []
    for t in data_types:
        if t != "attitude":
            dt_list.append([t+".x",t+".y",t+".z"])
        else:
            dt_list.append([t+".roll", t+".pitch", t+".yaw"])

    return dt_list


def create_time_series(dt_list, act_labels, trial_codes, mode="mag", labeled=True):
    """
    EEE4114F: This defines what data you would like to include for a given set.  

    Args:
        dt_list: A list of columns that shows the type of data we want.
        act_labels: list of activites
        trial_codes: list of trials
        mode: It can be "raw" which means you want raw data
        for every dimension of each data type,
        [attitude(roll, pitch, yaw); gravity(x, y, z); rotationRate(x, y, z); userAcceleration(x,y,z)].
        or it can be "mag" which means you only want the magnitude for each data type: (x^2+y^2+z^2)^(1/2)
        labeled: True, if we want a labeled dataset. False, if we only want sensor values.

    Returns:
        It returns a time-series of sensor data.
    
    """
    num_data_cols = len(dt_list) if mode == "mag" else len(dt_list*3)

    if labeled:
        dataset = np.zeros((0,num_data_cols+1)) # "1" --> [act] we do not need the other labels
    else:
        dataset = np.zeros((0,num_data_cols))
        
    ds_list = get_ds_infos()
    
    print("[INFO] -- Creating Time-Series")
    for sub_id in ds_list["code"]:
        for act_id, act in enumerate(act_labels):
            for trial in trial_codes[act_id]:
                fname = f'C:/Users/emanu/Documents/GithubRepos/EEE4114F-ML-Project-2025/data/A_DeviceMotion_data/'+act+'_'+str(trial)+'/sub_'+str(int(sub_id))+'.csv'
                raw_data = pd.read_csv(fname)
                raw_data = raw_data.drop(['Unnamed: 0'], axis=1)
                vals = np.zeros((len(raw_data), num_data_cols))
                for x_id, axes in enumerate(dt_list):
                    if mode == "mag":
                        vals[:,x_id] = (raw_data[axes]**2).sum(axis=1)**0.5        
                    else:
                        vals[:,x_id*3:(x_id+1)*3] = raw_data[axes].values
                    vals = vals[:,:num_data_cols]
                if labeled:
                    lbls = np.array([[act_id]]*len(raw_data))
                    vals = np.concatenate((vals, lbls), axis=1)
                dataset = np.append(dataset,vals, axis=0)
    cols = []
    for axes in dt_list:
        if mode == "raw":
            cols += axes
        else:
            cols += [str(axes[0][:-2])]
            
    if labeled:
        cols += ["act"]
    
    dataset = pd.DataFrame(data=dataset, columns=cols)
    return dataset

# %% [markdown]
# You would need to decide what to include in your dataset, for example if you want to try a reduce dataset with only a few sensors then you can alter the `sdt` list.

# %%
ACT_LABELS = ["dws","ups", "wlk", "jog", "std", "sit"]
TRIAL_CODES = {
    ACT_LABELS[0]:[1,2,11],
    ACT_LABELS[1]:[3,4,12],
    ACT_LABELS[2]:[7,8,15],
    ACT_LABELS[3]:[9,16],
    ACT_LABELS[4]:[6,14],
    ACT_LABELS[5]:[5,13]
}

## Here we set parameter to build labeled time-series from dataset of "(A)DeviceMotion_data"
## attitude(roll, pitch, yaw); gravity(x, y, z); rotationRate(x, y, z); userAcceleration(x,y,z)
sdt = ["attitude", "gravity"]
print("[INFO] -- Selected sensor data types: "+str(sdt))    
act_labels = ACT_LABELS [0:4]
print("[INFO] -- Selected activites: "+str(act_labels))    
trial_codes = [TRIAL_CODES[act] for act in act_labels]
dt_list = set_data_types(sdt)
dataset = create_time_series(dt_list, act_labels, trial_codes, mode="raw", labeled=True)
print("[INFO] -- Shape of time-Series dataset:"+str(dataset.shape))    
dataset.head()
# Out:
# [INFO] -- Selected sensor data types: ['attitude', 'gravity']
# [INFO] -- Selected activites: ['dws', 'ups', 'wlk', 'jog']
# [INFO] -- Data subjects' information is imported.
# [INFO] -- Creating Time-Series
# [INFO] -- Shape of time-Series dataset:(767660, 7)
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  act
# 0  -0.031672  0.0
# 1  -0.032255  0.0
# 2  -0.032707  0.0
# 3  -0.041140  0.0
# 4  -0.058530  0.0

# %% [markdown]
# # Data Pre-processing
# There are numerous approaches to solving this task and your choice of algorithm will determine what form your input data should take. For example, a feed-forward neural network could be used, but what type of representation would make sense? Without being able to account for the temporal structure of the data, feed-forward networks might fail. One way around this is to potentially use summarized statistics about the data to simplify the features in a way that is not reliant on temporal information. E.g. instead of the raw signal for the acceleration, what if you worked with the mean? This might not be the best approach, compared to other algorithms, but it could be useful for a feed-forward network.
#
# what about convolutional neural networks? Well, you could use 1D convolutions directly on time-series data which would then result in fewer model parameters compared to a fully-connected network, with the added benefit of retaining temporal information. Alternatively you could look to transform the time-series data into 2D data using something such as an FFT to produce a spectogram. Or for something simpler you can create fixed windows to divide your dataset into chunks of 2D data e.g. for 6 sensors and a window of 400 samples you would generate a 6 x 400 input.

# %%
def windows(dataset, window_size=400, stride=200):
    """
    Create fixed-length windows of the input data. 

    Args:
        dataset: DataFrame of the time-series data
        size: (int) the size of the windows in number of samples.
        stride: (int) the stride length of the windows. 

    Returns:
        windows_df: DataFrame of the windowed time-series data. Each window should have the shape (n_sensors, window_size). 
            The number of examples will change depending on the stride.    

    """

    windows_df = pd.DataFrame()

    return windows_df

# %% [markdown]
# # Pytorch Dataset
# If using Pytorch it is useful to create datasets using their dataset structures. This may require modification if using additional transformations, or formats

# %%
class MotionSense(Dataset):
    def __init__(self, X, Y, transform=None):
        self.X = torch.tensor(X.values)
        self.Y = torch.tensor(Y.values)
        self.transform = transform

    def __getitem__(self, index):
        if torch.is_tensor(index):
            index = int(index.item())

        x = self.X[index]
        y = self.Y[index]

        return x, y

    def __len__(self):
        return len(self.X)

# %% [markdown]
# # Resampling
# You can split the dataset using sklearn, but you need to take care with your specific data. For example, randomly splitting raw sensor data will result in jumbled time-series signals.

# %%
X = dataset[dt_list[0]] # You could collect the input and target data as separate dataframes
Y = dataset.act

# %%
# You may be tempted to use train_test_split directly. But if using raw sensor data this would randomize the signals and not retain the order. 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)

# %%
X_train.head()
# Out:
#         attitude.roll  attitude.pitch  attitude.yaw
# 9892         0.663510       -0.626979      0.987572
# 228573       0.400124       -1.295022      0.575873
# 330425      -3.126583       -0.969074     -0.489576
# 266223       0.044079       -1.382963     -0.683808
# 55005        0.270858       -0.821511      1.456301

# %% [markdown]
# Notice the indeces are all jumbled? If using windowed data the usual splitting methods work, as each window retains the order of sensor values, as long as you split the data along the correct axis.
#
# If using summarized data e.g. taking the mean, max, min etc. as input features rather than the raw data then you should be fine using train_test_split.
#
# If working with raw sensor data there is an sklearn fuction for splitting time series data to make splitting raw signals easier if you want to work with that instead.

# %%
# Here is an example of the TimeSeriesSplit. It does create cross-validation data by default. 
ts_cv = TimeSeriesSplit(
    n_splits=5,
    gap=20,
    max_train_size=10000,
    test_size=1000
)

all_splits = list(ts_cv.split(X ,Y)) # These are indices, not the data itself.

# %% [markdown]
# Once you have the indices you can sample the data

# %%
X.iloc[all_splits[0][0]].head() # This is the training input data from the first split
# Out:
#         attitude.roll  attitude.pitch  attitude.yaw
# 752640      -1.495920       -1.000981     -1.166895
# 752641      -1.447688       -0.984781     -1.181937
# 752642      -1.359836       -0.982208     -1.175865
# 752643      -1.271804       -0.996054     -1.143785
# 752644      -1.215326       -1.020445     -1.106657

# %%
Y.iloc[all_splits[0][0]].head() # This is the training target data from the first split. You can see the indices still match, and arre ordered correctly.
# Out:
# 752640    1.0
# 752641    1.0
# 752642    1.0
# 752643    1.0
# 752644    1.0
# Name: act, dtype: float64

# %% [markdown]
# Once you have your splits, you can convert them to Pytorch datasets for easier loading. Technically you could offload the sampling methods to Pytorch samplers, but this can be trickier to implement.

# %%
train_1 = MotionSense(X.iloc[all_splits[0][0]].reset_index(drop=True), 
                      Y.iloc[all_splits[0][0]].reset_index(drop=True)) # reset_index is to make sure each new set is indexed from 0
train_1_loader = DataLoader(train_1, batch_size=5)  # Will load data in batches. Batching raw signals can be problematic if it cuts-off a given signal, or stitches it together with other signals etc.

# %% [markdown]
# # Models
# As mentioned previously there are a few options for the types of models you end up using.

# %%
def FCNet (nn.Module):
    def __init__(self):
        super(FCNet, self).__init__()
        # define your model parameters

    def forward(self, x):
        # determine how data flows through the model
        return x

# %% [markdown]
# # Training
# With your model defined you will need to decide on an optimizer used to perform parameter updates. The choice is yours, but for the most part default optimizers like Adam should work for CNNs, although SGD can be more stable but take longer to train.
#
# You can then load in data, for example if using the loader described before the loop shown below will iterate through batches of data.

# %%
for i, (X, Y) in enumerate(train_1_loader, 0):
    print(f"Batch: {i}")
    print(f"Input: {X}")
    print(f"Target: {Y}")
# Out:
# Batch: 0
# Input: tensor([[-1.4959, -1.0010, -1.1669],
#         [-1.4477, -0.9848, -1.1819],
#         [-1.3598, -0.9822, -1.1759],
#         [-1.2718, -0.9961, -1.1438],
#         [-1.2153, -1.0204, -1.1067]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 1
# Input: tensor([[-1.2263, -1.0453, -1.1163],
#         [-1.2169, -1.0652, -1.1150],
#         [-1.1931, -1.0796, -1.1055],
#         [-1.1753, -1.0925, -1.1078],
#         [-1.1669, -1.1039, -1.1096]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 2
# Input: tensor([[-1.1352, -1.1126, -1.1085],
#         [-1.0819, -1.1183, -1.1036],
#         [-1.0354, -1.1253, -1.1026],
#         [-1.0059, -1.1372, -1.1089],
#         [-0.9958, -1.1494, -1.1349]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 3
# Input: tensor([[-1.0042, -1.1557, -1.1850],
#         [-1.0291, -1.1535, -1.2555],
#         [-1.0579, -1.1465, -1.3236],
#         [-1.0816, -1.1386, -1.3777],
#         [-1.0925, -1.1341, -1.4169]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 4
# Input: tensor([[-1.0985, -1.1355, -1.4395],
#         [-1.1086, -1.1416, -1.4521],
#         [-1.1285, -1.1509, -1.4714],
#         [-1.1355, -1.1612, -1.4857],
#         [-1.1365, -1.1732, -1.4849]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 5
# Input: tensor([[-1.1107, -1.1949, -1.4468],
#         [-1.0348, -1.2289, -1.3479],
#         [-0.8677, -1.2591, -1.1612],
#         [-0.6403, -1.2629, -0.9016],
#         [-0.4317, -1.2396, -0.6501]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 6
# Input: tensor([[-0.2985, -1.2159, -0.4758],
#         [-0.2165, -1.2080, -0.3580],
#         [-0.1579, -1.2205, -0.2888],
#         [-0.1423, -1.2567, -0.2849],
#         [-0.1895, -1.2838, -0.3765]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 7
# Input: tensor([[-0.3590, -1.3184, -0.6133],
#         [-0.6733, -1.3466, -0.9979],
#         [-1.1191, -1.3436, -1.4901],
#         [-1.4131, -1.2891, -1.7696],
#         [-1.5710, -1.2119, -1.8537]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 8
# Input: tensor([[-1.7158, -1.1167, -1.9332],
#         [-1.8489, -1.0043, -2.0304],
#         [-1.9325, -0.8828, -2.1071],
#         [-1.9669, -0.7668, -2.1489],
#         [-2.0010, -0.6626, -2.1786]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 9
# Input: tensor([[-2.0343, -0.5530, -2.2064],
#         [-2.0732, -0.4436, -2.2267],
#         [-2.1099, -0.3449, -2.2425],
#         [-2.1563, -0.2624, -2.2545],
#         [-2.2081, -0.1919, -2.2621]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 10
# Input: tensor([[-2.2329, -0.1274, -2.2694],
#         [-2.2470, -0.0737, -2.2723],
#         [-2.2557, -0.0321, -2.2687],
#         [-2.2686, -0.0037, -2.2575],
#         [-2.2866,  0.0073, -2.2463]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 11
# Input: tensor([[-2.2961e+00,  5.1660e-03, -2.2423e+00],
#         [-2.2775e+00,  3.0900e-04, -2.2330e+00],
#         [-2.2356e+00, -7.4110e-03, -2.2135e+00],
#         [-2.2137e+00, -2.3209e-02, -2.1993e+00],
#         [-2.2270e+00, -3.9066e-02, -2.1902e+00]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 12
# Input: tensor([[-2.2569, -0.0404, -2.1931],
#         [-2.2769, -0.0646, -2.1853],
#         [-2.2328, -0.1096, -2.1631],
#         [-2.2236, -0.1668, -2.1502],
#         [-2.1908, -0.2260, -2.1490]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 13
# Input: tensor([[-2.1676, -0.2932, -2.1473],
#         [-2.1433, -0.3622, -2.1461],
#         [-2.1245, -0.4318, -2.1490],
#         [-2.1037, -0.4956, -2.1469],
#         [-2.0683, -0.5546, -2.1383]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 14
# Input: tensor([[-2.0109, -0.6084, -2.1224],
#         [-1.9527, -0.6579, -2.0975],
#         [-1.8858, -0.7055, -2.0656],
#         [-1.8125, -0.7540, -2.0288],
#         [-1.7455, -0.8000, -1.9888]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 15
# Input: tensor([[-1.6964, -0.8418, -1.9507],
#         [-1.6592, -0.8830, -1.9191],
#         [-1.6161, -0.9262, -1.8873],
#         [-1.5633, -0.9712, -1.8550],
#         [-1.5125, -1.0189, -1.8252]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 16
# Input: tensor([[-1.4616, -1.0658, -1.7917],
#         [-1.4119, -1.1060, -1.7625],
#         [-1.3652, -1.1418, -1.7343],
#         [-1.3195, -1.1755, -1.7077],
#         [-1.2680, -1.2048, -1.6828]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 17
# Input: tensor([[-1.2148, -1.2270, -1.6593],
#         [-1.1716, -1.2405, -1.6416],
#         [-1.1456, -1.2452, -1.6365],
#         [-1.1377, -1.2451, -1.6437],
#         [-1.1547, -1.2459, -1.6702]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 18
# Input: tensor([[-1.1716, -1.2484, -1.7047],
#         [-1.1862, -1.2498, -1.7367],
#         [-1.2284, -1.2495, -1.7846],
#         [-1.2656, -1.2443, -1.8302],
#         [-1.2648, -1.2374, -1.8313]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 19
# Input: tensor([[-1.2494, -1.2440, -1.8227],
#         [-1.1829, -1.2674, -1.7784],
#         [-1.0697, -1.2991, -1.6837],
#         [-0.9346, -1.3185, -1.5542],
#         [-0.7471, -1.3266, -1.3516]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 20
# Input: tensor([[-0.5131, -1.3189, -1.0912],
#         [-0.3003, -1.2917, -0.8425],
#         [-0.1617, -1.2640, -0.6693],
#         [-0.0606, -1.2515, -0.5452],
#         [ 0.0258, -1.2523, -0.4596]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 21
# Input: tensor([[ 0.0748, -1.2556, -0.4402],
#         [ 0.0267, -1.2825, -0.5106],
#         [-0.1624, -1.3164, -0.7116],
#         [-0.3657, -1.3281, -0.9411],
#         [-0.6053, -1.3316, -1.2040]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 22
# Input: tensor([[-0.9287, -1.3309, -1.5270],
#         [-1.2251, -1.3052, -1.7863],
#         [-1.4401, -1.2502, -1.9558],
#         [-1.6333, -1.1691, -2.1076],
#         [-1.7596, -1.0619, -2.2233]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 23
# Input: tensor([[-1.8289, -0.9457, -2.3128],
#         [-1.9105, -0.8406, -2.3729],
#         [-1.9799, -0.7398, -2.4163],
#         [-2.0188, -0.6381, -2.4434],
#         [-2.0505, -0.5434, -2.4617]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 24
# Input: tensor([[-2.0888, -0.4567, -2.4805],
#         [-2.1273, -0.3787, -2.4985],
#         [-2.1559, -0.3099, -2.5117],
#         [-2.1824, -0.2493, -2.5203],
#         [-2.2037, -0.1958, -2.5292]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 25
# Input: tensor([[-2.2309, -0.1519, -2.5399],
#         [-2.2650, -0.1168, -2.5443],
#         [-2.2981, -0.0946, -2.5367],
#         [-2.3189, -0.0851, -2.5218],
#         [-2.3147, -0.0811, -2.5172]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 26
# Input: tensor([[-2.2827, -0.0735, -2.5231],
#         [-2.2444, -0.0716, -2.5177],
#         [-2.2244, -0.0760, -2.5007],
#         [-2.2306, -0.0674, -2.4913],
#         [-2.2495, -0.0771, -2.4781]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 27
# Input: tensor([[-2.2389, -0.1250, -2.4581],
#         [-2.2569, -0.1860, -2.4432],
#         [-2.2485, -0.2497, -2.4342],
#         [-2.2404, -0.3201, -2.4291],
#         [-2.2125, -0.3910, -2.4178]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 28
# Input: tensor([[-2.1718, -0.4594, -2.4044],
#         [-2.1266, -0.5354, -2.3997],
#         [-2.0888, -0.5942, -2.3806],
#         [-2.0726, -0.6538, -2.3574],
#         [-2.0479, -0.7168, -2.3439]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 29
# Input: tensor([[-2.0152, -0.7720, -2.3309],
#         [-1.9763, -0.8246, -2.3124],
#         [-1.9279, -0.8759, -2.2881],
#         [-1.8569, -0.9254, -2.2582],
#         [-1.7771, -0.9820, -2.2277]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 30
# Input: tensor([[-1.7020, -1.0318, -2.2005],
#         [-1.6507, -1.0780, -2.1853],
#         [-1.6436, -1.1322, -2.1836],
#         [-1.6310, -1.1749, -2.1623],
#         [-1.6128, -1.2116, -2.1346]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 31
# Input: tensor([[-1.5694, -1.2477, -2.0773],
#         [-1.5212, -1.2729, -2.0143],
#         [-1.5150, -1.2915, -1.9902],
#         [-1.4872, -1.3032, -1.9582],
#         [-1.4599, -1.3070, -1.9386]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 32
# Input: tensor([[-1.4564, -1.3065, -1.9517],
#         [-1.4955, -1.2998, -2.0095],
#         [-1.5240, -1.2913, -2.0637],
#         [-1.5843, -1.2857, -2.1672],
#         [-1.6350, -1.2848, -2.2696]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 33
# Input: tensor([[-1.6860, -1.2842, -2.3539],
#         [-1.6909, -1.2903, -2.3777],
#         [-1.6686, -1.3146, -2.3351],
#         [-1.5841, -1.3541, -2.2354],
#         [-1.4350, -1.3853, -2.0589]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 34
# Input: tensor([[-1.1762, -1.3993, -1.7436],
#         [-0.8436, -1.3995, -1.3555],
#         [-0.4274, -1.3930, -0.9075],
#         [-0.0893, -1.3654, -0.5530],
#         [ 0.1298, -1.3347, -0.3372]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 35
# Input: tensor([[ 0.2676, -1.3149, -0.2094],
#         [ 0.3603, -1.3064, -0.1259],
#         [ 0.4327, -1.3086, -0.0618],
#         [ 0.4705, -1.3262, -0.0236],
#         [ 0.4578, -1.3639, -0.0449]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 36
# Input: tensor([[ 0.3747, -1.4099, -0.1667],
#         [ 0.1304, -1.4492, -0.4697],
#         [-0.3025, -1.4663, -0.9459],
#         [-0.6727, -1.4532, -1.3165],
#         [-0.8433, -1.4309, -1.4616]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 37
# Input: tensor([[-0.9626, -1.4138, -1.5696],
#         [-1.0969, -1.4001, -1.7046],
#         [-1.2098, -1.3823, -1.8192],
#         [-1.2892, -1.3572, -1.9010],
#         [-1.3727, -1.3323, -1.9843]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 38
# Input: tensor([[-1.4442, -1.3102, -2.0590],
#         [-1.4808, -1.2898, -2.1066],
#         [-1.5194, -1.2671, -2.1498],
#         [-1.5745, -1.2399, -2.1907],
#         [-1.6300, -1.2092, -2.2151]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 39
# Input: tensor([[-1.6832, -1.1775, -2.2341],
#         [-1.7284, -1.1467, -2.2534],
#         [-1.7575, -1.1188, -2.2714],
#         [-1.7709, -1.0966, -2.2888],
#         [-1.7736, -1.0820, -2.3055]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 40
# Input: tensor([[-1.7687, -1.0748, -2.3123],
#         [-1.7676, -1.0740, -2.3083],
#         [-1.7705, -1.0775, -2.2978],
#         [-1.7732, -1.0845, -2.2816],
#         [-1.7736, -1.0969, -2.2552]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 41
# Input: tensor([[-1.7640, -1.1157, -2.2153],
#         [-1.7373, -1.1422, -2.1672],
#         [-1.6954, -1.1734, -2.1110],
#         [-1.6495, -1.2058, -2.0599],
#         [-1.5709, -1.2350, -2.0113]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 42
# Input: tensor([[-1.4959, -1.2522, -1.9672],
#         [-1.5057, -1.2500, -1.9707],
#         [-1.5297, -1.2370, -1.9670],
#         [-1.5294, -1.2207, -1.9328],
#         [-1.4693, -1.2166, -1.8775]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 43
# Input: tensor([[-1.3350, -1.2339, -1.7892],
#         [-1.2118, -1.2582, -1.6922],
#         [-1.1316, -1.2663, -1.5952],
#         [-1.0178, -1.2555, -1.4609],
#         [-0.8380, -1.2548, -1.2867]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 44
# Input: tensor([[-0.7667, -1.2911, -1.2131],
#         [-0.7113, -1.3137, -1.1286],
#         [-0.6671, -1.2899, -1.0211],
#         [-0.6642, -1.2389, -0.9978],
#         [-0.5791, -1.2058, -1.0218]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 45
# Input: tensor([[-0.4764, -1.2154, -1.0919],
#         [-0.4260, -1.2303, -1.1326],
#         [-0.3515, -1.2158, -1.0956],
#         [-0.3291, -1.2057, -1.1066],
#         [-0.3630, -1.2095, -1.1553]], dtype=torch.float64)
# Target: tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# Batch: 46
# Input: tensor([[-2.3169, -1.3510,  0.1152],
#         [-2.2511, -1.3751,  0.1520],
#         [-2.1746, -1.3960,  0.2042],
#         [-2.0952, -1.4115,  0.2670],
#         [-2.0177, -1.4232,  0.3274]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 47
# Input: tensor([[-1.9343, -1.4324,  0.3898],
#         [-1.8375, -1.4406,  0.4684],
#         [-1.7134, -1.4479,  0.5737],
#         [-1.5766, -1.4539,  0.6895],
#         [-1.4559, -1.4592,  0.7907]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 48
# Input: tensor([[-1.3426, -1.4633,  0.8846],
#         [-1.2172, -1.4668,  0.9899],
#         [-1.0808, -1.4702,  1.1075],
#         [-0.9420, -1.4730,  1.2315],
#         [-0.8051, -1.4741,  1.3576]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 49
# Input: tensor([[-0.6679, -1.4723,  1.4858],
#         [-0.5362, -1.4678,  1.6092],
#         [-0.4113, -1.4609,  1.7262],
#         [-0.2961, -1.4533,  1.8342],
#         [-0.1861, -1.4456,  1.9370]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 50
# Input: tensor([[-0.0772, -1.4377,  2.0379],
#         [ 0.0347, -1.4274,  2.1384],
#         [ 0.1365, -1.4146,  2.2255],
#         [ 0.2171, -1.4010,  2.2954],
#         [ 0.2788, -1.3871,  2.3492]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 51
# Input: tensor([[ 0.3231, -1.3747,  2.3815],
#         [ 0.3570, -1.3663,  2.3944],
#         [ 0.3890, -1.3605,  2.4079],
#         [ 0.4264, -1.3565,  2.4339],
#         [ 0.4686, -1.3562,  2.4709]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 52
# Input: tensor([[ 0.5078, -1.3595,  2.5114],
#         [ 0.5423, -1.3644,  2.5510],
#         [ 0.5558, -1.3713,  2.5811],
#         [ 0.5635, -1.3795,  2.6138],
#         [ 0.5954, -1.3955,  2.6692]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 53
# Input: tensor([[ 0.6634, -1.4212,  2.7564],
#         [ 0.7894, -1.4561,  2.9000],
#         [ 1.0720, -1.4973, -3.0884],
#         [ 1.9034, -1.5254, -2.2508],
#         [ 2.8643, -1.5038, -1.2794]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 54
# Input: tensor([[-3.0656, -1.4600, -0.9035],
#         [-2.8823, -1.4128, -0.6838],
#         [-2.7517, -1.3654, -0.5104],
#         [-2.6740, -1.3167, -0.3851],
#         [-2.6447, -1.2670, -0.3031]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 55
# Input: tensor([[-2.6450, -1.2181, -0.2471],
#         [-2.6534, -1.1734, -0.2019],
#         [-2.6575, -1.1350, -0.1569],
#         [-2.6542, -1.1024, -0.1064],
#         [-2.6472, -1.0741, -0.0523]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 56
# Input: tensor([[-2.6380e+00, -1.0511e+00,  1.1400e-04],
#         [-2.6304e+00, -1.0350e+00,  4.7412e-02],
#         [-2.6294e+00, -1.0263e+00,  8.6633e-02],
#         [-2.6332e+00, -1.0241e+00,  1.1715e-01],
#         [-2.6343e+00, -1.0276e+00,  1.3992e-01]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 57
# Input: tensor([[-2.6273, -1.0373,  0.1569],
#         [-2.6174, -1.0538,  0.1707],
#         [-2.6165, -1.0755,  0.1810],
#         [-2.6328, -1.0984,  0.1861],
#         [-2.6591, -1.1194,  0.1897]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 58
# Input: tensor([[-2.6816, -1.1338,  0.1969],
#         [-2.6955, -1.1381,  0.2087],
#         [-2.6909, -1.1373,  0.2247],
#         [-2.6668, -1.1393,  0.2410],
#         [-2.6341, -1.1549,  0.2538]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 59
# Input: tensor([[-2.6199, -1.1842,  0.2497],
#         [-2.6493, -1.2141,  0.2241],
#         [-2.6905, -1.2332,  0.2001],
#         [-2.6890, -1.2508,  0.2015],
#         [-2.6653, -1.2774,  0.1994]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 60
# Input: tensor([[-2.6551, -1.3088,  0.1829],
#         [-2.6789, -1.3467,  0.1460],
#         [-2.7149, -1.3797,  0.1180],
#         [-2.7250, -1.4021,  0.1265],
#         [-2.7039, -1.4208,  0.1551]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 61
# Input: tensor([[-2.6703, -1.4371,  0.1873],
#         [-2.6615, -1.4550,  0.1996],
#         [-2.6842, -1.4727,  0.1834],
#         [-2.7153, -1.4910,  0.1542],
#         [-2.7841, -1.5100,  0.0844]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 62
# Input: tensor([[-2.9418, -1.5282, -0.0767],
#         [ 3.0120, -1.5438, -0.4131],
#         [ 2.2378, -1.5516, -1.1939],
#         [ 1.4472, -1.5435, -1.9875],
#         [ 1.1466, -1.5269, -2.2878]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 63
# Input: tensor([[ 1.0410, -1.5090, -2.3908],
#         [ 0.9921, -1.4918, -2.4369],
#         [ 0.9485, -1.4752, -2.4791],
#         [ 0.9103, -1.4576, -2.5204],
#         [ 0.8860, -1.4383, -2.5536]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 64
# Input: tensor([[ 0.8841, -1.4187, -2.5685],
#         [ 0.9040, -1.4031, -2.5636],
#         [ 0.9377, -1.3920, -2.5433],
#         [ 0.9760, -1.3833, -2.5155],
#         [ 1.0124, -1.3752, -2.4878]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 65
# Input: tensor([[ 1.0473, -1.3672, -2.4589],
#         [ 1.0853, -1.3607, -2.4197],
#         [ 1.1138, -1.3562, -2.3782],
#         [ 1.1428, -1.3564, -2.3226],
#         [ 1.1938, -1.3625, -2.2398]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 66
# Input: tensor([[ 1.2938, -1.3762, -2.1098],
#         [ 1.4473, -1.3949, -1.9212],
#         [ 1.7100, -1.4125, -1.6257],
#         [ 2.0353, -1.4158, -1.2881],
#         [ 2.3301, -1.4075, -0.9922]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 67
# Input: tensor([[ 2.5527, -1.3982, -0.7557],
#         [ 2.7633, -1.3865, -0.5147],
#         [ 3.0164, -1.3684, -0.2192],
#         [-3.0494, -1.3406,  0.0460],
#         [-2.9318, -1.3095,  0.2183]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 68
# Input: tensor([[-2.8753, -1.2771,  0.3375],
#         [-2.8501, -1.2532,  0.4318],
#         [-2.8368, -1.2274,  0.5136],
#         [-2.8232, -1.2059,  0.5891],
#         [-2.7965, -1.1881,  0.6628]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 69
# Input: tensor([[-2.7605, -1.1740,  0.7331],
#         [-2.7256, -1.1653,  0.7968],
#         [-2.6995, -1.1612,  0.8504],
#         [-2.6765, -1.1606,  0.8956],
#         [-2.6467, -1.1639,  0.9376]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 70
# Input: tensor([[-2.6140, -1.1730,  0.9766],
#         [-2.5827, -1.1883,  1.0126],
#         [-2.5623, -1.2101,  1.0416],
#         [-2.5540, -1.2380,  1.0649],
#         [-2.5479, -1.2668,  1.0867]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 71
# Input: tensor([[-2.5387, -1.2904,  1.1098],
#         [-2.5255, -1.3066,  1.1342],
#         [-2.4853, -1.3183,  1.1716],
#         [-2.4025, -1.3289,  1.2371],
#         [-2.2869, -1.3422,  1.3325]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 72
# Input: tensor([[-2.2090, -1.3577,  1.4080],
#         [-2.2235, -1.3691,  1.4054],
#         [-2.2458, -1.3758,  1.3963],
#         [-2.1799, -1.3853,  1.4540],
#         [-2.0337, -1.4050,  1.5756]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 73
# Input: tensor([[-1.8140, -1.4333,  1.7572],
#         [-1.6126, -1.4566,  1.9209],
#         [-1.5295, -1.4714,  1.9766],
#         [-1.4964, -1.4771,  1.9953],
#         [-1.3447, -1.4753,  2.1123]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 74
# Input: tensor([[-1.0993, -1.4709,  2.3152],
#         [-0.8437, -1.4669,  2.5450],
#         [-0.6411, -1.4616,  2.7417],
#         [-0.5095, -1.4527,  2.8743],
#         [-0.4144, -1.4437,  2.9631]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 75
# Input: tensor([[-0.3310, -1.4330,  3.0271],
#         [-0.2516, -1.4212,  3.0914],
#         [-0.1659, -1.4106, -3.1227],
#         [-0.0692, -1.4019, -3.0513],
#         [ 0.0269, -1.3958, -2.9849]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 76
# Input: tensor([[ 0.1069, -1.3949, -2.9332],
#         [ 0.1746, -1.3993, -2.8894],
#         [ 0.2394, -1.4042, -2.8497],
#         [ 0.2930, -1.4087, -2.8207],
#         [ 0.3100, -1.4221, -2.8221]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 77
# Input: tensor([[ 0.2814, -1.4548, -2.8608],
#         [ 0.1100, -1.5082, -3.0391],
#         [-1.5648, -1.5445,  1.5521],
#         [-2.4318, -1.4769,  0.6466],
#         [-2.5752, -1.4006,  0.4609]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 78
# Input: tensor([[-2.6287, -1.3330,  0.3804],
#         [-2.6350, -1.2715,  0.3657],
#         [-2.5773, -1.2161,  0.4011],
#         [-2.4919, -1.1647,  0.4240],
#         [-2.4658, -1.1203,  0.4052]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 79
# Input: tensor([[-2.4753, -1.0841,  0.3834],
#         [-2.4954, -1.0541,  0.3692],
#         [-2.5128, -1.0295,  0.3604],
#         [-2.5233, -1.0115,  0.3519],
#         [-2.5330, -0.9998,  0.3402]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 80
# Input: tensor([[-2.5419, -0.9960,  0.3264],
#         [-2.5471, -1.0001,  0.3119],
#         [-2.5526, -1.0097,  0.2968],
#         [-2.5580, -1.0272,  0.2876],
#         [-2.5505, -1.0562,  0.2925]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 81
# Input: tensor([[-2.5198, -1.0969,  0.3168],
#         [-2.4737, -1.1405,  0.3535],
#         [-2.4269, -1.1727,  0.3911],
#         [-2.3463, -1.1907,  0.4392],
#         [-2.2742, -1.1900,  0.4753]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 82
# Input: tensor([[-2.2553, -1.1776,  0.4904],
#         [-2.2840, -1.1636,  0.4920],
#         [-2.2765, -1.1697,  0.5104],
#         [-2.1937, -1.2031,  0.5688],
#         [-2.0773, -1.2453,  0.6482]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 83
# Input: tensor([[-2.0235, -1.2832,  0.6823],
#         [-2.0296, -1.2920,  0.6684],
#         [-1.9821, -1.2903,  0.7095],
#         [-1.9291, -1.2948,  0.7459],
#         [-1.7842, -1.3271,  0.8357]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 84
# Input: tensor([[-1.5948, -1.3626,  0.9538],
#         [-1.4212, -1.3831,  1.0503],
#         [-1.2457, -1.3910,  1.1587],
#         [-1.0609, -1.3898,  1.2775],
#         [-0.9061, -1.3928,  1.3761]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 85
# Input: tensor([[-0.7761, -1.3959,  1.4826],
#         [-0.6513, -1.3923,  1.5872],
#         [-0.5316, -1.3810,  1.6799],
#         [-0.4204, -1.3665,  1.7620],
#         [-0.3267, -1.3557,  1.8280]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 86
# Input: tensor([[-0.2098, -1.3469,  1.9100],
#         [-0.0780, -1.3396,  2.0017],
#         [ 0.0629, -1.3338,  2.0983],
#         [ 0.2077, -1.3277,  2.1940],
#         [ 0.3258, -1.3215,  2.2664]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 87
# Input: tensor([[ 0.3855, -1.3165,  2.2996],
#         [ 0.4176, -1.3157,  2.3178],
#         [ 0.4531, -1.3187,  2.3400],
#         [ 0.4852, -1.3278,  2.3608],
#         [ 0.5220, -1.3508,  2.3986]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 88
# Input: tensor([[ 0.5710, -1.3919,  2.4559],
#         [ 0.7144, -1.4528,  2.5856],
#         [ 1.2138, -1.5206,  3.0364],
#         [-3.1083, -1.5357, -1.3048],
#         [-2.5547, -1.4730, -0.7234]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 89
# Input: tensor([[-2.4447, -1.3943, -0.5746],
#         [-2.3756, -1.3106, -0.4503],
#         [-2.3115, -1.2260, -0.3491],
#         [-2.2733, -1.1509, -0.3124],
#         [-2.2829, -1.0943, -0.2956]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 90
# Input: tensor([[-2.2839, -1.0510, -0.2759],
#         [-2.2897, -1.0118, -0.2509],
#         [-2.3119, -0.9780, -0.2263],
#         [-2.3467, -0.9519, -0.2101],
#         [-2.3919, -0.9380, -0.2042]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 91
# Input: tensor([[-2.4449, -0.9367, -0.2032],
#         [-2.4930, -0.9465, -0.2039],
#         [-2.5186, -0.9673, -0.2048],
#         [-2.5183, -1.0040, -0.2053],
#         [-2.4982, -1.0573, -0.1992]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 92
# Input: tensor([[-2.4904, -1.1104, -0.1897],
#         [-2.5305, -1.1364, -0.2108],
#         [-2.4970, -1.1341, -0.1868],
#         [-2.4317, -1.1307, -0.1335],
#         [-2.4021, -1.1176, -0.1052]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 93
# Input: tensor([[-2.3962, -1.1162, -0.1042],
#         [-2.3423, -1.1592, -0.0958],
#         [-2.2650, -1.2154, -0.0407],
#         [-2.2145, -1.2181,  0.0261],
#         [-2.2341, -1.1943,  0.0155]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 94
# Input: tensor([[-2.2564, -1.1999,  0.0097],
#         [-2.2295, -1.2310,  0.0231],
#         [-2.1393, -1.2860,  0.0573],
#         [-1.9956, -1.3350,  0.1122],
#         [-1.8527, -1.3623,  0.1862]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 95
# Input: tensor([[-1.6920, -1.3821,  0.2913],
#         [-1.5407, -1.3966,  0.4171],
#         [-1.4194, -1.4175,  0.5330],
#         [-1.1987, -1.4316,  0.7258],
#         [-0.9491, -1.4374,  0.9489]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 96
# Input: tensor([[-0.6810, -1.4370,  1.2034],
#         [-0.4590, -1.4242,  1.4178],
#         [-0.2396, -1.4035,  1.6237],
#         [-0.0491, -1.3836,  1.7838],
#         [ 0.1209, -1.3685,  1.9121]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 97
# Input: tensor([[ 0.2701, -1.3590,  2.0146],
#         [ 0.3991, -1.3562,  2.1013],
#         [ 0.5085, -1.3575,  2.1804],
#         [ 0.5952, -1.3594,  2.2420],
#         [ 0.6498, -1.3642,  2.2801]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 98
# Input: tensor([[ 0.6673, -1.3851,  2.3020],
#         [ 0.7014, -1.4272,  2.3482],
#         [ 0.8883, -1.4858,  2.5320],
#         [ 1.7696, -1.5372, -2.8884],
#         [-2.8500, -1.5199, -1.2209]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 99
# Input: tensor([[-2.5167, -1.4564, -0.8689],
#         [-2.4340, -1.3795, -0.7357],
#         [-2.3775, -1.3011, -0.6240],
#         [-2.3285, -1.2247, -0.5429],
#         [-2.2956, -1.1556, -0.5172]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 100
# Input: tensor([[-2.3023, -1.0989, -0.5048],
#         [-2.3159, -1.0520, -0.4892],
#         [-2.3330, -1.0115, -0.4685],
#         [-2.3631, -0.9754, -0.4509],
#         [-2.4010, -0.9469, -0.4411]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 101
# Input: tensor([[-2.4423, -0.9303, -0.4355],
#         [-2.4858, -0.9260, -0.4295],
#         [-2.5215, -0.9339, -0.4209],
#         [-2.5382, -0.9552, -0.4131],
#         [-2.5320, -0.9919, -0.4053]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 102
# Input: tensor([[-2.5086, -1.0449, -0.3944],
#         [-2.5007, -1.1046, -0.3854],
#         [-2.5762, -1.1410, -0.4359],
#         [-2.5573, -1.1289, -0.4196],
#         [-2.4702, -1.1189, -0.3495]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 103
# Input: tensor([[-2.4150, -1.1023, -0.2993],
#         [-2.4028, -1.1037, -0.2907],
#         [-2.3700, -1.1472, -0.2961],
#         [-2.3214, -1.1940, -0.2628],
#         [-2.3045, -1.1901, -0.2321]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 104
# Input: tensor([[-2.3401, -1.1757, -0.2490],
#         [-2.3531, -1.1941, -0.2403],
#         [-2.3096, -1.2445, -0.2154],
#         [-2.2243, -1.3151, -0.1980],
#         [-2.1226, -1.3706, -0.1739]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 105
# Input: tensor([[-2.0061, -1.4005, -0.1020],
#         [-1.7986, -1.4240,  0.0687],
#         [-1.6357, -1.4464,  0.2073],
#         [-1.4223, -1.4691,  0.3977],
#         [-1.0212, -1.4810,  0.7696]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 106
# Input: tensor([[-0.6139, -1.4769,  1.1615],
#         [-0.3417, -1.4645,  1.4290],
#         [-0.1127, -1.4469,  1.6558],
#         [ 0.0784, -1.4254,  1.8377],
#         [ 0.2397, -1.4066,  1.9709]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 107
# Input: tensor([[ 0.3974, -1.3905,  2.0855],
#         [ 0.5331, -1.3772,  2.1781],
#         [ 0.6520, -1.3698,  2.2625],
#         [ 0.7612, -1.3688,  2.3469],
#         [ 0.8582, -1.3733,  2.4219]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 108
# Input: tensor([[ 0.9341, -1.3904,  2.4917],
#         [ 1.0143, -1.4259,  2.5867],
#         [ 1.3051, -1.4692,  2.8793],
#         [ 2.0766, -1.4862, -2.6514],
#         [ 2.7240, -1.4761, -1.9884]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 109
# Input: tensor([[-3.0406, -1.4494, -1.4276],
#         [-2.7400, -1.3883, -1.0853],
#         [-2.5613, -1.3163, -0.8510],
#         [-2.4437, -1.2449, -0.6864],
#         [-2.3667, -1.1716, -0.6002]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 110
# Input: tensor([[-2.3474, -1.1092, -0.5503],
#         [-2.3515, -1.0570, -0.5149],
#         [-2.3572, -1.0116, -0.4809],
#         [-2.3695, -0.9754, -0.4487],
#         [-2.3958, -0.9489, -0.4224]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 111
# Input: tensor([[-2.4338, -0.9348, -0.4004],
#         [-2.4798, -0.9339, -0.3815],
#         [-2.5250, -0.9454, -0.3663],
#         [-2.5570, -0.9679, -0.3576],
#         [-2.5706, -1.0012, -0.3547]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 112
# Input: tensor([[-2.5651, -1.0459, -0.3537],
#         [-2.5701, -1.1009, -0.3564],
#         [-2.6595, -1.1389, -0.4310],
#         [-2.6368, -1.1272, -0.4175],
#         [-2.5476, -1.1240, -0.3357]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 113
# Input: tensor([[-2.4703, -1.1125, -0.2647],
#         [-2.4293, -1.1121, -0.2265],
#         [-2.3813, -1.1595, -0.2106],
#         [-2.3548, -1.2200, -0.2059],
#         [-2.3576, -1.2117, -0.1832]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 114
# Input: tensor([[-2.3577, -1.1887, -0.1699],
#         [-2.3536, -1.1983, -0.1431],
#         [-2.3291, -1.2419, -0.1199],
#         [-2.2654, -1.3113, -0.1183],
#         [-2.1751, -1.3730, -0.1126]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 115
# Input: tensor([[-2.0541, -1.4045, -0.0481],
#         [-1.8573, -1.4281,  0.1076],
#         [-1.6575, -1.4493,  0.2699],
#         [-1.4693, -1.4728,  0.4278],
#         [-1.1047, -1.4890,  0.7523]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 116
# Input: tensor([[-0.6744, -1.4899,  1.1475],
#         [-0.2436, -1.4817,  1.5623],
#         [ 0.0362, -1.4615,  1.8382],
#         [ 0.2086, -1.4347,  2.0025],
#         [ 0.3402, -1.4079,  2.1154]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 117
# Input: tensor([[ 0.4549, -1.3832,  2.1975],
#         [ 0.5524, -1.3633,  2.2606],
#         [ 0.6405, -1.3511,  2.3179],
#         [ 0.7376, -1.3477,  2.3894],
#         [ 0.8397, -1.3504,  2.4670]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 118
# Input: tensor([[ 0.9249, -1.3611,  2.5377],
#         [ 0.9942, -1.3868,  2.6195],
#         [ 1.1286, -1.4274,  2.7712],
#         [ 1.6191, -1.4756, -3.0286],
#         [ 2.3913, -1.4913, -2.2469]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 119
# Input: tensor([[ 3.0861, -1.4831, -1.5017],
#         [-2.7936, -1.4345, -1.0552],
#         [-2.5897, -1.3682, -0.7878],
#         [-2.4645, -1.3001, -0.6023],
#         [-2.3860, -1.2303, -0.5040]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 120
# Input: tensor([[-2.3524, -1.1695, -0.4486],
#         [-2.3497, -1.1218, -0.4113],
#         [-2.3617, -1.0802, -0.3820],
#         [-2.3810, -1.0439, -0.3557],
#         [-2.4099, -1.0151, -0.3371]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 121
# Input: tensor([[-2.4488, -0.9959, -0.3268],
#         [-2.4978, -0.9877, -0.3220],
#         [-2.5428, -0.9936, -0.3171],
#         [-2.5689, -1.0115, -0.3135],
#         [-2.5724, -1.0412, -0.3137]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 122
# Input: tensor([[-2.5571, -1.0859, -0.3154],
#         [-2.5434, -1.1393, -0.3160],
#         [-2.6369, -1.1704, -0.3818],
#         [-2.6539, -1.1462, -0.3865],
#         [-2.5474, -1.1381, -0.3059]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 123
# Input: tensor([[-2.4504, -1.1287, -0.2320],
#         [-2.4102, -1.1231, -0.2069],
#         [-2.3803, -1.1595, -0.2110],
#         [-2.3412, -1.2185, -0.2076],
#         [-2.3011, -1.2211, -0.1593]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 124
# Input: tensor([[-2.3028, -1.1945, -0.1543],
#         [-2.2974, -1.2002, -0.1404],
#         [-2.2718, -1.2404, -0.1056],
#         [-2.2120, -1.3174, -0.0894],
#         [-2.1258, -1.3992, -0.0846]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 125
# Input: tensor([[-2.0110, -1.4359, -0.0276],
#         [-1.6997, -1.4564,  0.2439],
#         [-1.3674, -1.4729,  0.5414],
#         [-1.0389, -1.4904,  0.8436],
#         [-0.5414, -1.4929,  1.3071]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 126
# Input: tensor([[-0.1591, -1.4786,  1.6566],
#         [ 0.1113, -1.4590,  1.9050],
#         [ 0.2723, -1.4283,  2.0629],
#         [ 0.3439, -1.3930,  2.1367],
#         [ 0.4229, -1.3647,  2.1881]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 127
# Input: tensor([[ 0.5361, -1.3441,  2.2472],
#         [ 0.6369, -1.3308,  2.3088],
#         [ 0.7388, -1.3233,  2.3738],
#         [ 0.8439, -1.3226,  2.4493],
#         [ 0.9260, -1.3259,  2.5106]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 128
# Input: tensor([[ 0.9679, -1.3392,  2.5563],
#         [ 1.0052, -1.3692,  2.6191],
#         [ 1.1799, -1.4175,  2.8016],
#         [ 1.6362, -1.4602, -3.0312],
#         [ 2.1099, -1.4918, -2.5296]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 129
# Input: tensor([[ 2.8658, -1.5034, -1.7216],
#         [-2.7910, -1.4519, -1.0425],
#         [-2.5440, -1.3762, -0.7374],
#         [-2.4348, -1.3067, -0.5708],
#         [-2.3732, -1.2396, -0.4933]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 130
# Input: tensor([[-2.3589, -1.1831, -0.4549],
#         [-2.3718, -1.1377, -0.4325],
#         [-2.3861, -1.0980, -0.4077],
#         [-2.4055, -1.0658, -0.3796],
#         [-2.4327, -1.0398, -0.3555]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 131
# Input: tensor([[-2.4646, -1.0229, -0.3375],
#         [-2.4979, -1.0165, -0.3221],
#         [-2.5250, -1.0214, -0.3092],
#         [-2.5389, -1.0374, -0.3006],
#         [-2.5386, -1.0665, -0.2975]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 132
# Input: tensor([[-2.5212, -1.1121, -0.2918],
#         [-2.5024, -1.1670, -0.2810],
#         [-2.6107, -1.2033, -0.3566],
#         [-2.6210, -1.1828, -0.3591],
#         [-2.5028, -1.1756, -0.2715]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 133
# Input: tensor([[-2.4034, -1.1608, -0.1959],
#         [-2.3326, -1.1627, -0.1620],
#         [-2.2617, -1.2124, -0.1557],
#         [-2.2496, -1.2514, -0.1500],
#         [-2.2666, -1.2390, -0.1330]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 134
# Input: tensor([[-2.2683, -1.2309, -0.1352],
#         [-2.2779, -1.2475, -0.1409],
#         [-2.2272, -1.2966, -0.1338],
#         [-2.1173, -1.3582, -0.1119],
#         [-1.9779, -1.4015, -0.0452]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 135
# Input: tensor([[-1.8069, -1.4256,  0.0968],
#         [-1.5436, -1.4434,  0.3266],
#         [-1.3258, -1.4606,  0.5154],
#         [-1.0280, -1.4762,  0.7913],
#         [-0.6338, -1.4792,  1.1728]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 136
# Input: tensor([[-0.2950, -1.4633,  1.5089],
#         [-0.0507, -1.4377,  1.7480],
#         [ 0.1286, -1.4109,  1.9150],
#         [ 0.2895, -1.3868,  2.0533],
#         [ 0.4308, -1.3667,  2.1573]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 137
# Input: tensor([[ 0.5721, -1.3508,  2.2516],
#         [ 0.7102, -1.3388,  2.3445],
#         [ 0.8273, -1.3308,  2.4252],
#         [ 0.9136, -1.3287,  2.4861],
#         [ 0.9742, -1.3351,  2.5356]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 138
# Input: tensor([[ 1.0383, -1.3549,  2.6067],
#         [ 1.1675, -1.3875,  2.7516],
#         [ 1.4727, -1.4270,  3.0579],
#         [ 1.9119, -1.4562, -2.7844],
#         [ 2.4259, -1.4816, -2.2385]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 139
# Input: tensor([[ 3.0823, -1.4659, -1.5439],
#         [-2.8113, -1.4165, -1.0933],
#         [-2.5992, -1.3611, -0.8159],
#         [-2.4771, -1.2973, -0.6463],
#         [-2.4164, -1.2323, -0.5670]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 140
# Input: tensor([[-2.4003, -1.1792, -0.5151],
#         [-2.4037, -1.1356, -0.4783],
#         [-2.4127, -1.0977, -0.4428],
#         [-2.4287, -1.0651, -0.4125],
#         [-2.4607, -1.0378, -0.3951]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 141
# Input: tensor([[-2.5056, -1.0174, -0.3881],
#         [-2.5462, -1.0115, -0.3810],
#         [-2.5768, -1.0168, -0.3725],
#         [-2.5924, -1.0331, -0.3662],
#         [-2.5881, -1.0634, -0.3633]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 142
# Input: tensor([[-2.5624, -1.1079, -0.3529],
#         [-2.5478, -1.1578, -0.3430],
#         [-2.6353, -1.1840, -0.4111],
#         [-2.5953, -1.1777, -0.3887],
#         [-2.5000, -1.1747, -0.3110]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 143
# Input: tensor([[-2.4248, -1.1633, -0.2439],
#         [-2.3866, -1.1742, -0.2190],
#         [-2.3412, -1.2211, -0.2101],
#         [-2.2962, -1.2474, -0.1794],
#         [-2.2890, -1.2351, -0.1632]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 144
# Input: tensor([[-2.2925, -1.2275, -0.1606],
#         [-2.3040, -1.2499, -0.1542],
#         [-2.2600, -1.3116, -0.1425],
#         [-2.1658, -1.3932, -0.1277],
#         [-2.0761, -1.4436, -0.1046]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 145
# Input: tensor([[-1.8845, -1.4726,  0.0575],
#         [-1.5031, -1.4952,  0.4086],
#         [-1.0260, -1.5151,  0.8541],
#         [-0.3317, -1.5163,  1.5212],
#         [ 0.1104, -1.4925,  1.9395]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 146
# Input: tensor([[ 0.2992, -1.4644,  2.1090],
#         [ 0.4421, -1.4376,  2.2297],
#         [ 0.5249, -1.4063,  2.3065],
#         [ 0.5731, -1.3758,  2.3485],
#         [ 0.6429, -1.3503,  2.3806]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 147
# Input: tensor([[ 0.7488, -1.3314,  2.4326],
#         [ 0.8601, -1.3173,  2.5053],
#         [ 0.9559, -1.3073,  2.5682],
#         [ 1.0357, -1.3022,  2.6279],
#         [ 1.1030, -1.3025,  2.6797]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 148
# Input: tensor([[ 1.1711, -1.3128,  2.7454],
#         [ 1.2450, -1.3349,  2.8448],
#         [ 1.3902, -1.3697,  3.0116],
#         [ 1.6958, -1.4082, -2.9602],
#         [ 2.0330, -1.4465, -2.5918]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 149
# Input: tensor([[ 2.5307, -1.4697, -2.0439],
#         [ 3.1146, -1.4509, -1.3981],
#         [-2.7928, -1.4050, -0.9558],
#         [-2.5741, -1.3485, -0.6873],
#         [-2.4482, -1.2838, -0.5470]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 150
# Input: tensor([[-2.3919, -1.2245, -0.4667],
#         [-2.3724, -1.1755, -0.4109],
#         [-2.3734, -1.1320, -0.3647],
#         [-2.3832, -1.0944, -0.3207],
#         [-2.4022, -1.0629, -0.2845]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 151
# Input: tensor([[-2.4319, -1.0401, -0.2573],
#         [-2.4686, -1.0268, -0.2356],
#         [-2.5020, -1.0273, -0.2186],
#         [-2.5212, -1.0404, -0.2045],
#         [-2.5208, -1.0680, -0.1956]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 152
# Input: tensor([[-2.4980, -1.1130, -0.1899],
#         [-2.4817, -1.1671, -0.1900],
#         [-2.5535, -1.2085, -0.2361],
#         [-2.5892, -1.2178, -0.2460],
#         [-2.5105, -1.2175, -0.1744]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 153
# Input: tensor([[-2.4290, -1.2110, -0.1052],
#         [-2.3789, -1.2017, -0.0829],
#         [-2.3265, -1.2306, -0.0923],
#         [-2.2620, -1.2812, -0.0652],
#         [-2.1953, -1.2905,  0.0194]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 154
# Input: tensor([[-2.1805, -1.2756,  0.0337],
#         [-2.1716, -1.2849,  0.0402],
#         [-2.1414, -1.3268,  0.0628],
#         [-2.0179, -1.4000,  0.1288],
#         [-1.7827, -1.4643,  0.2856]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 155
# Input: tensor([[-1.4128, -1.4930,  0.6096],
#         [-0.9224, -1.4931,  1.0599],
#         [-0.4685, -1.4868,  1.4766],
#         [-0.1211, -1.4773,  1.7985],
#         [ 0.1482, -1.4543,  2.0362]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 156
# Input: tensor([[ 0.3130, -1.4283,  2.1751],
#         [ 0.4198, -1.4012,  2.2642],
#         [ 0.4624, -1.3687,  2.3048],
#         [ 0.4995, -1.3376,  2.3327],
#         [ 0.5819, -1.3123,  2.3710]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 157
# Input: tensor([[ 0.6771, -1.2950,  2.4216],
#         [ 0.7717, -1.2838,  2.4821],
#         [ 0.8727, -1.2793,  2.5402],
#         [ 0.9630, -1.2800,  2.5951],
#         [ 1.0203, -1.2844,  2.6346]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 158
# Input: tensor([[ 1.0640, -1.3000,  2.6843],
#         [ 1.1362, -1.3291,  2.7733],
#         [ 1.3303, -1.3723,  2.9702],
#         [ 1.6780, -1.4115, -2.9718],
#         [ 1.9713, -1.4501, -2.6399]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 159
# Input: tensor([[ 2.4535, -1.4774, -2.1034],
#         [-3.1212, -1.4567, -1.3313],
#         [-2.7026, -1.4026, -0.8484],
#         [-2.4998, -1.3386, -0.6024],
#         [-2.4069, -1.2711, -0.4975]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 160
# Input: tensor([[-2.3708, -1.2155, -0.4352],
#         [-2.3598, -1.1691, -0.3934],
#         [-2.3584, -1.1260, -0.3564],
#         [-2.3674, -1.0895, -0.3198],
#         [-2.3901, -1.0602, -0.2886]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 161
# Input: tensor([[-2.4269, -1.0405, -0.2657],
#         [-2.4711, -1.0324, -0.2471],
#         [-2.5068, -1.0371, -0.2307],
#         [-2.5265, -1.0561, -0.2201],
#         [-2.5249, -1.0927, -0.2144]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 162
# Input: tensor([[-2.5048, -1.1467, -0.2068],
#         [-2.5183, -1.1994, -0.2177],
#         [-2.5921, -1.2100, -0.2694],
#         [-2.5278, -1.2047, -0.2220],
#         [-2.4434, -1.1975, -0.1465]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 163
# Input: tensor([[-2.3968, -1.1950, -0.1097],
#         [-2.3932, -1.2209, -0.1381],
#         [-2.3406, -1.2396, -0.1154],
#         [-2.2219, -1.2437, -0.0114],
#         [-2.1975, -1.2409,  0.0097]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 164
# Input: tensor([[-2.2385, -1.2638, -0.0245],
#         [-2.2255, -1.3228, -0.0306],
#         [-2.1499, -1.3845, -0.0087],
#         [-1.9395, -1.4466,  0.1234],
#         [-1.6958, -1.4713,  0.3101]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 165
# Input: tensor([[-1.4243, -1.4879,  0.5456],
#         [-0.9676, -1.5014,  0.9646],
#         [-0.4283, -1.4994,  1.4747],
#         [ 0.0033, -1.4804,  1.8782],
#         [ 0.2509, -1.4500,  2.0922]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 166
# Input: tensor([[ 0.3836, -1.4168,  2.2033],
#         [ 0.4555, -1.3858,  2.2700],
#         [ 0.5057, -1.3555,  2.3152],
#         [ 0.5683, -1.3290,  2.3498],
#         [ 0.6439, -1.3067,  2.3888]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 167
# Input: tensor([[ 0.7430, -1.2888,  2.4502],
#         [ 0.8540, -1.2757,  2.5199],
#         [ 0.9451, -1.2704,  2.5808],
#         [ 1.0050, -1.2716,  2.6274],
#         [ 1.0510, -1.2786,  2.6696]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 168
# Input: tensor([[ 1.1114, -1.2973,  2.7387],
#         [ 1.1999, -1.3280,  2.8457],
#         [ 1.3993, -1.3711,  3.0524],
#         [ 1.7284, -1.4116, -2.9026],
#         [ 2.0171, -1.4556, -2.5784]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 169
# Input: tensor([[ 2.5883, -1.4789, -1.9616],
#         [-3.0203, -1.4504, -1.2215],
#         [-2.6541, -1.3977, -0.7963],
# ...
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1944
# Input: tensor([[-0.5452, -1.2234,  1.9617],
#         [-0.4302, -1.2109,  2.0325],
#         [-0.2931, -1.2063,  2.1337],
#         [-0.1556, -1.2042,  2.2493],
#         [-0.0617, -1.1880,  2.3413]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1945
# Input: tensor([[ 0.0111, -1.1688,  2.4187],
#         [ 0.0939, -1.1543,  2.4920],
#         [ 0.2132, -1.1394,  2.5671],
#         [ 0.3393, -1.1297,  2.6363],
#         [ 0.4336, -1.1273,  2.6848]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1946
# Input: tensor([[ 0.5046, -1.1348,  2.7017],
#         [ 0.5456, -1.1556,  2.6982],
#         [ 0.5351, -1.1882,  2.6650],
#         [ 0.4641, -1.2369,  2.5946],
#         [ 0.3702, -1.2931,  2.5152]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1947
# Input: tensor([[ 0.2232, -1.3468,  2.3617],
#         [-0.0978, -1.3753,  2.0418],
#         [-0.4770, -1.3715,  1.7102],
#         [-0.8101, -1.3484,  1.4401],
#         [-1.1077, -1.2963,  1.2024]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1948
# Input: tensor([[-1.3114, -1.2279,  1.0524],
#         [-1.4462, -1.1632,  0.9373],
#         [-1.5289, -1.1043,  0.8619],
#         [-1.5921, -1.0515,  0.8174],
#         [-1.6536, -1.0031,  0.7898]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1949
# Input: tensor([[-1.7098, -0.9611,  0.7760],
#         [-1.7593, -0.9303,  0.7707],
#         [-1.8054, -0.9096,  0.7710],
#         [-1.8510, -0.8986,  0.7764],
#         [-1.8912, -0.8977,  0.7852]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1950
# Input: tensor([[-1.9076, -0.9078,  0.7991],
#         [-1.8855, -0.9322,  0.8228],
#         [-1.8331, -0.9719,  0.8618],
#         [-1.7890, -1.0257,  0.9212],
#         [-1.8640, -1.1011,  0.9211]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1951
# Input: tensor([[-1.8146, -1.0978,  0.9289],
#         [-1.6888, -1.0767,  0.9912],
#         [-1.6196, -1.0565,  1.0378],
#         [-1.5468, -1.0512,  1.0795],
#         [-1.4482, -1.0869,  1.1286]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1952
# Input: tensor([[-1.4208, -1.1232,  1.1501],
#         [-1.4707, -1.1123,  1.1396],
#         [-1.4669, -1.1021,  1.1458],
#         [-1.3902, -1.1231,  1.1917],
#         [-1.2657, -1.1593,  1.2741]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1953
# Input: tensor([[-0.9411, -1.2256,  1.5272],
#         [-0.8138, -1.2508,  1.6230],
#         [-0.7215, -1.2612,  1.7094],
#         [-0.5978, -1.2597,  1.8106],
#         [-0.4590, -1.2611,  1.9138]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1954
# Input: tensor([[-0.3083, -1.2629,  2.0266],
#         [-0.1735, -1.2560,  2.1372],
#         [-0.0578, -1.2361,  2.2356],
#         [ 0.0422, -1.2157,  2.3277],
#         [ 0.1276, -1.2012,  2.4104]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1955
# Input: tensor([[ 0.2201, -1.1819,  2.4926],
#         [ 0.3032, -1.1636,  2.5602],
#         [ 0.3938, -1.1533,  2.6135],
#         [ 0.4908, -1.1484,  2.6702],
#         [ 0.5759, -1.1493,  2.7237]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1956
# Input: tensor([[ 0.6470, -1.1578,  2.7628],
#         [ 0.7032, -1.1755,  2.7914],
#         [ 0.7396, -1.2061,  2.8165],
#         [ 0.7522, -1.2478,  2.8404],
#         [ 0.7818, -1.3066,  2.8728]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1957
# Input: tensor([[ 0.8293, -1.3763,  2.8960],
#         [ 0.6080, -1.4290,  2.6654],
#         [ 0.0521, -1.4514,  2.1611],
#         [-0.6185, -1.4371,  1.5819],
#         [-1.0717, -1.3747,  1.2130]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1958
# Input: tensor([[-1.2990, -1.3046,  1.0430],
#         [-1.4315, -1.2445,  0.9357],
#         [-1.5142, -1.1883,  0.8725],
#         [-1.5659, -1.1344,  0.8448],
#         [-1.6175, -1.0825,  0.8332]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1959
# Input: tensor([[-1.6771, -1.0361,  0.8317],
#         [-1.7286, -1.0012,  0.8419],
#         [-1.7726, -0.9797,  0.8603],
#         [-1.8105, -0.9707,  0.8853],
#         [-1.8423, -0.9719,  0.9127]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1960
# Input: tensor([[-1.8566, -0.9828,  0.9413],
#         [-1.8340, -1.0044,  0.9763],
#         [-1.7760, -1.0393,  1.0283],
#         [-1.7271, -1.0850,  1.0907],
#         [-1.8717, -1.1390,  1.0293]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1961
# Input: tensor([[-1.8711, -1.1183,  1.0136],
#         [-1.7279, -1.1008,  1.0917],
#         [-1.6338, -1.0784,  1.1388],
#         [-1.5385, -1.0659,  1.1741],
#         [-1.3959, -1.0998,  1.2418]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1962
# Input: tensor([[-1.3690, -1.1424,  1.2572],
#         [-1.4134, -1.1242,  1.2642],
#         [-1.4049, -1.1017,  1.2697],
#         [-1.3166, -1.1082,  1.3451],
#         [-1.1916, -1.1516,  1.4671]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1963
# Input: tensor([[-1.0171, -1.2175,  1.6097],
#         [-0.8562, -1.2533,  1.7186],
#         [-0.7404, -1.2535,  1.7958],
#         [-0.6346, -1.2415,  1.8731],
#         [-0.5093, -1.2367,  1.9668]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1964
# Input: tensor([[-0.3565, -1.2343,  2.0935],
#         [-0.2326, -1.2250,  2.2061],
#         [-0.1360, -1.2120,  2.2958],
#         [-0.0413, -1.1952,  2.3808],
#         [ 0.0316, -1.1767,  2.4559]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1965
# Input: tensor([[ 0.0893, -1.1601,  2.5212],
#         [ 0.1631, -1.1445,  2.5831],
#         [ 0.2564, -1.1321,  2.6374],
#         [ 0.3599, -1.1274,  2.6903],
#         [ 0.4574, -1.1303,  2.7475]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1966
# Input: tensor([[ 0.5295, -1.1373,  2.7887],
#         [ 0.5603, -1.1461,  2.8021],
#         [ 0.5578, -1.1573,  2.7904],
#         [ 0.5568, -1.1748,  2.7794],
#         [ 0.5302, -1.2088,  2.7678]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1967
# Input: tensor([[ 0.4877, -1.2544,  2.7367],
#         [ 0.4268, -1.3124,  2.6565],
#         [ 0.2262, -1.3602,  2.4412],
#         [-0.1122, -1.3756,  2.1465],
#         [-0.5090, -1.3761,  1.8183]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1968
# Input: tensor([[-0.9210, -1.3410,  1.4707],
#         [-1.1800, -1.2834,  1.2502],
#         [-1.3431, -1.2281,  1.0837],
#         [-1.4351, -1.1772,  0.9858],
#         [-1.5052, -1.1295,  0.9306]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1969
# Input: tensor([[-1.5692, -1.0844,  0.8928],
#         [-1.6273, -1.0429,  0.8688],
#         [-1.6825, -1.0079,  0.8533],
#         [-1.7273, -0.9804,  0.8475],
#         [-1.7592, -0.9622,  0.8549]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1970
# Input: tensor([[-1.7803, -0.9548,  0.8697],
#         [-1.7806, -0.9567,  0.8905],
#         [-1.7524, -0.9709,  0.9221],
#         [-1.6980, -0.9983,  0.9752],
#         [-1.6545, -1.0354,  1.0484]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1971
# Input: tensor([[-1.7170, -1.1027,  1.0402],
#         [-1.6790, -1.1121,  1.0523],
#         [-1.5851, -1.0984,  1.1143],
#         [-1.5341, -1.0650,  1.1523],
#         [-1.4592, -1.0385,  1.1921]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1972
# Input: tensor([[-1.3345, -1.0640,  1.2592],
#         [-1.3154, -1.1469,  1.2962],
#         [-1.3677, -1.1845,  1.3155],
#         [-1.3204, -1.1681,  1.3520],
#         [-1.1973, -1.1753,  1.3939]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1973
# Input: tensor([[-1.0151, -1.1935,  1.4998],
#         [-0.8005, -1.2217,  1.6549],
#         [-0.6700, -1.2531,  1.7709],
#         [-0.5673, -1.2627,  1.8778],
#         [-0.4459, -1.2451,  1.9766]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1974
# Input: tensor([[-0.3287, -1.2312,  2.0391],
#         [-0.2122, -1.2237,  2.1005],
#         [-0.1207, -1.2141,  2.1663],
#         [-0.0499, -1.2057,  2.2272],
#         [ 0.0236, -1.1978,  2.2826]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1975
# Input: tensor([[ 0.0991, -1.1876,  2.3421],
#         [ 0.1794, -1.1746,  2.4063],
#         [ 0.2706, -1.1621,  2.4709],
#         [ 0.3720, -1.1507,  2.5398],
#         [ 0.4539, -1.1402,  2.6008]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1976
# Input: tensor([[ 0.5166, -1.1344,  2.6434],
#         [ 0.5781, -1.1361,  2.6749],
#         [ 0.6271, -1.1429,  2.7034],
#         [ 0.6595, -1.1586,  2.7261],
#         [ 0.6651, -1.1888,  2.7368]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1977
# Input: tensor([[ 0.6406, -1.2344,  2.7326],
#         [ 0.5985, -1.2919,  2.6910],
#         [ 0.4667, -1.3532,  2.5424],
#         [ 0.1513, -1.3893,  2.2566],
#         [-0.2302, -1.3952,  1.9334]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1978
# Input: tensor([[-0.6713, -1.3813,  1.5587],
#         [-1.0227, -1.3354,  1.2686],
#         [-1.2409, -1.2799,  1.0863],
#         [-1.3752, -1.2295,  0.9547],
#         [-1.4670, -1.1865,  0.8786]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1979
# Input: tensor([[-1.5402, -1.1479,  0.8335],
#         [-1.6009, -1.1107,  0.8079],
#         [-1.6555, -1.0799,  0.7926],
#         [-1.7051, -1.0562,  0.7862],
#         [-1.7431, -1.0393,  0.7920]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1980
# Input: tensor([[-1.7694, -1.0322,  0.8084],
#         [-1.7827, -1.0355,  0.8291],
#         [-1.7700, -1.0490,  0.8551],
#         [-1.7222, -1.0761,  0.8942],
#         [-1.6762, -1.1121,  0.9482]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1981
# Input: tensor([[-1.7317, -1.1703,  0.9501],
#         [-1.8662, -1.1833,  0.8645],
#         [-1.7265, -1.1613,  0.9601],
#         [-1.5896, -1.1384,  1.0563],
#         [-1.5150, -1.1132,  1.1074]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1982
# Input: tensor([[-1.4256, -1.1295,  1.1452],
#         [-1.3761, -1.1826,  1.1592],
#         [-1.4004, -1.1929,  1.1742],
#         [-1.4072, -1.1659,  1.1922],
#         [-1.3217, -1.1689,  1.2369]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1983
# Input: tensor([[-1.1797, -1.1913,  1.3415],
#         [-0.9608, -1.2365,  1.5265],
#         [-0.7097, -1.2981,  1.7521],
#         [-0.5551, -1.3125,  1.8952],
#         [-0.4069, -1.2982,  2.0124]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1984
# Input: tensor([[-0.2634, -1.2897,  2.1019],
#         [-0.1168, -1.2839,  2.1964],
#         [-0.0037, -1.2713,  2.2745],
#         [ 0.1018, -1.2477,  2.3476],
#         [ 0.2017, -1.2260,  2.4116]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1985
# Input: tensor([[ 0.2854, -1.2152,  2.4719],
#         [ 0.3418, -1.1957,  2.5327],
#         [ 0.3940, -1.1665,  2.5943],
#         [ 0.4652, -1.1454,  2.6469],
#         [ 0.5510, -1.1299,  2.7002]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1986
# Input: tensor([[ 0.6189, -1.1144,  2.7480],
#         [ 0.6600, -1.1060,  2.7830],
#         [ 0.6906, -1.1059,  2.8039],
#         [ 0.7314, -1.1152,  2.8326],
#         [ 0.7737, -1.1366,  2.8634]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1987
# Input: tensor([[ 0.7659, -1.1723,  2.8711],
#         [ 0.7307, -1.2187,  2.8676],
#         [ 0.6700, -1.2828,  2.8231],
#         [ 0.4860, -1.3465,  2.6658],
#         [ 0.1644, -1.3815,  2.4027]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1988
# Input: tensor([[-0.1952, -1.4017,  2.0921],
#         [-0.6593, -1.3991,  1.6757],
#         [-1.0208, -1.3598,  1.3514],
#         [-1.2472, -1.3061,  1.1379],
#         [-1.3922, -1.2514,  1.0062]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1989
# Input: tensor([[-1.5004, -1.2050,  0.9288],
#         [-1.5903, -1.1642,  0.8809],
#         [-1.6618, -1.1273,  0.8535],
#         [-1.7148, -1.0971,  0.8436],
#         [-1.7531, -1.0747,  0.8475]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1990
# Input: tensor([[-1.7832, -1.0598,  0.8607],
#         [-1.8076, -1.0537,  0.8784],
#         [-1.8184, -1.0554,  0.9007],
#         [-1.7981, -1.0667,  0.9342],
#         [-1.7392, -1.0913,  0.9851]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1991
# Input: tensor([[-1.6776, -1.1246,  1.0512],
#         [-1.7120, -1.1808,  1.0846],
#         [-1.8074, -1.1999,  1.0349],
#         [-1.6218, -1.1753,  1.1493],
#         [-1.4693, -1.1528,  1.2505]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1992
# Input: tensor([[-1.4073, -1.1285,  1.2865],
#         [-1.2799, -1.1317,  1.3605],
#         [-1.1344, -1.1773,  1.4665],
#         [-1.1871, -1.2398,  1.4881],
#         [-1.2181, -1.2284,  1.5117]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1993
# Input: tensor([[-1.1894, -1.2136,  1.5214],
#         [-1.0530, -1.2224,  1.6162],
#         [-0.7876, -1.2395,  1.8023],
#         [-0.5786, -1.2720,  1.9672],
#         [-0.4737, -1.2806,  2.0789]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1994
# Input: tensor([[-0.3417, -1.2594,  2.2131],
#         [-0.2016, -1.2282,  2.2981],
#         [-0.0731, -1.2156,  2.3719],
#         [ 0.0391, -1.1976,  2.4450],
#         [ 0.1440, -1.1815,  2.5160]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1995
# Input: tensor([[ 0.2177, -1.1719,  2.5784],
#         [ 0.2395, -1.1467,  2.6171],
#         [ 0.2525, -1.1174,  2.6439],
#         [ 0.3210, -1.0968,  2.6785],
#         [ 0.4162, -1.0911,  2.7155]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1996
# Input: tensor([[ 0.4864, -1.0875,  2.7508],
#         [ 0.5603, -1.0910,  2.7829],
#         [ 0.6283, -1.1012,  2.8094],
#         [ 0.6600, -1.1145,  2.8201],
#         [ 0.6672, -1.1342,  2.8165]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1997
# Input: tensor([[ 0.6721, -1.1664,  2.8173],
#         [ 0.6492, -1.2171,  2.8151],
#         [ 0.6463, -1.2800,  2.8052],
#         [ 0.6159, -1.3492,  2.7409],
#         [ 0.3573, -1.3905,  2.4989]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1998
# Input: tensor([[-0.0345, -1.4072,  2.1624],
#         [-0.5508, -1.3981,  1.6985],
#         [-0.9368, -1.3448,  1.3585],
#         [-1.1570, -1.2878,  1.1710],
#         [-1.2957, -1.2384,  1.0415]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
# Batch: 1999
# Input: tensor([[-1.3818, -1.1934,  0.9719],
#         [-1.4534, -1.1527,  0.9284],
#         [-1.5303, -1.1148,  0.8949],
#         [-1.5964, -1.0834,  0.8769],
#         [-1.6475, -1.0635,  0.8743]], dtype=torch.float64)
# Target: tensor([2., 2., 2., 2., 2.], dtype=torch.float64)

# %% [markdown]
# # Evaluation
# Make sure to correctly evaluate your models. Justify your methods given your particular model and data used e.g. if you use random holdout, is it justified? What do your performance metrics tell you e.g. was the model overfitting, underfitting, are their early stages in the training process where the model performs well compared to the end of training, which model do you choose to save, are the model outputs "reasonable" i.e. are there errors that might make sense given the data?
